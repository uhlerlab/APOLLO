# %%
import sys
sys.path.append('/home/xinyiz/c2p_dag/')
sys.path.append('/home/xinyiz/c2p_dag/img2seq/')

import numpy as np
import pickle
import os
import pandas as pd
from scipy import sparse

import time

import scanpy
import numpy as np

import torch
from torch import optim


import matplotlib.pyplot as plt
import seaborn as sns
import umap
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import anndata as ad
import gc


import gae.gae.optimizer as optimizer

import gae.gae.model
import gae.gae.model_lord
import gae.gae.preprocessing as preprocessing
# Out:
# 2025-06-04 19:01:16.218233: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nSamples= 2048

Z1 = np.random.binomial(1, 0.5, size=nSamples)

gamma2 = np.random.gamma(shape=5, scale=1, size=nSamples)
Z2 = Z1 + gamma2 * np.sqrt(0.0045) 

Z3 = np.random.binomial(1, 0.5, size=nSamples)

gamma4 = np.random.gamma(shape=2, scale=2, size=nSamples)
Z4 = Z3 + gamma4 * np.sqrt(0.00125)

gamma5 = np.random.gamma(shape=3, scale=2, size=nSamples)
Z5 = np.random.binomial(1, 0.5, size=nSamples)+gamma5 * np.sqrt(0.0075)

Z = np.stack([Z1, Z2, Z3, Z4, Z5], axis=1)

# %%
variables = [Z1, Z2, Z3, Z4, Z5]
titles = ['Z1', 'Z2', 'Z3', 'Z4', 'Z5']

fig, axs = plt.subplots(1, 5, figsize=(20, 4))
for i, (z, title) in enumerate(zip(variables, titles)):
    axs[i].hist(z, bins=30, color='skyblue', edgecolor='black')
    axs[i].set_title(title)
    axs[i].set_xlabel('Value')
    axs[i].set_ylabel('Samples')
    axs[i].grid(True)

plt.tight_layout()
plt.savefig('z_distribution_indeptlatent_mixingObs_2.pdf')
plt.show()

# %%
Z
# Out:
# array([[0.        , 0.22018651, 0.        , 0.16576577, 1.67831107],
#        [0.        , 0.42155413, 1.        , 1.07750778, 0.89197141],
#        [1.        , 1.30300346, 1.        , 1.10458852, 1.69282591],
#        ...,
#        [1.        , 1.67389075, 0.        , 0.23961877, 0.57366593],
#        [0.        , 0.07230504, 0.        , 0.24035569, 1.03472902],
#        [0.        , 0.32113575, 0.        , 0.21943264, 1.50925024]])

# %%
# Initialize X with zeros 
X = np.zeros((nSamples, 80))

Z_X = np.stack([Z1, Z2, Z3, Z4], axis=1)

# X1-X10: pure children of Z4
G1 = np.random.randn(10, 1)
X[:, 0:10] = Z_X[:, [3]] @ G1.T

# X11-X20: pure children of Z3
G2 = np.random.randn(10, 1)
X[:, 10:20] = Z_X[:, [2]] @ G2.T

# X21-X30: pure children of Z2
G3 = np.random.randn(10, 1)
X[:, 20:30] = Z_X[:, [1]] @ G3.T

# X31-X40: children of Z2 and Z3
G4 = np.random.randn(10, 2)
X[:, 30:40] = Z_X[:, [1, 2]] @ G4.T

# X41-X50: children of Z2 and Z4
G5 = np.random.randn(10, 2)
X[:, 40:50] = Z_X[:, [1, 3]] @ G5.T

# X51-X60: children of Z3 and Z4
G6 = np.random.randn(10, 2)
X[:, 50:60] = Z_X[:, [2, 3]] @ G6.T

# X61-X70: children of Z2, Z3, Z4
G7 = np.random.randn(10, 3)
X[:, 60:70] = Z_X[:, [1, 2, 3]] @ G7.T

G8 = np.random.randn(10, 4)
X[:, 70:80] = Z_X @ G8.T

Y = np.zeros((nSamples, 40))

Z_Y = np.stack([Z1, Z2, Z5], axis=1)

GY1 = np.random.randn(10, 1)
Y[:, 0:10] = Z_Y[:, [2]] @ GY1.T

GY2 = np.random.randn(10, 1)
Y[:, 10:20] = Z_Y[:, [1]] @ GY2.T

GY3 = np.random.randn(10, 2)
Y[:, 20:30] = Z_Y[:, [1, 2]] @ GY3.T

GY4 = np.random.randn(10, 3)
Y[:, 30:40] = Z_Y @ GY4.T

# %%
#train-test split
np.random.seed(3)
pctVal=0.05
pctTest=0.1

allIdx_all=np.arange(nSamples)
np.random.shuffle(allIdx_all)
valIdx_all=allIdx_all[:int(pctVal*nSamples)]
testIdx_all=allIdx_all[int(pctVal*nSamples):(int(pctVal*nSamples)+int(pctTest*nSamples))]
trainIdx_all=allIdx_all[(int(pctVal*nSamples)+int(pctTest*nSamples)):]

hiddenSize=20
sharedSize=2
dSpecificSize=2
seed=3
#test0: 5, 3

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
 

batchsize=256
saveFreq=100
epochs=3000
lr_latent=0.001
lr_decoder=0.0001
weight_decay=0

dropout=0.01
XreconWeight=20
ridgeL=0.01

addNoise=True
actDecay=0.001

testSaveName='lord_bce'
name='test3_noSharedRecon_indeptlatent_mixingObs_2'
logsavepath=os.path.join('/data/xinyi/c2p/simulation/results/log',testSaveName,name)
modelsavepath=os.path.join('/data/xinyi/c2p/simulation/results/models',testSaveName,name)
plotsavepath=os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName,name)

loss_x=torch.nn.MSELoss()
loss_y=torch.nn.MSELoss()

# %%
if not os.path.exists(os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName)):
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName))
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/models',testSaveName))
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/log',testSaveName))
if not os.path.exists(logsavepath):
    os.mkdir(logsavepath)
if not os.path.exists(modelsavepath):
    os.mkdir(modelsavepath)
if not os.path.exists(plotsavepath):
    os.mkdir(plotsavepath)
nFeatures_x=X.shape[1]
nFeatures_y=Y.shape[1]

# %%
def train(epoch):
    t = time.time()
    model_x.train()
    model_y.train()
    
    loss_all=0
    loss_x_train_all_x=0
    loss_x_train_all_y=0
    loss_lNorm_all=0
    loss_lNorm_all_x=0
    loss_lNorm_all_y=0
    
    ntrainBatches=int(np.ceil(trainIdx_all.shape[0]/batchsize))
    for i in range(ntrainBatches):
#         if i%200==0:
#             print(i)
        trainIdx=trainIdx_all[i*batchsize:min((i+1)*batchsize,trainIdx_all.shape[0])]
        traintarget_x=torch.tensor(X[trainIdx]).cuda().float()
        traintarget_y=torch.tensor(Y[trainIdx]).cuda().float()
        trainIdx=torch.tensor(trainIdx)
        trainInput_shared=latent_shared(trainIdx).cuda().float()
        trainInput_x=latent_x(trainIdx).cuda().float()
        trainInput_y=latent_y(trainIdx).cuda().float()

        if addNoise:
            trainInput_shared=trainInput_shared+torch.randn_like(trainInput_shared)
            trainInput_x=trainInput_x+torch.randn_like(trainInput_x)
            trainInput_y=trainInput_y+torch.randn_like(trainInput_y)
            
        optimizer_x.zero_grad()
        optimizer_latent.zero_grad()
        optimizer_y.zero_grad()

        recon_x= model_x(torch.cat((trainInput_shared,trainInput_x),dim=1))
        y_recon = model_y(torch.cat((trainInput_shared,trainInput_y),dim=1))

        loss_x_train_x=loss_x(recon_x, traintarget_x)
        loss_x_train_y=loss_y(y_recon, traintarget_y)        
        loss=loss_x_train_x+loss_x_train_y
        
#         print(y_recon)
#         print(traintarget_y)
        if addNoise:
            loss_lNorm=torch.mean(torch.linalg.norm(latent_shared(trainIdx).cuda(),dim=1))/latent_shared.embedding_dim
            loss_lNorm_all+=loss_lNorm.item()
            loss+=loss_lNorm*actDecay
            
            loss_lNorm_x=torch.mean(torch.linalg.norm(latent_x(trainIdx).cuda(),dim=1))/latent_x.embedding_dim
            loss_lNorm_all_x+=loss_lNorm_x.item()
            loss+=loss_lNorm_x*actDecay
            
            loss_lNorm_y=torch.mean(torch.linalg.norm(latent_y(trainIdx).cuda(),dim=1))/latent_y.embedding_dim
            loss_lNorm_all_y+=loss_lNorm_y.item()
            loss+=loss_lNorm_y*actDecay
            
        
        loss_x_train_all_y+=loss_x_train_y.item()
        loss_x_train_all_x+=loss_x_train_x.item()
        loss_all+=loss.item()
        
            
        loss.backward()
        optimizer_x.step()
        optimizer_latent.step()
        optimizer_y.step()


    loss_x_train_all_y=loss_x_train_all_y/ntrainBatches
    loss_x_train_all_x=loss_x_train_all_x/ntrainBatches
    loss_all=loss_all/ntrainBatches
    if addNoise:
        loss_lNorm_all=loss_lNorm_all/ntrainBatches
        loss_lNorm_all_x=loss_lNorm_all_x/ntrainBatches
        loss_lNorm_all_y=loss_lNorm_all_y/ntrainBatches

    
    with torch.no_grad():
        model_x.eval()
        model_y.eval()
        loss_x_val_all_x=0
        loss_x_val_all_y=0
        loss_val_all=0
        nvalBatches=int(np.ceil(valIdx_all.shape[0]/batchsize))
        for i in range(nvalBatches):
            valIdx=valIdx_all[i*batchsize:min((i+1)*batchsize,valIdx_all.shape[0])]
            valtarget_x=torch.tensor(X[valIdx]).cuda().float()
            valtarget_y=torch.tensor(Y[valIdx]).cuda().float()
            valIdx=torch.tensor(valIdx)
            valInput_shared=latent_shared(valIdx).cuda().float()
            valInput_x=latent_x(valIdx).cuda().float()
            valInput_y=latent_y(valIdx).cuda().float()

            recon_x= model_x(torch.cat((valInput_shared,valInput_x),dim=1))
            y_recon = model_y(torch.cat((valInput_shared,valInput_y),dim=1))

            loss_x_val_x=loss_x(recon_x, valtarget_x)
            loss_x_val_y=loss_y(y_recon, valtarget_y)


            loss=loss_x_val_x+loss_x_val_y
            
            loss_x_val_all_x+=loss_x_val_x.item()
            loss_x_val_all_y+=loss_x_val_y.item()
            loss_val_all+=loss.item()

        loss_x_val_all_x=loss_x_val_all_x/nvalBatches
        loss_x_val_all_y=loss_x_val_all_y/nvalBatches
        loss_val_all=loss_val_all/nvalBatches
    
    print(' Epoch: {:04d}'.format(epoch),
          'loss_train: {:.4f}'.format(loss_all),
          'loss_x_train_x: {:.4f}'.format(loss_x_train_all_x),
          'loss_x_train_y: {:.4f}'.format(loss_x_train_all_y),
          'loss_val: {:.4f}'.format(loss_val_all),
          'loss_x_val_x: {:.4f}'.format(loss_x_val_all_x),
          'loss_x_val_y: {:.4f}'.format(loss_x_val_all_y),
          'time: {:.4f}s'.format(time.time() - t))
    return loss_all,loss_x_train_all_x,loss_x_train_all_y,loss_val_all,loss_x_val_all_x,loss_x_val_all_y,loss_lNorm_all,loss_lNorm_all_x,loss_lNorm_all_y

# %%
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.enabled = True

model_x = gae.gae.model_lord.fc_decode_l4(nFeatures_x,sharedSize+dSpecificSize,hiddenSize, dropout)
model_y = gae.gae.model_lord.fc_decode_l4(nFeatures_y, sharedSize+dSpecificSize,hiddenSize, dropout)


model_x.cuda()
model_y.cuda()

optimizer_x = optim.Adam(model_x.parameters(), lr=lr_decoder, weight_decay=weight_decay)
optimizer_y = optim.Adam(model_y.parameters(), lr=lr_decoder, weight_decay=weight_decay)

latent_shared=torch.nn.Embedding(X.shape[0],sharedSize)
latent_x=torch.nn.Embedding(X.shape[0],dSpecificSize)
latent_y=torch.nn.Embedding(X.shape[0],dSpecificSize)
optimizer_latent= torch.optim.Adam([latent_shared.weight,latent_x.weight,latent_y.weight], lr=lr_latent, weight_decay=weight_decay)

train_loss=[np.inf]*(epochs)
val_loss=[np.inf]*(epochs)

train_loss_x=[np.inf]*(epochs)
val_loss_x=[np.inf]*(epochs)

train_loss_y=[np.inf]*(epochs)
val_loss_y=[np.inf]*(epochs)

train_lNorm=[np.inf]*(epochs)
train_lNorm_x=[np.inf]*(epochs)
train_lNorm_y=[np.inf]*(epochs)

t_ep=time.time()

for ep in range(epochs):

    train_loss[ep],train_loss_x[ep],train_loss_y[ep],val_loss[ep],val_loss_x[ep],val_loss_y[ep],train_lNorm[ep],train_lNorm_x[ep],train_lNorm_y[ep]=train(ep)


    if ep%saveFreq == 0 and ep != 0:
        torch.save(model_x.cpu().state_dict(), os.path.join(modelsavepath,str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)+'_x.pt'))
        torch.save(model_y.cpu().state_dict(), os.path.join(modelsavepath,str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)+'_y.pt'))

        with open(os.path.join(modelsavepath,'latentx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_x.weight, output, pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(modelsavepath,'latentShared_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_shared.weight, output, pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(modelsavepath,'latenty_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_y.weight, output, pickle.HIGHEST_PROTOCOL)



    model_x.cuda()
    model_y.cuda()
    torch.cuda.empty_cache()
print(' total time: {:.4f}s'.format(time.time() - t_ep))
# Out:
#  Epoch: 0000 loss_train: 4.2429 loss_x_train_x: 1.6054 loss_x_train_y: 2.6356 loss_val: 3.8393 loss_x_val_x: 1.5004 loss_x_val_y: 2.3389 time: 0.7536s
#  Epoch: 0001 loss_train: 4.2123 loss_x_train_x: 1.5952 loss_x_train_y: 2.6151 loss_val: 3.8269 loss_x_val_x: 1.4962 loss_x_val_y: 2.3308 time: 0.0673s
#  Epoch: 0002 loss_train: 4.1859 loss_x_train_x: 1.5809 loss_x_train_y: 2.6031 loss_val: 3.8302 loss_x_val_x: 1.4982 loss_x_val_y: 2.3321 time: 0.0589s
#  Epoch: 0003 loss_train: 4.1569 loss_x_train_x: 1.5711 loss_x_train_y: 2.5839 loss_val: 3.8417 loss_x_val_x: 1.5038 loss_x_val_y: 2.3379 time: 0.0639s
#  Epoch: 0004 loss_train: 4.1399 loss_x_train_x: 1.5659 loss_x_train_y: 2.5721 loss_val: 3.8516 loss_x_val_x: 1.5080 loss_x_val_y: 2.3435 time: 0.0960s
#  Epoch: 0005 loss_train: 4.1113 loss_x_train_x: 1.5507 loss_x_train_y: 2.5587 loss_val: 3.8538 loss_x_val_x: 1.5102 loss_x_val_y: 2.3436 time: 0.0743s
#  Epoch: 0006 loss_train: 4.0851 loss_x_train_x: 1.5430 loss_x_train_y: 2.5402 loss_val: 3.8483 loss_x_val_x: 1.5095 loss_x_val_y: 2.3388 time: 0.0587s
#  Epoch: 0007 loss_train: 4.0609 loss_x_train_x: 1.5317 loss_x_train_y: 2.5273 loss_val: 3.8354 loss_x_val_x: 1.5046 loss_x_val_y: 2.3307 time: 0.0607s
#  Epoch: 0008 loss_train: 4.0390 loss_x_train_x: 1.5221 loss_x_train_y: 2.5150 loss_val: 3.8168 loss_x_val_x: 1.4968 loss_x_val_y: 2.3200 time: 0.0611s
#  Epoch: 0009 loss_train: 4.0171 loss_x_train_x: 1.5143 loss_x_train_y: 2.5010 loss_val: 3.8008 loss_x_val_x: 1.4911 loss_x_val_y: 2.3097 time: 0.0624s
#  Epoch: 0010 loss_train: 3.9928 loss_x_train_x: 1.5043 loss_x_train_y: 2.4866 loss_val: 3.7831 loss_x_val_x: 1.4849 loss_x_val_y: 2.2983 time: 0.0660s
#  Epoch: 0011 loss_train: 3.9691 loss_x_train_x: 1.4946 loss_x_train_y: 2.4726 loss_val: 3.7658 loss_x_val_x: 1.4779 loss_x_val_y: 2.2879 time: 0.0638s
#  Epoch: 0012 loss_train: 3.9464 loss_x_train_x: 1.4874 loss_x_train_y: 2.4571 loss_val: 3.7476 loss_x_val_x: 1.4715 loss_x_val_y: 2.2762 time: 0.0769s
#  Epoch: 0013 loss_train: 3.9198 loss_x_train_x: 1.4730 loss_x_train_y: 2.4450 loss_val: 3.7321 loss_x_val_x: 1.4653 loss_x_val_y: 2.2668 time: 0.0710s
#  Epoch: 0014 loss_train: 3.9000 loss_x_train_x: 1.4656 loss_x_train_y: 2.4325 loss_val: 3.7086 loss_x_val_x: 1.4561 loss_x_val_y: 2.2524 time: 0.0754s
#  Epoch: 0015 loss_train: 3.8796 loss_x_train_x: 1.4568 loss_x_train_y: 2.4208 loss_val: 3.6909 loss_x_val_x: 1.4486 loss_x_val_y: 2.2423 time: 0.0752s
#  Epoch: 0016 loss_train: 3.8567 loss_x_train_x: 1.4486 loss_x_train_y: 2.4063 loss_val: 3.6713 loss_x_val_x: 1.4409 loss_x_val_y: 2.2304 time: 0.0896s
#  Epoch: 0017 loss_train: 3.8330 loss_x_train_x: 1.4409 loss_x_train_y: 2.3903 loss_val: 3.6527 loss_x_val_x: 1.4346 loss_x_val_y: 2.2181 time: 0.0696s
#  Epoch: 0018 loss_train: 3.8202 loss_x_train_x: 1.4334 loss_x_train_y: 2.3849 loss_val: 3.6358 loss_x_val_x: 1.4270 loss_x_val_y: 2.2088 time: 0.0740s
#  Epoch: 0019 loss_train: 3.7929 loss_x_train_x: 1.4211 loss_x_train_y: 2.3699 loss_val: 3.6182 loss_x_val_x: 1.4200 loss_x_val_y: 2.1982 time: 0.0740s
#  Epoch: 0020 loss_train: 3.7757 loss_x_train_x: 1.4175 loss_x_train_y: 2.3563 loss_val: 3.5996 loss_x_val_x: 1.4115 loss_x_val_y: 2.1881 time: 0.0693s
#  Epoch: 0021 loss_train: 3.7521 loss_x_train_x: 1.4062 loss_x_train_y: 2.3440 loss_val: 3.5827 loss_x_val_x: 1.4055 loss_x_val_y: 2.1772 time: 0.0699s
#  Epoch: 0022 loss_train: 3.7342 loss_x_train_x: 1.3995 loss_x_train_y: 2.3328 loss_val: 3.5654 loss_x_val_x: 1.3989 loss_x_val_y: 2.1665 time: 0.0680s
#  Epoch: 0023 loss_train: 3.7140 loss_x_train_x: 1.3890 loss_x_train_y: 2.3231 loss_val: 3.5471 loss_x_val_x: 1.3906 loss_x_val_y: 2.1565 time: 0.0676s
#  Epoch: 0024 loss_train: 3.6902 loss_x_train_x: 1.3801 loss_x_train_y: 2.3083 loss_val: 3.5308 loss_x_val_x: 1.3836 loss_x_val_y: 2.1472 time: 0.0873s
#  Epoch: 0025 loss_train: 3.6710 loss_x_train_x: 1.3733 loss_x_train_y: 2.2958 loss_val: 3.5100 loss_x_val_x: 1.3749 loss_x_val_y: 2.1351 time: 0.0815s
#  Epoch: 0026 loss_train: 3.6532 loss_x_train_x: 1.3633 loss_x_train_y: 2.2880 loss_val: 3.4930 loss_x_val_x: 1.3679 loss_x_val_y: 2.1251 time: 0.0786s
#  Epoch: 0027 loss_train: 3.6357 loss_x_train_x: 1.3594 loss_x_train_y: 2.2744 loss_val: 3.4744 loss_x_val_x: 1.3622 loss_x_val_y: 2.1122 time: 0.0702s
#  Epoch: 0028 loss_train: 3.6150 loss_x_train_x: 1.3504 loss_x_train_y: 2.2627 loss_val: 3.4607 loss_x_val_x: 1.3556 loss_x_val_y: 2.1050 time: 0.0728s
#  Epoch: 0029 loss_train: 3.5942 loss_x_train_x: 1.3433 loss_x_train_y: 2.2490 loss_val: 3.4443 loss_x_val_x: 1.3494 loss_x_val_y: 2.0949 time: 0.0761s
#  Epoch: 0030 loss_train: 3.5762 loss_x_train_x: 1.3332 loss_x_train_y: 2.2411 loss_val: 3.4278 loss_x_val_x: 1.3418 loss_x_val_y: 2.0859 time: 0.0796s
#  Epoch: 0031 loss_train: 3.5575 loss_x_train_x: 1.3263 loss_x_train_y: 2.2294 loss_val: 3.4114 loss_x_val_x: 1.3352 loss_x_val_y: 2.0762 time: 0.0827s
#  Epoch: 0032 loss_train: 3.5352 loss_x_train_x: 1.3158 loss_x_train_y: 2.2174 loss_val: 3.3941 loss_x_val_x: 1.3277 loss_x_val_y: 2.0665 time: 0.0721s
#  Epoch: 0033 loss_train: 3.5193 loss_x_train_x: 1.3109 loss_x_train_y: 2.2065 loss_val: 3.3799 loss_x_val_x: 1.3213 loss_x_val_y: 2.0585 time: 0.0717s
#  Epoch: 0034 loss_train: 3.5011 loss_x_train_x: 1.3046 loss_x_train_y: 2.1946 loss_val: 3.3640 loss_x_val_x: 1.3144 loss_x_val_y: 2.0496 time: 0.0717s
#  Epoch: 0035 loss_train: 3.4841 loss_x_train_x: 1.2975 loss_x_train_y: 2.1848 loss_val: 3.3468 loss_x_val_x: 1.3077 loss_x_val_y: 2.0392 time: 0.0737s
#  Epoch: 0036 loss_train: 3.4655 loss_x_train_x: 1.2891 loss_x_train_y: 2.1745 loss_val: 3.3287 loss_x_val_x: 1.3013 loss_x_val_y: 2.0274 time: 0.0689s
#  Epoch: 0037 loss_train: 3.4492 loss_x_train_x: 1.2854 loss_x_train_y: 2.1620 loss_val: 3.3125 loss_x_val_x: 1.2950 loss_x_val_y: 2.0175 time: 0.0715s
#  Epoch: 0038 loss_train: 3.4255 loss_x_train_x: 1.2723 loss_x_train_y: 2.1514 loss_val: 3.2916 loss_x_val_x: 1.2870 loss_x_val_y: 2.0046 time: 0.0695s
#  Epoch: 0039 loss_train: 3.4087 loss_x_train_x: 1.2678 loss_x_train_y: 2.1390 loss_val: 3.2734 loss_x_val_x: 1.2783 loss_x_val_y: 1.9951 time: 0.0659s
#  Epoch: 0040 loss_train: 3.3895 loss_x_train_x: 1.2590 loss_x_train_y: 2.1287 loss_val: 3.2599 loss_x_val_x: 1.2743 loss_x_val_y: 1.9856 time: 0.0572s
#  Epoch: 0041 loss_train: 3.3685 loss_x_train_x: 1.2467 loss_x_train_y: 2.1199 loss_val: 3.2430 loss_x_val_x: 1.2674 loss_x_val_y: 1.9756 time: 0.0558s
#  Epoch: 0042 loss_train: 3.3581 loss_x_train_x: 1.2478 loss_x_train_y: 2.1084 loss_val: 3.2297 loss_x_val_x: 1.2608 loss_x_val_y: 1.9689 time: 0.0566s
#  Epoch: 0043 loss_train: 3.3309 loss_x_train_x: 1.2372 loss_x_train_y: 2.0919 loss_val: 3.2106 loss_x_val_x: 1.2545 loss_x_val_y: 1.9561 time: 0.0565s
#  Epoch: 0044 loss_train: 3.3165 loss_x_train_x: 1.2287 loss_x_train_y: 2.0859 loss_val: 3.1964 loss_x_val_x: 1.2479 loss_x_val_y: 1.9485 time: 0.0560s
#  Epoch: 0045 loss_train: 3.3007 loss_x_train_x: 1.2235 loss_x_train_y: 2.0753 loss_val: 3.1817 loss_x_val_x: 1.2402 loss_x_val_y: 1.9414 time: 0.0560s
#  Epoch: 0046 loss_train: 3.2830 loss_x_train_x: 1.2152 loss_x_train_y: 2.0659 loss_val: 3.1586 loss_x_val_x: 1.2325 loss_x_val_y: 1.9261 time: 0.0558s
#  Epoch: 0047 loss_train: 3.2657 loss_x_train_x: 1.2113 loss_x_train_y: 2.0525 loss_val: 3.1426 loss_x_val_x: 1.2248 loss_x_val_y: 1.9178 time: 0.0569s
#  Epoch: 0048 loss_train: 3.2541 loss_x_train_x: 1.2035 loss_x_train_y: 2.0488 loss_val: 3.1280 loss_x_val_x: 1.2182 loss_x_val_y: 1.9098 time: 0.0554s
#  Epoch: 0049 loss_train: 3.2338 loss_x_train_x: 1.1979 loss_x_train_y: 2.0340 loss_val: 3.1087 loss_x_val_x: 1.2099 loss_x_val_y: 1.8988 time: 0.0554s
#  Epoch: 0050 loss_train: 3.2215 loss_x_train_x: 1.1937 loss_x_train_y: 2.0259 loss_val: 3.0956 loss_x_val_x: 1.2054 loss_x_val_y: 1.8902 time: 0.0556s
#  Epoch: 0051 loss_train: 3.1971 loss_x_train_x: 1.1860 loss_x_train_y: 2.0092 loss_val: 3.0773 loss_x_val_x: 1.1982 loss_x_val_y: 1.8791 time: 0.0592s
#  Epoch: 0052 loss_train: 3.1795 loss_x_train_x: 1.1725 loss_x_train_y: 2.0051 loss_val: 3.0590 loss_x_val_x: 1.1927 loss_x_val_y: 1.8663 time: 0.0541s
#  Epoch: 0053 loss_train: 3.1673 loss_x_train_x: 1.1720 loss_x_train_y: 1.9934 loss_val: 3.0397 loss_x_val_x: 1.1859 loss_x_val_y: 1.8538 time: 0.0545s
#  Epoch: 0054 loss_train: 3.1534 loss_x_train_x: 1.1687 loss_x_train_y: 1.9829 loss_val: 3.0246 loss_x_val_x: 1.1782 loss_x_val_y: 1.8463 time: 0.0545s
#  Epoch: 0055 loss_train: 3.1308 loss_x_train_x: 1.1560 loss_x_train_y: 1.9730 loss_val: 3.0081 loss_x_val_x: 1.1707 loss_x_val_y: 1.8374 time: 0.0580s
#  Epoch: 0056 loss_train: 3.1138 loss_x_train_x: 1.1531 loss_x_train_y: 1.9588 loss_val: 2.9927 loss_x_val_x: 1.1647 loss_x_val_y: 1.8280 time: 0.0716s
#  Epoch: 0057 loss_train: 3.0985 loss_x_train_x: 1.1437 loss_x_train_y: 1.9530 loss_val: 2.9765 loss_x_val_x: 1.1575 loss_x_val_y: 1.8190 time: 0.0688s
#  Epoch: 0058 loss_train: 3.0762 loss_x_train_x: 1.1347 loss_x_train_y: 1.9396 loss_val: 2.9624 loss_x_val_x: 1.1512 loss_x_val_y: 1.8112 time: 0.0731s
#  Epoch: 0059 loss_train: 3.0650 loss_x_train_x: 1.1313 loss_x_train_y: 1.9319 loss_val: 2.9499 loss_x_val_x: 1.1467 loss_x_val_y: 1.8032 time: 0.1096s
#  Epoch: 0060 loss_train: 3.0482 loss_x_train_x: 1.1279 loss_x_train_y: 1.9184 loss_val: 2.9298 loss_x_val_x: 1.1401 loss_x_val_y: 1.7897 time: 0.0640s
#  Epoch: 0061 loss_train: 3.0316 loss_x_train_x: 1.1166 loss_x_train_y: 1.9131 loss_val: 2.9144 loss_x_val_x: 1.1334 loss_x_val_y: 1.7810 time: 0.0671s
#  Epoch: 0062 loss_train: 3.0154 loss_x_train_x: 1.1113 loss_x_train_y: 1.9022 loss_val: 2.8948 loss_x_val_x: 1.1243 loss_x_val_y: 1.7705 time: 0.0645s
#  Epoch: 0063 loss_train: 3.0002 loss_x_train_x: 1.1087 loss_x_train_y: 1.8896 loss_val: 2.8804 loss_x_val_x: 1.1189 loss_x_val_y: 1.7615 time: 0.0603s
#  Epoch: 0064 loss_train: 2.9865 loss_x_train_x: 1.1059 loss_x_train_y: 1.8787 loss_val: 2.8673 loss_x_val_x: 1.1140 loss_x_val_y: 1.7534 time: 0.0602s
#  Epoch: 0065 loss_train: 2.9612 loss_x_train_x: 1.0922 loss_x_train_y: 1.8672 loss_val: 2.8469 loss_x_val_x: 1.1077 loss_x_val_y: 1.7392 time: 0.0615s
#  Epoch: 0066 loss_train: 2.9503 loss_x_train_x: 1.0853 loss_x_train_y: 1.8631 loss_val: 2.8316 loss_x_val_x: 1.1012 loss_x_val_y: 1.7304 time: 0.0604s
#  Epoch: 0067 loss_train: 2.9350 loss_x_train_x: 1.0810 loss_x_train_y: 1.8521 loss_val: 2.8180 loss_x_val_x: 1.0960 loss_x_val_y: 1.7220 time: 0.0602s
#  Epoch: 0068 loss_train: 2.9180 loss_x_train_x: 1.0738 loss_x_train_y: 1.8423 loss_val: 2.8059 loss_x_val_x: 1.0908 loss_x_val_y: 1.7151 time: 0.0601s
#  Epoch: 0069 loss_train: 2.9080 loss_x_train_x: 1.0684 loss_x_train_y: 1.8377 loss_val: 2.7912 loss_x_val_x: 1.0853 loss_x_val_y: 1.7059 time: 0.0600s
#  Epoch: 0070 loss_train: 2.8824 loss_x_train_x: 1.0630 loss_x_train_y: 1.8175 loss_val: 2.7782 loss_x_val_x: 1.0792 loss_x_val_y: 1.6991 time: 0.0605s
#  Epoch: 0071 loss_train: 2.8737 loss_x_train_x: 1.0573 loss_x_train_y: 1.8144 loss_val: 2.7540 loss_x_val_x: 1.0705 loss_x_val_y: 1.6835 time: 0.0598s
#  Epoch: 0072 loss_train: 2.8493 loss_x_train_x: 1.0493 loss_x_train_y: 1.7982 loss_val: 2.7391 loss_x_val_x: 1.0656 loss_x_val_y: 1.6735 time: 0.0601s
#  Epoch: 0073 loss_train: 2.8398 loss_x_train_x: 1.0445 loss_x_train_y: 1.7934 loss_val: 2.7232 loss_x_val_x: 1.0579 loss_x_val_y: 1.6652 time: 0.0607s
#  Epoch: 0074 loss_train: 2.8279 loss_x_train_x: 1.0402 loss_x_train_y: 1.7858 loss_val: 2.7085 loss_x_val_x: 1.0537 loss_x_val_y: 1.6548 time: 0.0603s
#  Epoch: 0075 loss_train: 2.8148 loss_x_train_x: 1.0376 loss_x_train_y: 1.7753 loss_val: 2.6941 loss_x_val_x: 1.0485 loss_x_val_y: 1.6457 time: 0.0670s
#  Epoch: 0076 loss_train: 2.7947 loss_x_train_x: 1.0270 loss_x_train_y: 1.7658 loss_val: 2.6756 loss_x_val_x: 1.0410 loss_x_val_y: 1.6346 time: 0.0621s
#  Epoch: 0077 loss_train: 2.7775 loss_x_train_x: 1.0209 loss_x_train_y: 1.7547 loss_val: 2.6591 loss_x_val_x: 1.0345 loss_x_val_y: 1.6246 time: 0.0614s
#  Epoch: 0078 loss_train: 2.7566 loss_x_train_x: 1.0165 loss_x_train_y: 1.7382 loss_val: 2.6427 loss_x_val_x: 1.0278 loss_x_val_y: 1.6148 time: 0.0741s
#  Epoch: 0079 loss_train: 2.7447 loss_x_train_x: 1.0100 loss_x_train_y: 1.7328 loss_val: 2.6305 loss_x_val_x: 1.0218 loss_x_val_y: 1.6087 time: 0.0638s
#  Epoch: 0080 loss_train: 2.7351 loss_x_train_x: 1.0046 loss_x_train_y: 1.7286 loss_val: 2.6130 loss_x_val_x: 1.0162 loss_x_val_y: 1.5968 time: 0.0638s
#  Epoch: 0081 loss_train: 2.7202 loss_x_train_x: 1.0048 loss_x_train_y: 1.7135 loss_val: 2.6092 loss_x_val_x: 1.0140 loss_x_val_y: 1.5951 time: 0.0671s
#  Epoch: 0082 loss_train: 2.7065 loss_x_train_x: 0.9969 loss_x_train_y: 1.7076 loss_val: 2.5889 loss_x_val_x: 1.0079 loss_x_val_y: 1.5810 time: 0.0655s
#  Epoch: 0083 loss_train: 2.6810 loss_x_train_x: 0.9853 loss_x_train_y: 1.6938 loss_val: 2.5735 loss_x_val_x: 1.0021 loss_x_val_y: 1.5713 time: 0.0696s
#  Epoch: 0084 loss_train: 2.6720 loss_x_train_x: 0.9821 loss_x_train_y: 1.6880 loss_val: 2.5612 loss_x_val_x: 0.9951 loss_x_val_y: 1.5661 time: 0.0751s
#  Epoch: 0085 loss_train: 2.6565 loss_x_train_x: 0.9766 loss_x_train_y: 1.6781 loss_val: 2.5459 loss_x_val_x: 0.9875 loss_x_val_y: 1.5584 time: 0.0593s
#  Epoch: 0086 loss_train: 2.6417 loss_x_train_x: 0.9764 loss_x_train_y: 1.6635 loss_val: 2.5285 loss_x_val_x: 0.9818 loss_x_val_y: 1.5467 time: 0.0630s
#  Epoch: 0087 loss_train: 2.6261 loss_x_train_x: 0.9717 loss_x_train_y: 1.6526 loss_val: 2.5120 loss_x_val_x: 0.9770 loss_x_val_y: 1.5351 time: 0.0603s
#  Epoch: 0088 loss_train: 2.6152 loss_x_train_x: 0.9648 loss_x_train_y: 1.6485 loss_val: 2.4999 loss_x_val_x: 0.9727 loss_x_val_y: 1.5272 time: 0.0603s
#  Epoch: 0089 loss_train: 2.6046 loss_x_train_x: 0.9593 loss_x_train_y: 1.6434 loss_val: 2.4885 loss_x_val_x: 0.9651 loss_x_val_y: 1.5234 time: 0.0638s
#  Epoch: 0090 loss_train: 2.5815 loss_x_train_x: 0.9524 loss_x_train_y: 1.6272 loss_val: 2.4701 loss_x_val_x: 0.9611 loss_x_val_y: 1.5090 time: 0.0640s
#  Epoch: 0091 loss_train: 2.5710 loss_x_train_x: 0.9502 loss_x_train_y: 1.6190 loss_val: 2.4564 loss_x_val_x: 0.9559 loss_x_val_y: 1.5005 time: 0.0594s
#  Epoch: 0092 loss_train: 2.5539 loss_x_train_x: 0.9438 loss_x_train_y: 1.6082 loss_val: 2.4451 loss_x_val_x: 0.9493 loss_x_val_y: 1.4958 time: 0.0595s
#  Epoch: 0093 loss_train: 2.5254 loss_x_train_x: 0.9314 loss_x_train_y: 1.5921 loss_val: 2.4269 loss_x_val_x: 0.9458 loss_x_val_y: 1.4811 time: 0.0599s
#  Epoch: 0094 loss_train: 2.5206 loss_x_train_x: 0.9314 loss_x_train_y: 1.5873 loss_val: 2.4214 loss_x_val_x: 0.9413 loss_x_val_y: 1.4801 time: 0.0595s
#  Epoch: 0095 loss_train: 2.5063 loss_x_train_x: 0.9257 loss_x_train_y: 1.5787 loss_val: 2.4056 loss_x_val_x: 0.9340 loss_x_val_y: 1.4716 time: 0.0595s
#  Epoch: 0096 loss_train: 2.4964 loss_x_train_x: 0.9227 loss_x_train_y: 1.5718 loss_val: 2.3893 loss_x_val_x: 0.9306 loss_x_val_y: 1.4588 time: 0.0603s
#  Epoch: 0097 loss_train: 2.4898 loss_x_train_x: 0.9171 loss_x_train_y: 1.5708 loss_val: 2.3771 loss_x_val_x: 0.9255 loss_x_val_y: 1.4516 time: 0.0599s
#  Epoch: 0098 loss_train: 2.4689 loss_x_train_x: 0.9116 loss_x_train_y: 1.5554 loss_val: 2.3656 loss_x_val_x: 0.9220 loss_x_val_y: 1.4436 time: 0.0599s
#  Epoch: 0099 loss_train: 2.4493 loss_x_train_x: 0.9007 loss_x_train_y: 1.5467 loss_val: 2.3524 loss_x_val_x: 0.9186 loss_x_val_y: 1.4338 time: 0.0598s
#  Epoch: 0100 loss_train: 2.4354 loss_x_train_x: 0.9062 loss_x_train_y: 1.5274 loss_val: 2.3409 loss_x_val_x: 0.9122 loss_x_val_y: 1.4288 time: 0.0606s
#  Epoch: 0101 loss_train: 2.4379 loss_x_train_x: 0.9012 loss_x_train_y: 1.5348 loss_val: 2.3271 loss_x_val_x: 0.9075 loss_x_val_y: 1.4196 time: 0.0601s
#  Epoch: 0102 loss_train: 2.4097 loss_x_train_x: 0.8924 loss_x_train_y: 1.5154 loss_val: 2.3142 loss_x_val_x: 0.9022 loss_x_val_y: 1.4120 time: 0.0604s
#  Epoch: 0103 loss_train: 2.4006 loss_x_train_x: 0.8902 loss_x_train_y: 1.5085 loss_val: 2.2956 loss_x_val_x: 0.8972 loss_x_val_y: 1.3984 time: 0.0596s
#  Epoch: 0104 loss_train: 2.3862 loss_x_train_x: 0.8900 loss_x_train_y: 1.4944 loss_val: 2.2841 loss_x_val_x: 0.8913 loss_x_val_y: 1.3927 time: 0.0600s
#  Epoch: 0105 loss_train: 2.3736 loss_x_train_x: 0.8809 loss_x_train_y: 1.4908 loss_val: 2.2740 loss_x_val_x: 0.8884 loss_x_val_y: 1.3856 time: 0.0593s
#  Epoch: 0106 loss_train: 2.3617 loss_x_train_x: 0.8738 loss_x_train_y: 1.4860 loss_val: 2.2588 loss_x_val_x: 0.8835 loss_x_val_y: 1.3754 time: 0.0655s
#  Epoch: 0107 loss_train: 2.3459 loss_x_train_x: 0.8684 loss_x_train_y: 1.4756 loss_val: 2.2470 loss_x_val_x: 0.8796 loss_x_val_y: 1.3674 time: 0.0607s
#  Epoch: 0108 loss_train: 2.3443 loss_x_train_x: 0.8707 loss_x_train_y: 1.4717 loss_val: 2.2420 loss_x_val_x: 0.8772 loss_x_val_y: 1.3648 time: 0.0611s
#  Epoch: 0109 loss_train: 2.3171 loss_x_train_x: 0.8643 loss_x_train_y: 1.4508 loss_val: 2.2258 loss_x_val_x: 0.8717 loss_x_val_y: 1.3541 time: 0.0595s
#  Epoch: 0110 loss_train: 2.3144 loss_x_train_x: 0.8639 loss_x_train_y: 1.4487 loss_val: 2.2149 loss_x_val_x: 0.8697 loss_x_val_y: 1.3452 time: 0.0596s
#  Epoch: 0111 loss_train: 2.2912 loss_x_train_x: 0.8551 loss_x_train_y: 1.4342 loss_val: 2.2027 loss_x_val_x: 0.8655 loss_x_val_y: 1.3371 time: 0.0604s
#  Epoch: 0112 loss_train: 2.2828 loss_x_train_x: 0.8490 loss_x_train_y: 1.4319 loss_val: 2.1878 loss_x_val_x: 0.8607 loss_x_val_y: 1.3272 time: 0.0548s
#  Epoch: 0113 loss_train: 2.2753 loss_x_train_x: 0.8468 loss_x_train_y: 1.4267 loss_val: 2.1746 loss_x_val_x: 0.8541 loss_x_val_y: 1.3205 time: 0.0519s
#  Epoch: 0114 loss_train: 2.2637 loss_x_train_x: 0.8459 loss_x_train_y: 1.4159 loss_val: 2.1649 loss_x_val_x: 0.8507 loss_x_val_y: 1.3142 time: 0.0664s
#  Epoch: 0115 loss_train: 2.2443 loss_x_train_x: 0.8391 loss_x_train_y: 1.4033 loss_val: 2.1576 loss_x_val_x: 0.8462 loss_x_val_y: 1.3114 time: 0.0593s
#  Epoch: 0116 loss_train: 2.2284 loss_x_train_x: 0.8317 loss_x_train_y: 1.3948 loss_val: 2.1434 loss_x_val_x: 0.8395 loss_x_val_y: 1.3038 time: 0.0593s
#  Epoch: 0117 loss_train: 2.2239 loss_x_train_x: 0.8323 loss_x_train_y: 1.3897 loss_val: 2.1322 loss_x_val_x: 0.8375 loss_x_val_y: 1.2947 time: 0.0592s
#  Epoch: 0118 loss_train: 2.2148 loss_x_train_x: 0.8301 loss_x_train_y: 1.3828 loss_val: 2.1195 loss_x_val_x: 0.8338 loss_x_val_y: 1.2857 time: 0.0596s
#  Epoch: 0119 loss_train: 2.2035 loss_x_train_x: 0.8215 loss_x_train_y: 1.3801 loss_val: 2.1096 loss_x_val_x: 0.8305 loss_x_val_y: 1.2791 time: 0.0607s
#  Epoch: 0120 loss_train: 2.1824 loss_x_train_x: 0.8168 loss_x_train_y: 1.3637 loss_val: 2.0957 loss_x_val_x: 0.8253 loss_x_val_y: 1.2704 time: 0.0597s
#  Epoch: 0121 loss_train: 2.1708 loss_x_train_x: 0.8154 loss_x_train_y: 1.3534 loss_val: 2.0828 loss_x_val_x: 0.8215 loss_x_val_y: 1.2613 time: 0.0591s
#  Epoch: 0122 loss_train: 2.1617 loss_x_train_x: 0.8167 loss_x_train_y: 1.3431 loss_val: 2.0726 loss_x_val_x: 0.8198 loss_x_val_y: 1.2528 time: 0.0599s
#  Epoch: 0123 loss_train: 2.1538 loss_x_train_x: 0.8078 loss_x_train_y: 1.3441 loss_val: 2.0630 loss_x_val_x: 0.8186 loss_x_val_y: 1.2445 time: 0.0603s
#  Epoch: 0124 loss_train: 2.1384 loss_x_train_x: 0.8038 loss_x_train_y: 1.3327 loss_val: 2.0528 loss_x_val_x: 0.8135 loss_x_val_y: 1.2392 time: 0.0596s
#  Epoch: 0125 loss_train: 2.1232 loss_x_train_x: 0.7972 loss_x_train_y: 1.3241 loss_val: 2.0423 loss_x_val_x: 0.8100 loss_x_val_y: 1.2324 time: 0.0591s
#  Epoch: 0126 loss_train: 2.1184 loss_x_train_x: 0.7968 loss_x_train_y: 1.3198 loss_val: 2.0304 loss_x_val_x: 0.8048 loss_x_val_y: 1.2256 time: 0.0599s
#  Epoch: 0127 loss_train: 2.1065 loss_x_train_x: 0.7961 loss_x_train_y: 1.3086 loss_val: 2.0194 loss_x_val_x: 0.8041 loss_x_val_y: 1.2152 time: 0.0596s
#  Epoch: 0128 loss_train: 2.0908 loss_x_train_x: 0.7934 loss_x_train_y: 1.2955 loss_val: 2.0068 loss_x_val_x: 0.8002 loss_x_val_y: 1.2067 time: 0.0596s
#  Epoch: 0129 loss_train: 2.0847 loss_x_train_x: 0.7867 loss_x_train_y: 1.2961 loss_val: 1.9926 loss_x_val_x: 0.7947 loss_x_val_y: 1.1979 time: 0.0597s
#  Epoch: 0130 loss_train: 2.0641 loss_x_train_x: 0.7843 loss_x_train_y: 1.2780 loss_val: 1.9846 loss_x_val_x: 0.7930 loss_x_val_y: 1.1916 time: 0.0596s
#  Epoch: 0131 loss_train: 2.0534 loss_x_train_x: 0.7806 loss_x_train_y: 1.2709 loss_val: 1.9759 loss_x_val_x: 0.7874 loss_x_val_y: 1.1885 time: 0.0597s
#  Epoch: 0132 loss_train: 2.0488 loss_x_train_x: 0.7702 loss_x_train_y: 1.2767 loss_val: 1.9719 loss_x_val_x: 0.7858 loss_x_val_y: 1.1861 time: 0.0594s
#  Epoch: 0133 loss_train: 2.0344 loss_x_train_x: 0.7753 loss_x_train_y: 1.2572 loss_val: 1.9592 loss_x_val_x: 0.7837 loss_x_val_y: 1.1755 time: 0.0598s
#  Epoch: 0134 loss_train: 2.0241 loss_x_train_x: 0.7666 loss_x_train_y: 1.2556 loss_val: 1.9477 loss_x_val_x: 0.7799 loss_x_val_y: 1.1677 time: 0.0597s
#  Epoch: 0135 loss_train: 2.0156 loss_x_train_x: 0.7651 loss_x_train_y: 1.2486 loss_val: 1.9365 loss_x_val_x: 0.7736 loss_x_val_y: 1.1628 time: 0.0600s
#  Epoch: 0136 loss_train: 2.0018 loss_x_train_x: 0.7629 loss_x_train_y: 1.2369 loss_val: 1.9256 loss_x_val_x: 0.7736 loss_x_val_y: 1.1520 time: 0.0593s
#  Epoch: 0137 loss_train: 1.9853 loss_x_train_x: 0.7604 loss_x_train_y: 1.2230 loss_val: 1.9138 loss_x_val_x: 0.7691 loss_x_val_y: 1.1447 time: 0.0593s
#  Epoch: 0138 loss_train: 1.9786 loss_x_train_x: 0.7572 loss_x_train_y: 1.2195 loss_val: 1.9006 loss_x_val_x: 0.7662 loss_x_val_y: 1.1344 time: 0.0595s
#  Epoch: 0139 loss_train: 1.9664 loss_x_train_x: 0.7526 loss_x_train_y: 1.2119 loss_val: 1.8908 loss_x_val_x: 0.7618 loss_x_val_y: 1.1290 time: 0.0599s
#  Epoch: 0140 loss_train: 1.9676 loss_x_train_x: 0.7513 loss_x_train_y: 1.2144 loss_val: 1.8854 loss_x_val_x: 0.7637 loss_x_val_y: 1.1217 time: 0.0575s
#  Epoch: 0141 loss_train: 1.9536 loss_x_train_x: 0.7502 loss_x_train_y: 1.2015 loss_val: 1.8815 loss_x_val_x: 0.7601 loss_x_val_y: 1.1215 time: 0.0595s
#  Epoch: 0142 loss_train: 1.9486 loss_x_train_x: 0.7505 loss_x_train_y: 1.1962 loss_val: 1.8754 loss_x_val_x: 0.7560 loss_x_val_y: 1.1194 time: 0.0594s
#  Epoch: 0143 loss_train: 1.9318 loss_x_train_x: 0.7404 loss_x_train_y: 1.1895 loss_val: 1.8618 loss_x_val_x: 0.7534 loss_x_val_y: 1.1084 time: 0.0602s
#  Epoch: 0144 loss_train: 1.9274 loss_x_train_x: 0.7414 loss_x_train_y: 1.1841 loss_val: 1.8544 loss_x_val_x: 0.7513 loss_x_val_y: 1.1031 time: 0.0595s
#  Epoch: 0145 loss_train: 1.8957 loss_x_train_x: 0.7315 loss_x_train_y: 1.1623 loss_val: 1.8395 loss_x_val_x: 0.7478 loss_x_val_y: 1.0918 time: 0.0596s
#  Epoch: 0146 loss_train: 1.8984 loss_x_train_x: 0.7294 loss_x_train_y: 1.1670 loss_val: 1.8326 loss_x_val_x: 0.7447 loss_x_val_y: 1.0879 time: 0.0597s
#  Epoch: 0147 loss_train: 1.9024 loss_x_train_x: 0.7347 loss_x_train_y: 1.1658 loss_val: 1.8227 loss_x_val_x: 0.7395 loss_x_val_y: 1.0832 time: 0.0612s
#  Epoch: 0148 loss_train: 1.8909 loss_x_train_x: 0.7305 loss_x_train_y: 1.1584 loss_val: 1.8190 loss_x_val_x: 0.7393 loss_x_val_y: 1.0796 time: 0.0597s
#  Epoch: 0149 loss_train: 1.8683 loss_x_train_x: 0.7192 loss_x_train_y: 1.1472 loss_val: 1.8069 loss_x_val_x: 0.7378 loss_x_val_y: 1.0691 time: 0.0598s
#  Epoch: 0150 loss_train: 1.8565 loss_x_train_x: 0.7127 loss_x_train_y: 1.1418 loss_val: 1.8018 loss_x_val_x: 0.7338 loss_x_val_y: 1.0680 time: 0.0595s
#  Epoch: 0151 loss_train: 1.8557 loss_x_train_x: 0.7158 loss_x_train_y: 1.1380 loss_val: 1.7910 loss_x_val_x: 0.7311 loss_x_val_y: 1.0599 time: 0.0602s
#  Epoch: 0152 loss_train: 1.8474 loss_x_train_x: 0.7217 loss_x_train_y: 1.1239 loss_val: 1.7866 loss_x_val_x: 0.7306 loss_x_val_y: 1.0560 time: 0.0600s
#  Epoch: 0153 loss_train: 1.8399 loss_x_train_x: 0.7187 loss_x_train_y: 1.1193 loss_val: 1.7774 loss_x_val_x: 0.7276 loss_x_val_y: 1.0498 time: 0.0595s
#  Epoch: 0154 loss_train: 1.8232 loss_x_train_x: 0.7069 loss_x_train_y: 1.1144 loss_val: 1.7658 loss_x_val_x: 0.7248 loss_x_val_y: 1.0409 time: 0.0599s
#  Epoch: 0155 loss_train: 1.8251 loss_x_train_x: 0.7119 loss_x_train_y: 1.1113 loss_val: 1.7605 loss_x_val_x: 0.7240 loss_x_val_y: 1.0365 time: 0.0605s
#  Epoch: 0156 loss_train: 1.8075 loss_x_train_x: 0.7010 loss_x_train_y: 1.1046 loss_val: 1.7538 loss_x_val_x: 0.7219 loss_x_val_y: 1.0318 time: 0.0598s
#  Epoch: 0157 loss_train: 1.8054 loss_x_train_x: 0.7084 loss_x_train_y: 1.0951 loss_val: 1.7428 loss_x_val_x: 0.7187 loss_x_val_y: 1.0241 time: 0.0597s
#  Epoch: 0158 loss_train: 1.7925 loss_x_train_x: 0.7012 loss_x_train_y: 1.0894 loss_val: 1.7344 loss_x_val_x: 0.7166 loss_x_val_y: 1.0178 time: 0.0601s
#  Epoch: 0159 loss_train: 1.7883 loss_x_train_x: 0.7003 loss_x_train_y: 1.0861 loss_val: 1.7257 loss_x_val_x: 0.7115 loss_x_val_y: 1.0143 time: 0.0608s
#  Epoch: 0160 loss_train: 1.7739 loss_x_train_x: 0.6931 loss_x_train_y: 1.0788 loss_val: 1.7143 loss_x_val_x: 0.7096 loss_x_val_y: 1.0047 time: 0.0601s
#  Epoch: 0161 loss_train: 1.7759 loss_x_train_x: 0.7002 loss_x_train_y: 1.0737 loss_val: 1.7086 loss_x_val_x: 0.7095 loss_x_val_y: 0.9991 time: 0.0604s
#  Epoch: 0162 loss_train: 1.7559 loss_x_train_x: 0.6938 loss_x_train_y: 1.0602 loss_val: 1.6963 loss_x_val_x: 0.7059 loss_x_val_y: 0.9903 time: 0.0577s
#  Epoch: 0163 loss_train: 1.7496 loss_x_train_x: 0.6916 loss_x_train_y: 1.0561 loss_val: 1.6896 loss_x_val_x: 0.7057 loss_x_val_y: 0.9840 time: 0.0613s
#  Epoch: 0164 loss_train: 1.7441 loss_x_train_x: 0.6903 loss_x_train_y: 1.0520 loss_val: 1.6857 loss_x_val_x: 0.7034 loss_x_val_y: 0.9823 time: 0.0601s
#  Epoch: 0165 loss_train: 1.7345 loss_x_train_x: 0.6831 loss_x_train_y: 1.0495 loss_val: 1.6815 loss_x_val_x: 0.7012 loss_x_val_y: 0.9803 time: 0.0601s
#  Epoch: 0166 loss_train: 1.7268 loss_x_train_x: 0.6819 loss_x_train_y: 1.0430 loss_val: 1.6713 loss_x_val_x: 0.6979 loss_x_val_y: 0.9735 time: 0.0600s
#  Epoch: 0167 loss_train: 1.7279 loss_x_train_x: 0.6856 loss_x_train_y: 1.0403 loss_val: 1.6657 loss_x_val_x: 0.6970 loss_x_val_y: 0.9687 time: 0.0603s
#  Epoch: 0168 loss_train: 1.7116 loss_x_train_x: 0.6754 loss_x_train_y: 1.0343 loss_val: 1.6573 loss_x_val_x: 0.6957 loss_x_val_y: 0.9616 time: 0.0597s
#  Epoch: 0169 loss_train: 1.7093 loss_x_train_x: 0.6763 loss_x_train_y: 1.0311 loss_val: 1.6497 loss_x_val_x: 0.6932 loss_x_val_y: 0.9565 time: 0.0599s
#  Epoch: 0170 loss_train: 1.6930 loss_x_train_x: 0.6704 loss_x_train_y: 1.0206 loss_val: 1.6428 loss_x_val_x: 0.6913 loss_x_val_y: 0.9515 time: 0.0601s
#  Epoch: 0171 loss_train: 1.6939 loss_x_train_x: 0.6742 loss_x_train_y: 1.0178 loss_val: 1.6339 loss_x_val_x: 0.6882 loss_x_val_y: 0.9456 time: 0.0611s
#  Epoch: 0172 loss_train: 1.6725 loss_x_train_x: 0.6631 loss_x_train_y: 1.0075 loss_val: 1.6299 loss_x_val_x: 0.6864 loss_x_val_y: 0.9435 time: 0.0593s
#  Epoch: 0173 loss_train: 1.6694 loss_x_train_x: 0.6661 loss_x_train_y: 1.0014 loss_val: 1.6222 loss_x_val_x: 0.6855 loss_x_val_y: 0.9367 time: 0.0757s
#  Epoch: 0174 loss_train: 1.6568 loss_x_train_x: 0.6674 loss_x_train_y: 0.9875 loss_val: 1.6177 loss_x_val_x: 0.6840 loss_x_val_y: 0.9338 time: 0.0596s
#  Epoch: 0175 loss_train: 1.6691 loss_x_train_x: 0.6686 loss_x_train_y: 0.9986 loss_val: 1.6136 loss_x_val_x: 0.6815 loss_x_val_y: 0.9322 time: 0.0602s
#  Epoch: 0176 loss_train: 1.6559 loss_x_train_x: 0.6689 loss_x_train_y: 0.9851 loss_val: 1.6045 loss_x_val_x: 0.6801 loss_x_val_y: 0.9244 time: 0.0622s
#  Epoch: 0177 loss_train: 1.6430 loss_x_train_x: 0.6582 loss_x_train_y: 0.9829 loss_val: 1.5996 loss_x_val_x: 0.6789 loss_x_val_y: 0.9207 time: 0.0592s
#  Epoch: 0178 loss_train: 1.6393 loss_x_train_x: 0.6593 loss_x_train_y: 0.9780 loss_val: 1.5937 loss_x_val_x: 0.6790 loss_x_val_y: 0.9147 time: 0.0596s
#  Epoch: 0179 loss_train: 1.6374 loss_x_train_x: 0.6577 loss_x_train_y: 0.9778 loss_val: 1.5888 loss_x_val_x: 0.6763 loss_x_val_y: 0.9125 time: 0.0607s
#  Epoch: 0180 loss_train: 1.6142 loss_x_train_x: 0.6579 loss_x_train_y: 0.9544 loss_val: 1.5787 loss_x_val_x: 0.6754 loss_x_val_y: 0.9033 time: 0.0617s
#  Epoch: 0181 loss_train: 1.6048 loss_x_train_x: 0.6483 loss_x_train_y: 0.9547 loss_val: 1.5734 loss_x_val_x: 0.6740 loss_x_val_y: 0.8994 time: 0.0597s
#  Epoch: 0182 loss_train: 1.6134 loss_x_train_x: 0.6532 loss_x_train_y: 0.9584 loss_val: 1.5676 loss_x_val_x: 0.6719 loss_x_val_y: 0.8958 time: 0.0594s
#  Epoch: 0183 loss_train: 1.6038 loss_x_train_x: 0.6506 loss_x_train_y: 0.9513 loss_val: 1.5623 loss_x_val_x: 0.6704 loss_x_val_y: 0.8919 time: 0.0602s
#  Epoch: 0184 loss_train: 1.5939 loss_x_train_x: 0.6494 loss_x_train_y: 0.9426 loss_val: 1.5544 loss_x_val_x: 0.6672 loss_x_val_y: 0.8872 time: 0.0593s
#  Epoch: 0185 loss_train: 1.5869 loss_x_train_x: 0.6421 loss_x_train_y: 0.9429 loss_val: 1.5502 loss_x_val_x: 0.6667 loss_x_val_y: 0.8835 time: 0.0595s
#  Epoch: 0186 loss_train: 1.5817 loss_x_train_x: 0.6470 loss_x_train_y: 0.9328 loss_val: 1.5440 loss_x_val_x: 0.6643 loss_x_val_y: 0.8797 time: 0.0594s
#  Epoch: 0187 loss_train: 1.5798 loss_x_train_x: 0.6415 loss_x_train_y: 0.9363 loss_val: 1.5399 loss_x_val_x: 0.6634 loss_x_val_y: 0.8765 time: 0.0601s
#  Epoch: 0188 loss_train: 1.5786 loss_x_train_x: 0.6447 loss_x_train_y: 0.9319 loss_val: 1.5364 loss_x_val_x: 0.6633 loss_x_val_y: 0.8731 time: 0.0594s
#  Epoch: 0189 loss_train: 1.5679 loss_x_train_x: 0.6434 loss_x_train_y: 0.9225 loss_val: 1.5286 loss_x_val_x: 0.6606 loss_x_val_y: 0.8680 time: 0.0595s
#  Epoch: 0190 loss_train: 1.5601 loss_x_train_x: 0.6397 loss_x_train_y: 0.9184 loss_val: 1.5219 loss_x_val_x: 0.6584 loss_x_val_y: 0.8635 time: 0.0596s
#  Epoch: 0191 loss_train: 1.5544 loss_x_train_x: 0.6399 loss_x_train_y: 0.9126 loss_val: 1.5130 loss_x_val_x: 0.6571 loss_x_val_y: 0.8559 time: 0.0597s
#  Epoch: 0192 loss_train: 1.5476 loss_x_train_x: 0.6337 loss_x_train_y: 0.9119 loss_val: 1.5099 loss_x_val_x: 0.6556 loss_x_val_y: 0.8543 time: 0.0595s
#  Epoch: 0193 loss_train: 1.5355 loss_x_train_x: 0.6285 loss_x_train_y: 0.9051 loss_val: 1.5044 loss_x_val_x: 0.6563 loss_x_val_y: 0.8481 time: 0.0641s
#  Epoch: 0194 loss_train: 1.5410 loss_x_train_x: 0.6369 loss_x_train_y: 0.9022 loss_val: 1.4994 loss_x_val_x: 0.6546 loss_x_val_y: 0.8448 time: 0.0595s
#  Epoch: 0195 loss_train: 1.5342 loss_x_train_x: 0.6340 loss_x_train_y: 0.8983 loss_val: 1.4921 loss_x_val_x: 0.6521 loss_x_val_y: 0.8400 time: 0.0598s
#  Epoch: 0196 loss_train: 1.5261 loss_x_train_x: 0.6300 loss_x_train_y: 0.8942 loss_val: 1.4863 loss_x_val_x: 0.6512 loss_x_val_y: 0.8351 time: 0.0596s
#  Epoch: 0197 loss_train: 1.5141 loss_x_train_x: 0.6211 loss_x_train_y: 0.8910 loss_val: 1.4850 loss_x_val_x: 0.6514 loss_x_val_y: 0.8336 time: 0.0596s
#  Epoch: 0198 loss_train: 1.5199 loss_x_train_x: 0.6280 loss_x_train_y: 0.8900 loss_val: 1.4811 loss_x_val_x: 0.6499 loss_x_val_y: 0.8312 time: 0.0592s
#  Epoch: 0199 loss_train: 1.5020 loss_x_train_x: 0.6321 loss_x_train_y: 0.8679 loss_val: 1.4733 loss_x_val_x: 0.6487 loss_x_val_y: 0.8246 time: 0.0598s
#  Epoch: 0200 loss_train: 1.4962 loss_x_train_x: 0.6251 loss_x_train_y: 0.8691 loss_val: 1.4683 loss_x_val_x: 0.6452 loss_x_val_y: 0.8231 time: 0.0593s
#  Epoch: 0201 loss_train: 1.4894 loss_x_train_x: 0.6273 loss_x_train_y: 0.8601 loss_val: 1.4637 loss_x_val_x: 0.6456 loss_x_val_y: 0.8181 time: 0.0618s
#  Epoch: 0202 loss_train: 1.4933 loss_x_train_x: 0.6277 loss_x_train_y: 0.8637 loss_val: 1.4597 loss_x_val_x: 0.6441 loss_x_val_y: 0.8156 time: 0.0597s
#  Epoch: 0203 loss_train: 1.4812 loss_x_train_x: 0.6218 loss_x_train_y: 0.8575 loss_val: 1.4533 loss_x_val_x: 0.6427 loss_x_val_y: 0.8107 time: 0.0598s
#  Epoch: 0204 loss_train: 1.4753 loss_x_train_x: 0.6144 loss_x_train_y: 0.8589 loss_val: 1.4478 loss_x_val_x: 0.6405 loss_x_val_y: 0.8074 time: 0.0597s
#  Epoch: 0205 loss_train: 1.4786 loss_x_train_x: 0.6156 loss_x_train_y: 0.8610 loss_val: 1.4434 loss_x_val_x: 0.6386 loss_x_val_y: 0.8049 time: 0.0593s
#  Epoch: 0206 loss_train: 1.4634 loss_x_train_x: 0.6168 loss_x_train_y: 0.8447 loss_val: 1.4366 loss_x_val_x: 0.6368 loss_x_val_y: 0.7998 time: 0.0596s
#  Epoch: 0207 loss_train: 1.4583 loss_x_train_x: 0.6085 loss_x_train_y: 0.8479 loss_val: 1.4340 loss_x_val_x: 0.6372 loss_x_val_y: 0.7968 time: 0.0599s
#  Epoch: 0208 loss_train: 1.4593 loss_x_train_x: 0.6204 loss_x_train_y: 0.8370 loss_val: 1.4365 loss_x_val_x: 0.6382 loss_x_val_y: 0.7983 time: 0.0593s
#  Epoch: 0209 loss_train: 1.4564 loss_x_train_x: 0.6106 loss_x_train_y: 0.8439 loss_val: 1.4328 loss_x_val_x: 0.6372 loss_x_val_y: 0.7956 time: 0.0601s
#  Epoch: 0210 loss_train: 1.4392 loss_x_train_x: 0.6053 loss_x_train_y: 0.8320 loss_val: 1.4304 loss_x_val_x: 0.6366 loss_x_val_y: 0.7938 time: 0.0595s
#  Epoch: 0211 loss_train: 1.4331 loss_x_train_x: 0.6028 loss_x_train_y: 0.8283 loss_val: 1.4241 loss_x_val_x: 0.6357 loss_x_val_y: 0.7884 time: 0.0601s
#  Epoch: 0212 loss_train: 1.4420 loss_x_train_x: 0.6115 loss_x_train_y: 0.8286 loss_val: 1.4191 loss_x_val_x: 0.6346 loss_x_val_y: 0.7845 time: 0.0599s
#  Epoch: 0213 loss_train: 1.4319 loss_x_train_x: 0.6117 loss_x_train_y: 0.8183 loss_val: 1.4095 loss_x_val_x: 0.6324 loss_x_val_y: 0.7771 time: 0.0602s
#  Epoch: 0214 loss_train: 1.4239 loss_x_train_x: 0.6042 loss_x_train_y: 0.8177 loss_val: 1.4045 loss_x_val_x: 0.6305 loss_x_val_y: 0.7741 time: 0.0599s
#  Epoch: 0215 loss_train: 1.4135 loss_x_train_x: 0.6034 loss_x_train_y: 0.8082 loss_val: 1.4009 loss_x_val_x: 0.6299 loss_x_val_y: 0.7710 time: 0.0607s
#  Epoch: 0216 loss_train: 1.4169 loss_x_train_x: 0.5994 loss_x_train_y: 0.8155 loss_val: 1.3969 loss_x_val_x: 0.6298 loss_x_val_y: 0.7672 time: 0.0602s
#  Epoch: 0217 loss_train: 1.4208 loss_x_train_x: 0.6053 loss_x_train_y: 0.8135 loss_val: 1.3956 loss_x_val_x: 0.6281 loss_x_val_y: 0.7675 time: 0.0601s
#  Epoch: 0218 loss_train: 1.4058 loss_x_train_x: 0.6009 loss_x_train_y: 0.8029 loss_val: 1.3895 loss_x_val_x: 0.6272 loss_x_val_y: 0.7623 time: 0.0599s
#  Epoch: 0219 loss_train: 1.4062 loss_x_train_x: 0.5993 loss_x_train_y: 0.8049 loss_val: 1.3899 loss_x_val_x: 0.6274 loss_x_val_y: 0.7624 time: 0.0607s
#  Epoch: 0220 loss_train: 1.4021 loss_x_train_x: 0.6023 loss_x_train_y: 0.7979 loss_val: 1.3841 loss_x_val_x: 0.6268 loss_x_val_y: 0.7573 time: 0.0599s
#  Epoch: 0221 loss_train: 1.3997 loss_x_train_x: 0.6025 loss_x_train_y: 0.7952 loss_val: 1.3816 loss_x_val_x: 0.6265 loss_x_val_y: 0.7551 time: 0.0626s
#  Epoch: 0222 loss_train: 1.3838 loss_x_train_x: 0.5986 loss_x_train_y: 0.7833 loss_val: 1.3772 loss_x_val_x: 0.6247 loss_x_val_y: 0.7525 time: 0.0603s
#  Epoch: 0223 loss_train: 1.3905 loss_x_train_x: 0.5967 loss_x_train_y: 0.7919 loss_val: 1.3727 loss_x_val_x: 0.6234 loss_x_val_y: 0.7493 time: 0.0607s
#  Epoch: 0224 loss_train: 1.3788 loss_x_train_x: 0.5948 loss_x_train_y: 0.7820 loss_val: 1.3696 loss_x_val_x: 0.6231 loss_x_val_y: 0.7465 time: 0.0603s
#  Epoch: 0225 loss_train: 1.3820 loss_x_train_x: 0.5969 loss_x_train_y: 0.7832 loss_val: 1.3648 loss_x_val_x: 0.6216 loss_x_val_y: 0.7432 time: 0.0601s
#  Epoch: 0226 loss_train: 1.3805 loss_x_train_x: 0.6000 loss_x_train_y: 0.7786 loss_val: 1.3614 loss_x_val_x: 0.6210 loss_x_val_y: 0.7404 time: 0.0599s
#  Epoch: 0227 loss_train: 1.3731 loss_x_train_x: 0.5955 loss_x_train_y: 0.7756 loss_val: 1.3597 loss_x_val_x: 0.6218 loss_x_val_y: 0.7379 time: 0.0615s
#  Epoch: 0228 loss_train: 1.3703 loss_x_train_x: 0.5884 loss_x_train_y: 0.7799 loss_val: 1.3591 loss_x_val_x: 0.6208 loss_x_val_y: 0.7383 time: 0.0604s
#  Epoch: 0229 loss_train: 1.3659 loss_x_train_x: 0.5934 loss_x_train_y: 0.7706 loss_val: 1.3545 loss_x_val_x: 0.6197 loss_x_val_y: 0.7348 time: 0.0603s
#  Epoch: 0230 loss_train: 1.3561 loss_x_train_x: 0.5863 loss_x_train_y: 0.7679 loss_val: 1.3488 loss_x_val_x: 0.6197 loss_x_val_y: 0.7292 time: 0.0602s
#  Epoch: 0231 loss_train: 1.3576 loss_x_train_x: 0.5902 loss_x_train_y: 0.7654 loss_val: 1.3456 loss_x_val_x: 0.6186 loss_x_val_y: 0.7271 time: 0.0607s
#  Epoch: 0232 loss_train: 1.3494 loss_x_train_x: 0.5868 loss_x_train_y: 0.7607 loss_val: 1.3417 loss_x_val_x: 0.6188 loss_x_val_y: 0.7230 time: 0.0599s
#  Epoch: 0233 loss_train: 1.3464 loss_x_train_x: 0.5861 loss_x_train_y: 0.7584 loss_val: 1.3403 loss_x_val_x: 0.6172 loss_x_val_y: 0.7230 time: 0.0622s
#  Epoch: 0234 loss_train: 1.3414 loss_x_train_x: 0.5884 loss_x_train_y: 0.7511 loss_val: 1.3363 loss_x_val_x: 0.6170 loss_x_val_y: 0.7193 time: 0.0597s
#  Epoch: 0235 loss_train: 1.3381 loss_x_train_x: 0.5843 loss_x_train_y: 0.7519 loss_val: 1.3349 loss_x_val_x: 0.6169 loss_x_val_y: 0.7180 time: 0.0597s
#  Epoch: 0236 loss_train: 1.3400 loss_x_train_x: 0.5812 loss_x_train_y: 0.7569 loss_val: 1.3321 loss_x_val_x: 0.6169 loss_x_val_y: 0.7153 time: 0.0599s
#  Epoch: 0237 loss_train: 1.3321 loss_x_train_x: 0.5808 loss_x_train_y: 0.7494 loss_val: 1.3268 loss_x_val_x: 0.6151 loss_x_val_y: 0.7117 time: 0.0594s
#  Epoch: 0238 loss_train: 1.3327 loss_x_train_x: 0.5860 loss_x_train_y: 0.7448 loss_val: 1.3245 loss_x_val_x: 0.6141 loss_x_val_y: 0.7104 time: 0.0592s
#  Epoch: 0239 loss_train: 1.3122 loss_x_train_x: 0.5744 loss_x_train_y: 0.7359 loss_val: 1.3212 loss_x_val_x: 0.6143 loss_x_val_y: 0.7070 time: 0.0596s
#  Epoch: 0240 loss_train: 1.3079 loss_x_train_x: 0.5775 loss_x_train_y: 0.7284 loss_val: 1.3176 loss_x_val_x: 0.6147 loss_x_val_y: 0.7030 time: 0.0593s
#  Epoch: 0241 loss_train: 1.3062 loss_x_train_x: 0.5791 loss_x_train_y: 0.7252 loss_val: 1.3170 loss_x_val_x: 0.6147 loss_x_val_y: 0.7023 time: 0.0594s
#  Epoch: 0242 loss_train: 1.3111 loss_x_train_x: 0.5833 loss_x_train_y: 0.7258 loss_val: 1.3139 loss_x_val_x: 0.6141 loss_x_val_y: 0.6998 time: 0.0596s
#  Epoch: 0243 loss_train: 1.3125 loss_x_train_x: 0.5792 loss_x_train_y: 0.7315 loss_val: 1.3091 loss_x_val_x: 0.6129 loss_x_val_y: 0.6962 time: 0.0600s
#  Epoch: 0244 loss_train: 1.3066 loss_x_train_x: 0.5770 loss_x_train_y: 0.7277 loss_val: 1.3076 loss_x_val_x: 0.6116 loss_x_val_y: 0.6959 time: 0.0662s
#  Epoch: 0245 loss_train: 1.2881 loss_x_train_x: 0.5690 loss_x_train_y: 0.7172 loss_val: 1.3064 loss_x_val_x: 0.6122 loss_x_val_y: 0.6941 time: 0.0604s
#  Epoch: 0246 loss_train: 1.2975 loss_x_train_x: 0.5720 loss_x_train_y: 0.7235 loss_val: 1.3042 loss_x_val_x: 0.6118 loss_x_val_y: 0.6924 time: 0.0597s
#  Epoch: 0247 loss_train: 1.2966 loss_x_train_x: 0.5744 loss_x_train_y: 0.7202 loss_val: 1.3033 loss_x_val_x: 0.6118 loss_x_val_y: 0.6915 time: 0.0677s
#  Epoch: 0248 loss_train: 1.2864 loss_x_train_x: 0.5708 loss_x_train_y: 0.7136 loss_val: 1.3004 loss_x_val_x: 0.6111 loss_x_val_y: 0.6892 time: 0.0598s
#  Epoch: 0249 loss_train: 1.2903 loss_x_train_x: 0.5757 loss_x_train_y: 0.7127 loss_val: 1.2965 loss_x_val_x: 0.6107 loss_x_val_y: 0.6858 time: 0.0601s
#  Epoch: 0250 loss_train: 1.2861 loss_x_train_x: 0.5729 loss_x_train_y: 0.7113 loss_val: 1.2938 loss_x_val_x: 0.6104 loss_x_val_y: 0.6834 time: 0.0598s
#  Epoch: 0251 loss_train: 1.2886 loss_x_train_x: 0.5799 loss_x_train_y: 0.7068 loss_val: 1.2913 loss_x_val_x: 0.6091 loss_x_val_y: 0.6822 time: 0.0627s
#  Epoch: 0252 loss_train: 1.2870 loss_x_train_x: 0.5766 loss_x_train_y: 0.7085 loss_val: 1.2889 loss_x_val_x: 0.6091 loss_x_val_y: 0.6798 time: 0.0597s
#  Epoch: 0253 loss_train: 1.2681 loss_x_train_x: 0.5682 loss_x_train_y: 0.6979 loss_val: 1.2872 loss_x_val_x: 0.6089 loss_x_val_y: 0.6783 time: 0.0595s
#  Epoch: 0254 loss_train: 1.2817 loss_x_train_x: 0.5775 loss_x_train_y: 0.7023 loss_val: 1.2849 loss_x_val_x: 0.6079 loss_x_val_y: 0.6770 time: 0.0598s
#  Epoch: 0255 loss_train: 1.2642 loss_x_train_x: 0.5673 loss_x_train_y: 0.6949 loss_val: 1.2794 loss_x_val_x: 0.6061 loss_x_val_y: 0.6734 time: 0.0599s
#  Epoch: 0256 loss_train: 1.2706 loss_x_train_x: 0.5711 loss_x_train_y: 0.6975 loss_val: 1.2773 loss_x_val_x: 0.6057 loss_x_val_y: 0.6716 time: 0.0598s
#  Epoch: 0257 loss_train: 1.2627 loss_x_train_x: 0.5667 loss_x_train_y: 0.6940 loss_val: 1.2750 loss_x_val_x: 0.6065 loss_x_val_y: 0.6686 time: 0.0591s
#  Epoch: 0258 loss_train: 1.2714 loss_x_train_x: 0.5711 loss_x_train_y: 0.6984 loss_val: 1.2740 loss_x_val_x: 0.6064 loss_x_val_y: 0.6676 time: 0.0615s
#  Epoch: 0259 loss_train: 1.2685 loss_x_train_x: 0.5721 loss_x_train_y: 0.6944 loss_val: 1.2700 loss_x_val_x: 0.6054 loss_x_val_y: 0.6646 time: 0.0588s
#  Epoch: 0260 loss_train: 1.2576 loss_x_train_x: 0.5734 loss_x_train_y: 0.6823 loss_val: 1.2677 loss_x_val_x: 0.6047 loss_x_val_y: 0.6629 time: 0.0596s
#  Epoch: 0261 loss_train: 1.2448 loss_x_train_x: 0.5628 loss_x_train_y: 0.6800 loss_val: 1.2671 loss_x_val_x: 0.6041 loss_x_val_y: 0.6630 time: 0.0596s
#  Epoch: 0262 loss_train: 1.2486 loss_x_train_x: 0.5616 loss_x_train_y: 0.6851 loss_val: 1.2661 loss_x_val_x: 0.6049 loss_x_val_y: 0.6612 time: 0.0593s
#  Epoch: 0263 loss_train: 1.2413 loss_x_train_x: 0.5572 loss_x_train_y: 0.6821 loss_val: 1.2625 loss_x_val_x: 0.6040 loss_x_val_y: 0.6585 time: 0.0596s
#  Epoch: 0264 loss_train: 1.2454 loss_x_train_x: 0.5628 loss_x_train_y: 0.6807 loss_val: 1.2613 loss_x_val_x: 0.6025 loss_x_val_y: 0.6587 time: 0.0596s
#  Epoch: 0265 loss_train: 1.2451 loss_x_train_x: 0.5602 loss_x_train_y: 0.6830 loss_val: 1.2561 loss_x_val_x: 0.6025 loss_x_val_y: 0.6536 time: 0.0592s
#  Epoch: 0266 loss_train: 1.2365 loss_x_train_x: 0.5635 loss_x_train_y: 0.6711 loss_val: 1.2542 loss_x_val_x: 0.6015 loss_x_val_y: 0.6527 time: 0.0590s
#  Epoch: 0267 loss_train: 1.2404 loss_x_train_x: 0.5616 loss_x_train_y: 0.6769 loss_val: 1.2529 loss_x_val_x: 0.6019 loss_x_val_y: 0.6510 time: 0.0598s
#  Epoch: 0268 loss_train: 1.2429 loss_x_train_x: 0.5617 loss_x_train_y: 0.6792 loss_val: 1.2531 loss_x_val_x: 0.6022 loss_x_val_y: 0.6509 time: 0.0595s
#  Epoch: 0269 loss_train: 1.2123 loss_x_train_x: 0.5518 loss_x_train_y: 0.6586 loss_val: 1.2510 loss_x_val_x: 0.6013 loss_x_val_y: 0.6496 time: 0.0595s
#  Epoch: 0270 loss_train: 1.2274 loss_x_train_x: 0.5588 loss_x_train_y: 0.6667 loss_val: 1.2505 loss_x_val_x: 0.6026 loss_x_val_y: 0.6480 time: 0.0594s
#  Epoch: 0271 loss_train: 1.2197 loss_x_train_x: 0.5500 loss_x_train_y: 0.6678 loss_val: 1.2512 loss_x_val_x: 0.6032 loss_x_val_y: 0.6480 time: 0.0598s
#  Epoch: 0272 loss_train: 1.2141 loss_x_train_x: 0.5523 loss_x_train_y: 0.6598 loss_val: 1.2479 loss_x_val_x: 0.6028 loss_x_val_y: 0.6451 time: 0.0588s
#  Epoch: 0273 loss_train: 1.2106 loss_x_train_x: 0.5508 loss_x_train_y: 0.6578 loss_val: 1.2478 loss_x_val_x: 0.6037 loss_x_val_y: 0.6441 time: 0.0594s
#  Epoch: 0274 loss_train: 1.2155 loss_x_train_x: 0.5565 loss_x_train_y: 0.6571 loss_val: 1.2452 loss_x_val_x: 0.6030 loss_x_val_y: 0.6422 time: 0.0596s
#  Epoch: 0275 loss_train: 1.2114 loss_x_train_x: 0.5572 loss_x_train_y: 0.6522 loss_val: 1.2447 loss_x_val_x: 0.6024 loss_x_val_y: 0.6423 time: 0.0593s
#  Epoch: 0276 loss_train: 1.2148 loss_x_train_x: 0.5533 loss_x_train_y: 0.6595 loss_val: 1.2426 loss_x_val_x: 0.6025 loss_x_val_y: 0.6401 time: 0.0594s
#  Epoch: 0277 loss_train: 1.2070 loss_x_train_x: 0.5522 loss_x_train_y: 0.6529 loss_val: 1.2389 loss_x_val_x: 0.6021 loss_x_val_y: 0.6367 time: 0.0594s
#  Epoch: 0278 loss_train: 1.2137 loss_x_train_x: 0.5607 loss_x_train_y: 0.6510 loss_val: 1.2380 loss_x_val_x: 0.6018 loss_x_val_y: 0.6362 time: 0.0594s
#  Epoch: 0279 loss_train: 1.2088 loss_x_train_x: 0.5538 loss_x_train_y: 0.6530 loss_val: 1.2362 loss_x_val_x: 0.5996 loss_x_val_y: 0.6366 time: 0.0598s
#  Epoch: 0280 loss_train: 1.2098 loss_x_train_x: 0.5554 loss_x_train_y: 0.6525 loss_val: 1.2371 loss_x_val_x: 0.6014 loss_x_val_y: 0.6356 time: 0.0595s
#  Epoch: 0281 loss_train: 1.1964 loss_x_train_x: 0.5533 loss_x_train_y: 0.6411 loss_val: 1.2368 loss_x_val_x: 0.6005 loss_x_val_y: 0.6363 time: 0.0596s
#  Epoch: 0282 loss_train: 1.2006 loss_x_train_x: 0.5481 loss_x_train_y: 0.6505 loss_val: 1.2332 loss_x_val_x: 0.6006 loss_x_val_y: 0.6327 time: 0.0621s
#  Epoch: 0283 loss_train: 1.2030 loss_x_train_x: 0.5505 loss_x_train_y: 0.6506 loss_val: 1.2325 loss_x_val_x: 0.6007 loss_x_val_y: 0.6318 time: 0.0598s
#  Epoch: 0284 loss_train: 1.1906 loss_x_train_x: 0.5479 loss_x_train_y: 0.6408 loss_val: 1.2324 loss_x_val_x: 0.6009 loss_x_val_y: 0.6315 time: 0.0595s
#  Epoch: 0285 loss_train: 1.1939 loss_x_train_x: 0.5559 loss_x_train_y: 0.6361 loss_val: 1.2310 loss_x_val_x: 0.6020 loss_x_val_y: 0.6289 time: 0.0592s
#  Epoch: 0286 loss_train: 1.1846 loss_x_train_x: 0.5439 loss_x_train_y: 0.6387 loss_val: 1.2289 loss_x_val_x: 0.6013 loss_x_val_y: 0.6276 time: 0.0593s
#  Epoch: 0287 loss_train: 1.1941 loss_x_train_x: 0.5503 loss_x_train_y: 0.6418 loss_val: 1.2279 loss_x_val_x: 0.6013 loss_x_val_y: 0.6266 time: 0.0596s
#  Epoch: 0288 loss_train: 1.1940 loss_x_train_x: 0.5468 loss_x_train_y: 0.6452 loss_val: 1.2269 loss_x_val_x: 0.6025 loss_x_val_y: 0.6245 time: 0.0598s
#  Epoch: 0289 loss_train: 1.1822 loss_x_train_x: 0.5450 loss_x_train_y: 0.6353 loss_val: 1.2260 loss_x_val_x: 0.6021 loss_x_val_y: 0.6239 time: 0.0594s
#  Epoch: 0290 loss_train: 1.1913 loss_x_train_x: 0.5471 loss_x_train_y: 0.6423 loss_val: 1.2259 loss_x_val_x: 0.6016 loss_x_val_y: 0.6243 time: 0.0594s
#  Epoch: 0291 loss_train: 1.1855 loss_x_train_x: 0.5475 loss_x_train_y: 0.6360 loss_val: 1.2236 loss_x_val_x: 0.6031 loss_x_val_y: 0.6205 time: 0.0596s
#  Epoch: 0292 loss_train: 1.1803 loss_x_train_x: 0.5427 loss_x_train_y: 0.6356 loss_val: 1.2222 loss_x_val_x: 0.6021 loss_x_val_y: 0.6201 time: 0.0594s
#  Epoch: 0293 loss_train: 1.1680 loss_x_train_x: 0.5440 loss_x_train_y: 0.6220 loss_val: 1.2209 loss_x_val_x: 0.6012 loss_x_val_y: 0.6197 time: 0.0594s
#  Epoch: 0294 loss_train: 1.1695 loss_x_train_x: 0.5430 loss_x_train_y: 0.6245 loss_val: 1.2210 loss_x_val_x: 0.6016 loss_x_val_y: 0.6194 time: 0.0602s
#  Epoch: 0295 loss_train: 1.1650 loss_x_train_x: 0.5441 loss_x_train_y: 0.6190 loss_val: 1.2176 loss_x_val_x: 0.6015 loss_x_val_y: 0.6161 time: 0.0601s
#  Epoch: 0296 loss_train: 1.1716 loss_x_train_x: 0.5422 loss_x_train_y: 0.6274 loss_val: 1.2164 loss_x_val_x: 0.6006 loss_x_val_y: 0.6158 time: 0.0595s
#  Epoch: 0297 loss_train: 1.1666 loss_x_train_x: 0.5390 loss_x_train_y: 0.6257 loss_val: 1.2168 loss_x_val_x: 0.6017 loss_x_val_y: 0.6151 time: 0.0594s
#  Epoch: 0298 loss_train: 1.1650 loss_x_train_x: 0.5412 loss_x_train_y: 0.6219 loss_val: 1.2164 loss_x_val_x: 0.6019 loss_x_val_y: 0.6146 time: 0.0639s
#  Epoch: 0299 loss_train: 1.1656 loss_x_train_x: 0.5392 loss_x_train_y: 0.6245 loss_val: 1.2149 loss_x_val_x: 0.6013 loss_x_val_y: 0.6136 time: 0.0599s
#  Epoch: 0300 loss_train: 1.1613 loss_x_train_x: 0.5445 loss_x_train_y: 0.6149 loss_val: 1.2124 loss_x_val_x: 0.6012 loss_x_val_y: 0.6113 time: 0.0593s
#  Epoch: 0301 loss_train: 1.1579 loss_x_train_x: 0.5404 loss_x_train_y: 0.6156 loss_val: 1.2133 loss_x_val_x: 0.6023 loss_x_val_y: 0.6110 time: 0.0599s
#  Epoch: 0302 loss_train: 1.1557 loss_x_train_x: 0.5384 loss_x_train_y: 0.6153 loss_val: 1.2101 loss_x_val_x: 0.6010 loss_x_val_y: 0.6091 time: 0.0594s
#  Epoch: 0303 loss_train: 1.1570 loss_x_train_x: 0.5394 loss_x_train_y: 0.6157 loss_val: 1.2110 loss_x_val_x: 0.6019 loss_x_val_y: 0.6091 time: 0.0600s
#  Epoch: 0304 loss_train: 1.1608 loss_x_train_x: 0.5378 loss_x_train_y: 0.6210 loss_val: 1.2094 loss_x_val_x: 0.6001 loss_x_val_y: 0.6093 time: 0.0597s
#  Epoch: 0305 loss_train: 1.1515 loss_x_train_x: 0.5357 loss_x_train_y: 0.6139 loss_val: 1.2072 loss_x_val_x: 0.5997 loss_x_val_y: 0.6075 time: 0.0628s
#  Epoch: 0306 loss_train: 1.1480 loss_x_train_x: 0.5313 loss_x_train_y: 0.6147 loss_val: 1.2080 loss_x_val_x: 0.6016 loss_x_val_y: 0.6064 time: 0.0594s
#  Epoch: 0307 loss_train: 1.1430 loss_x_train_x: 0.5351 loss_x_train_y: 0.6059 loss_val: 1.2059 loss_x_val_x: 0.6020 loss_x_val_y: 0.6039 time: 0.0599s
#  Epoch: 0308 loss_train: 1.1444 loss_x_train_x: 0.5325 loss_x_train_y: 0.6100 loss_val: 1.2046 loss_x_val_x: 0.6020 loss_x_val_y: 0.6026 time: 0.0594s
#  Epoch: 0309 loss_train: 1.1357 loss_x_train_x: 0.5264 loss_x_train_y: 0.6073 loss_val: 1.2037 loss_x_val_x: 0.6016 loss_x_val_y: 0.6021 time: 0.0587s
#  Epoch: 0310 loss_train: 1.1416 loss_x_train_x: 0.5292 loss_x_train_y: 0.6104 loss_val: 1.2030 loss_x_val_x: 0.6010 loss_x_val_y: 0.6020 time: 0.0606s
#  Epoch: 0311 loss_train: 1.1519 loss_x_train_x: 0.5340 loss_x_train_y: 0.6159 loss_val: 1.2024 loss_x_val_x: 0.6008 loss_x_val_y: 0.6016 time: 0.0599s
#  Epoch: 0312 loss_train: 1.1343 loss_x_train_x: 0.5307 loss_x_train_y: 0.6017 loss_val: 1.2010 loss_x_val_x: 0.5998 loss_x_val_y: 0.6012 time: 0.0588s
#  Epoch: 0313 loss_train: 1.1390 loss_x_train_x: 0.5367 loss_x_train_y: 0.6002 loss_val: 1.1995 loss_x_val_x: 0.5998 loss_x_val_y: 0.5997 time: 0.0593s
#  Epoch: 0314 loss_train: 1.1364 loss_x_train_x: 0.5326 loss_x_train_y: 0.6018 loss_val: 1.1985 loss_x_val_x: 0.5995 loss_x_val_y: 0.5990 time: 0.0595s
#  Epoch: 0315 loss_train: 1.1354 loss_x_train_x: 0.5262 loss_x_train_y: 0.6073 loss_val: 1.1967 loss_x_val_x: 0.5989 loss_x_val_y: 0.5978 time: 0.0598s
#  Epoch: 0316 loss_train: 1.1316 loss_x_train_x: 0.5306 loss_x_train_y: 0.5991 loss_val: 1.1968 loss_x_val_x: 0.6001 loss_x_val_y: 0.5966 time: 0.0595s
# ...
#  Epoch: 2895 loss_train: 0.1000 loss_x_train_x: 0.0301 loss_x_train_y: 0.0654 loss_val: 1.6193 loss_x_val_x: 0.9293 loss_x_val_y: 0.6899 time: 0.0526s
#  Epoch: 2896 loss_train: 0.1034 loss_x_train_x: 0.0302 loss_x_train_y: 0.0687 loss_val: 1.6167 loss_x_val_x: 0.9284 loss_x_val_y: 0.6883 time: 0.0515s
#  Epoch: 2897 loss_train: 0.1027 loss_x_train_x: 0.0305 loss_x_train_y: 0.0678 loss_val: 1.6175 loss_x_val_x: 0.9288 loss_x_val_y: 0.6887 time: 0.0517s
#  Epoch: 2898 loss_train: 0.1030 loss_x_train_x: 0.0341 loss_x_train_y: 0.0645 loss_val: 1.6225 loss_x_val_x: 0.9311 loss_x_val_y: 0.6914 time: 0.0524s
#  Epoch: 2899 loss_train: 0.1011 loss_x_train_x: 0.0331 loss_x_train_y: 0.0636 loss_val: 1.6199 loss_x_val_x: 0.9277 loss_x_val_y: 0.6922 time: 0.0516s
#  Epoch: 2900 loss_train: 0.1063 loss_x_train_x: 0.0296 loss_x_train_y: 0.0723 loss_val: 1.6157 loss_x_val_x: 0.9270 loss_x_val_y: 0.6887 time: 0.0525s
#  Epoch: 2901 loss_train: 0.1015 loss_x_train_x: 0.0304 loss_x_train_y: 0.0667 loss_val: 1.6150 loss_x_val_x: 0.9258 loss_x_val_y: 0.6893 time: 0.0530s
#  Epoch: 2902 loss_train: 0.1041 loss_x_train_x: 0.0319 loss_x_train_y: 0.0677 loss_val: 1.6174 loss_x_val_x: 0.9266 loss_x_val_y: 0.6908 time: 0.0516s
#  Epoch: 2903 loss_train: 0.1070 loss_x_train_x: 0.0318 loss_x_train_y: 0.0707 loss_val: 1.6162 loss_x_val_x: 0.9253 loss_x_val_y: 0.6908 time: 0.0517s
#  Epoch: 2904 loss_train: 0.1001 loss_x_train_x: 0.0298 loss_x_train_y: 0.0658 loss_val: 1.6131 loss_x_val_x: 0.9241 loss_x_val_y: 0.6890 time: 0.0525s
#  Epoch: 2905 loss_train: 0.1022 loss_x_train_x: 0.0298 loss_x_train_y: 0.0680 loss_val: 1.6150 loss_x_val_x: 0.9251 loss_x_val_y: 0.6899 time: 0.0520s
#  Epoch: 2906 loss_train: 0.1061 loss_x_train_x: 0.0318 loss_x_train_y: 0.0699 loss_val: 1.6156 loss_x_val_x: 0.9243 loss_x_val_y: 0.6913 time: 0.0531s
#  Epoch: 2907 loss_train: 0.1091 loss_x_train_x: 0.0332 loss_x_train_y: 0.0714 loss_val: 1.6153 loss_x_val_x: 0.9266 loss_x_val_y: 0.6887 time: 0.0515s
#  Epoch: 2908 loss_train: 0.1002 loss_x_train_x: 0.0277 loss_x_train_y: 0.0680 loss_val: 1.6185 loss_x_val_x: 0.9277 loss_x_val_y: 0.6908 time: 0.0516s
#  Epoch: 2909 loss_train: 0.1012 loss_x_train_x: 0.0287 loss_x_train_y: 0.0681 loss_val: 1.6158 loss_x_val_x: 0.9273 loss_x_val_y: 0.6886 time: 0.0521s
#  Epoch: 2910 loss_train: 0.1059 loss_x_train_x: 0.0327 loss_x_train_y: 0.0688 loss_val: 1.6174 loss_x_val_x: 0.9286 loss_x_val_y: 0.6888 time: 0.0514s
#  Epoch: 2911 loss_train: 0.1024 loss_x_train_x: 0.0288 loss_x_train_y: 0.0691 loss_val: 1.6186 loss_x_val_x: 0.9295 loss_x_val_y: 0.6891 time: 0.0518s
#  Epoch: 2912 loss_train: 0.1092 loss_x_train_x: 0.0323 loss_x_train_y: 0.0724 loss_val: 1.6172 loss_x_val_x: 0.9265 loss_x_val_y: 0.6907 time: 0.0528s
#  Epoch: 2913 loss_train: 0.1011 loss_x_train_x: 0.0293 loss_x_train_y: 0.0674 loss_val: 1.6159 loss_x_val_x: 0.9259 loss_x_val_y: 0.6899 time: 0.0560s
#  Epoch: 2914 loss_train: 0.1003 loss_x_train_x: 0.0288 loss_x_train_y: 0.0671 loss_val: 1.6157 loss_x_val_x: 0.9279 loss_x_val_y: 0.6879 time: 0.0519s
#  Epoch: 2915 loss_train: 0.1032 loss_x_train_x: 0.0299 loss_x_train_y: 0.0688 loss_val: 1.6164 loss_x_val_x: 0.9274 loss_x_val_y: 0.6890 time: 0.0515s
#  Epoch: 2916 loss_train: 0.1017 loss_x_train_x: 0.0307 loss_x_train_y: 0.0665 loss_val: 1.6147 loss_x_val_x: 0.9240 loss_x_val_y: 0.6907 time: 0.0512s
#  Epoch: 2917 loss_train: 0.0991 loss_x_train_x: 0.0299 loss_x_train_y: 0.0647 loss_val: 1.6172 loss_x_val_x: 0.9253 loss_x_val_y: 0.6919 time: 0.0527s
#  Epoch: 2918 loss_train: 0.1026 loss_x_train_x: 0.0314 loss_x_train_y: 0.0667 loss_val: 1.6183 loss_x_val_x: 0.9260 loss_x_val_y: 0.6923 time: 0.0517s
#  Epoch: 2919 loss_train: 0.1020 loss_x_train_x: 0.0291 loss_x_train_y: 0.0684 loss_val: 1.6158 loss_x_val_x: 0.9248 loss_x_val_y: 0.6910 time: 0.0521s
#  Epoch: 2920 loss_train: 0.0967 loss_x_train_x: 0.0294 loss_x_train_y: 0.0629 loss_val: 1.6157 loss_x_val_x: 0.9268 loss_x_val_y: 0.6889 time: 0.0530s
#  Epoch: 2921 loss_train: 0.1039 loss_x_train_x: 0.0311 loss_x_train_y: 0.0683 loss_val: 1.6127 loss_x_val_x: 0.9253 loss_x_val_y: 0.6874 time: 0.0517s
#  Epoch: 2922 loss_train: 0.0990 loss_x_train_x: 0.0302 loss_x_train_y: 0.0643 loss_val: 1.6146 loss_x_val_x: 0.9262 loss_x_val_y: 0.6884 time: 0.0564s
#  Epoch: 2923 loss_train: 0.1005 loss_x_train_x: 0.0279 loss_x_train_y: 0.0681 loss_val: 1.6157 loss_x_val_x: 0.9266 loss_x_val_y: 0.6891 time: 0.0559s
#  Epoch: 2924 loss_train: 0.1005 loss_x_train_x: 0.0293 loss_x_train_y: 0.0668 loss_val: 1.6147 loss_x_val_x: 0.9254 loss_x_val_y: 0.6893 time: 0.0513s
#  Epoch: 2925 loss_train: 0.1008 loss_x_train_x: 0.0302 loss_x_train_y: 0.0662 loss_val: 1.6141 loss_x_val_x: 0.9257 loss_x_val_y: 0.6884 time: 0.0508s
#  Epoch: 2926 loss_train: 0.0990 loss_x_train_x: 0.0301 loss_x_train_y: 0.0644 loss_val: 1.6184 loss_x_val_x: 0.9262 loss_x_val_y: 0.6923 time: 0.0518s
#  Epoch: 2927 loss_train: 0.1029 loss_x_train_x: 0.0306 loss_x_train_y: 0.0679 loss_val: 1.6171 loss_x_val_x: 0.9251 loss_x_val_y: 0.6920 time: 0.0522s
#  Epoch: 2928 loss_train: 0.1000 loss_x_train_x: 0.0274 loss_x_train_y: 0.0681 loss_val: 1.6147 loss_x_val_x: 0.9244 loss_x_val_y: 0.6902 time: 0.0526s
#  Epoch: 2929 loss_train: 0.1024 loss_x_train_x: 0.0316 loss_x_train_y: 0.0664 loss_val: 1.6143 loss_x_val_x: 0.9245 loss_x_val_y: 0.6897 time: 0.0518s
#  Epoch: 2930 loss_train: 0.0960 loss_x_train_x: 0.0293 loss_x_train_y: 0.0622 loss_val: 1.6144 loss_x_val_x: 0.9247 loss_x_val_y: 0.6898 time: 0.0517s
#  Epoch: 2931 loss_train: 0.0978 loss_x_train_x: 0.0290 loss_x_train_y: 0.0643 loss_val: 1.6138 loss_x_val_x: 0.9252 loss_x_val_y: 0.6886 time: 0.0519s
#  Epoch: 2932 loss_train: 0.0979 loss_x_train_x: 0.0291 loss_x_train_y: 0.0643 loss_val: 1.6155 loss_x_val_x: 0.9274 loss_x_val_y: 0.6881 time: 0.0519s
#  Epoch: 2933 loss_train: 0.0990 loss_x_train_x: 0.0290 loss_x_train_y: 0.0655 loss_val: 1.6146 loss_x_val_x: 0.9256 loss_x_val_y: 0.6890 time: 0.0522s
#  Epoch: 2934 loss_train: 0.1020 loss_x_train_x: 0.0305 loss_x_train_y: 0.0669 loss_val: 1.6136 loss_x_val_x: 0.9253 loss_x_val_y: 0.6883 time: 0.0516s
#  Epoch: 2935 loss_train: 0.0993 loss_x_train_x: 0.0298 loss_x_train_y: 0.0651 loss_val: 1.6180 loss_x_val_x: 0.9290 loss_x_val_y: 0.6890 time: 0.0516s
#  Epoch: 2936 loss_train: 0.0959 loss_x_train_x: 0.0282 loss_x_train_y: 0.0632 loss_val: 1.6156 loss_x_val_x: 0.9285 loss_x_val_y: 0.6870 time: 0.0527s
#  Epoch: 2937 loss_train: 0.0988 loss_x_train_x: 0.0294 loss_x_train_y: 0.0649 loss_val: 1.6153 loss_x_val_x: 0.9251 loss_x_val_y: 0.6902 time: 0.0528s
#  Epoch: 2938 loss_train: 0.1014 loss_x_train_x: 0.0308 loss_x_train_y: 0.0662 loss_val: 1.6123 loss_x_val_x: 0.9247 loss_x_val_y: 0.6877 time: 0.0516s
#  Epoch: 2939 loss_train: 0.0951 loss_x_train_x: 0.0270 loss_x_train_y: 0.0636 loss_val: 1.6149 loss_x_val_x: 0.9270 loss_x_val_y: 0.6879 time: 0.0522s
#  Epoch: 2940 loss_train: 0.0992 loss_x_train_x: 0.0280 loss_x_train_y: 0.0667 loss_val: 1.6175 loss_x_val_x: 0.9290 loss_x_val_y: 0.6886 time: 0.0517s
#  Epoch: 2941 loss_train: 0.0994 loss_x_train_x: 0.0301 loss_x_train_y: 0.0648 loss_val: 1.6186 loss_x_val_x: 0.9283 loss_x_val_y: 0.6903 time: 0.0518s
#  Epoch: 2942 loss_train: 0.1014 loss_x_train_x: 0.0322 loss_x_train_y: 0.0647 loss_val: 1.6214 loss_x_val_x: 0.9297 loss_x_val_y: 0.6917 time: 0.0525s
#  Epoch: 2943 loss_train: 0.1004 loss_x_train_x: 0.0307 loss_x_train_y: 0.0652 loss_val: 1.6181 loss_x_val_x: 0.9276 loss_x_val_y: 0.6905 time: 0.0519s
#  Epoch: 2944 loss_train: 0.1027 loss_x_train_x: 0.0311 loss_x_train_y: 0.0671 loss_val: 1.6178 loss_x_val_x: 0.9273 loss_x_val_y: 0.6905 time: 0.0517s
#  Epoch: 2945 loss_train: 0.1015 loss_x_train_x: 0.0314 loss_x_train_y: 0.0656 loss_val: 1.6196 loss_x_val_x: 0.9289 loss_x_val_y: 0.6907 time: 0.0516s
#  Epoch: 2946 loss_train: 0.1014 loss_x_train_x: 0.0300 loss_x_train_y: 0.0669 loss_val: 1.6203 loss_x_val_x: 0.9300 loss_x_val_y: 0.6903 time: 0.0521s
#  Epoch: 2947 loss_train: 0.1040 loss_x_train_x: 0.0319 loss_x_train_y: 0.0676 loss_val: 1.6131 loss_x_val_x: 0.9240 loss_x_val_y: 0.6890 time: 0.0519s
#  Epoch: 2948 loss_train: 0.1012 loss_x_train_x: 0.0300 loss_x_train_y: 0.0667 loss_val: 1.6172 loss_x_val_x: 0.9272 loss_x_val_y: 0.6900 time: 0.0520s
#  Epoch: 2949 loss_train: 0.1003 loss_x_train_x: 0.0285 loss_x_train_y: 0.0673 loss_val: 1.6154 loss_x_val_x: 0.9268 loss_x_val_y: 0.6885 time: 0.0523s
#  Epoch: 2950 loss_train: 0.1028 loss_x_train_x: 0.0285 loss_x_train_y: 0.0698 loss_val: 1.6156 loss_x_val_x: 0.9260 loss_x_val_y: 0.6896 time: 0.0524s
#  Epoch: 2951 loss_train: 0.0989 loss_x_train_x: 0.0295 loss_x_train_y: 0.0649 loss_val: 1.6165 loss_x_val_x: 0.9277 loss_x_val_y: 0.6888 time: 0.0527s
#  Epoch: 2952 loss_train: 0.0945 loss_x_train_x: 0.0283 loss_x_train_y: 0.0617 loss_val: 1.6167 loss_x_val_x: 0.9289 loss_x_val_y: 0.6878 time: 0.0516s
#  Epoch: 2953 loss_train: 0.0994 loss_x_train_x: 0.0310 loss_x_train_y: 0.0639 loss_val: 1.6147 loss_x_val_x: 0.9268 loss_x_val_y: 0.6880 time: 0.0515s
#  Epoch: 2954 loss_train: 0.0981 loss_x_train_x: 0.0302 loss_x_train_y: 0.0634 loss_val: 1.6177 loss_x_val_x: 0.9284 loss_x_val_y: 0.6893 time: 0.0520s
#  Epoch: 2955 loss_train: 0.0982 loss_x_train_x: 0.0301 loss_x_train_y: 0.0636 loss_val: 1.6151 loss_x_val_x: 0.9255 loss_x_val_y: 0.6897 time: 0.0524s
#  Epoch: 2956 loss_train: 0.1017 loss_x_train_x: 0.0297 loss_x_train_y: 0.0674 loss_val: 1.6140 loss_x_val_x: 0.9228 loss_x_val_y: 0.6912 time: 0.0521s
#  Epoch: 2957 loss_train: 0.0972 loss_x_train_x: 0.0313 loss_x_train_y: 0.0614 loss_val: 1.6168 loss_x_val_x: 0.9252 loss_x_val_y: 0.6916 time: 0.0514s
#  Epoch: 2958 loss_train: 0.0963 loss_x_train_x: 0.0293 loss_x_train_y: 0.0625 loss_val: 1.6155 loss_x_val_x: 0.9254 loss_x_val_y: 0.6900 time: 0.0518s
#  Epoch: 2959 loss_train: 0.1084 loss_x_train_x: 0.0358 loss_x_train_y: 0.0681 loss_val: 1.6175 loss_x_val_x: 0.9296 loss_x_val_y: 0.6879 time: 0.0521s
#  Epoch: 2960 loss_train: 0.0986 loss_x_train_x: 0.0297 loss_x_train_y: 0.0644 loss_val: 1.6145 loss_x_val_x: 0.9283 loss_x_val_y: 0.6862 time: 0.0521s
#  Epoch: 2961 loss_train: 0.0979 loss_x_train_x: 0.0291 loss_x_train_y: 0.0644 loss_val: 1.6164 loss_x_val_x: 0.9283 loss_x_val_y: 0.6880 time: 0.0522s
#  Epoch: 2962 loss_train: 0.1006 loss_x_train_x: 0.0304 loss_x_train_y: 0.0656 loss_val: 1.6206 loss_x_val_x: 0.9297 loss_x_val_y: 0.6909 time: 0.0518s
#  Epoch: 2963 loss_train: 0.0974 loss_x_train_x: 0.0303 loss_x_train_y: 0.0626 loss_val: 1.6171 loss_x_val_x: 0.9271 loss_x_val_y: 0.6900 time: 0.0514s
#  Epoch: 2964 loss_train: 0.1017 loss_x_train_x: 0.0292 loss_x_train_y: 0.0680 loss_val: 1.6165 loss_x_val_x: 0.9261 loss_x_val_y: 0.6904 time: 0.0524s
#  Epoch: 2965 loss_train: 0.0967 loss_x_train_x: 0.0282 loss_x_train_y: 0.0640 loss_val: 1.6128 loss_x_val_x: 0.9234 loss_x_val_y: 0.6894 time: 0.0517s
#  Epoch: 2966 loss_train: 0.0958 loss_x_train_x: 0.0271 loss_x_train_y: 0.0641 loss_val: 1.6141 loss_x_val_x: 0.9244 loss_x_val_y: 0.6897 time: 0.0514s
#  Epoch: 2967 loss_train: 0.0989 loss_x_train_x: 0.0301 loss_x_train_y: 0.0643 loss_val: 1.6155 loss_x_val_x: 0.9262 loss_x_val_y: 0.6893 time: 0.0516s
#  Epoch: 2968 loss_train: 0.0972 loss_x_train_x: 0.0300 loss_x_train_y: 0.0627 loss_val: 1.6143 loss_x_val_x: 0.9266 loss_x_val_y: 0.6877 time: 0.0524s
#  Epoch: 2969 loss_train: 0.0987 loss_x_train_x: 0.0312 loss_x_train_y: 0.0630 loss_val: 1.6171 loss_x_val_x: 0.9283 loss_x_val_y: 0.6887 time: 0.0517s
#  Epoch: 2970 loss_train: 0.1029 loss_x_train_x: 0.0309 loss_x_train_y: 0.0675 loss_val: 1.6144 loss_x_val_x: 0.9250 loss_x_val_y: 0.6894 time: 0.0524s
#  Epoch: 2971 loss_train: 0.0929 loss_x_train_x: 0.0284 loss_x_train_y: 0.0600 loss_val: 1.6151 loss_x_val_x: 0.9269 loss_x_val_y: 0.6882 time: 0.0514s
#  Epoch: 2972 loss_train: 0.0957 loss_x_train_x: 0.0282 loss_x_train_y: 0.0630 loss_val: 1.6145 loss_x_val_x: 0.9259 loss_x_val_y: 0.6886 time: 0.0518s
#  Epoch: 2973 loss_train: 0.0990 loss_x_train_x: 0.0284 loss_x_train_y: 0.0662 loss_val: 1.6125 loss_x_val_x: 0.9245 loss_x_val_y: 0.6880 time: 0.0523s
#  Epoch: 2974 loss_train: 0.0966 loss_x_train_x: 0.0304 loss_x_train_y: 0.0618 loss_val: 1.6112 loss_x_val_x: 0.9247 loss_x_val_y: 0.6865 time: 0.0516s
#  Epoch: 2975 loss_train: 0.0946 loss_x_train_x: 0.0286 loss_x_train_y: 0.0615 loss_val: 1.6113 loss_x_val_x: 0.9250 loss_x_val_y: 0.6863 time: 0.0521s
#  Epoch: 2976 loss_train: 0.0970 loss_x_train_x: 0.0270 loss_x_train_y: 0.0654 loss_val: 1.6092 loss_x_val_x: 0.9238 loss_x_val_y: 0.6854 time: 0.0517s
#  Epoch: 2977 loss_train: 0.1012 loss_x_train_x: 0.0306 loss_x_train_y: 0.0661 loss_val: 1.6117 loss_x_val_x: 0.9250 loss_x_val_y: 0.6868 time: 0.0523s
#  Epoch: 2978 loss_train: 0.0988 loss_x_train_x: 0.0301 loss_x_train_y: 0.0641 loss_val: 1.6116 loss_x_val_x: 0.9253 loss_x_val_y: 0.6863 time: 0.0517s
#  Epoch: 2979 loss_train: 0.0984 loss_x_train_x: 0.0307 loss_x_train_y: 0.0632 loss_val: 1.6146 loss_x_val_x: 0.9265 loss_x_val_y: 0.6882 time: 0.0528s
#  Epoch: 2980 loss_train: 0.1027 loss_x_train_x: 0.0317 loss_x_train_y: 0.0665 loss_val: 1.6150 loss_x_val_x: 0.9254 loss_x_val_y: 0.6896 time: 0.0515s
#  Epoch: 2981 loss_train: 0.0994 loss_x_train_x: 0.0281 loss_x_train_y: 0.0668 loss_val: 1.6129 loss_x_val_x: 0.9239 loss_x_val_y: 0.6890 time: 0.0514s
#  Epoch: 2982 loss_train: 0.0980 loss_x_train_x: 0.0296 loss_x_train_y: 0.0639 loss_val: 1.6102 loss_x_val_x: 0.9235 loss_x_val_y: 0.6867 time: 0.0512s
#  Epoch: 2983 loss_train: 0.0986 loss_x_train_x: 0.0271 loss_x_train_y: 0.0669 loss_val: 1.6123 loss_x_val_x: 0.9242 loss_x_val_y: 0.6881 time: 0.0530s
#  Epoch: 2984 loss_train: 0.1021 loss_x_train_x: 0.0327 loss_x_train_y: 0.0649 loss_val: 1.6124 loss_x_val_x: 0.9255 loss_x_val_y: 0.6869 time: 0.0521s
#  Epoch: 2985 loss_train: 0.1033 loss_x_train_x: 0.0322 loss_x_train_y: 0.0665 loss_val: 1.6148 loss_x_val_x: 0.9256 loss_x_val_y: 0.6893 time: 0.0512s
#  Epoch: 2986 loss_train: 0.0982 loss_x_train_x: 0.0282 loss_x_train_y: 0.0655 loss_val: 1.6151 loss_x_val_x: 0.9277 loss_x_val_y: 0.6874 time: 0.0520s
#  Epoch: 2987 loss_train: 0.0979 loss_x_train_x: 0.0301 loss_x_train_y: 0.0633 loss_val: 1.6115 loss_x_val_x: 0.9245 loss_x_val_y: 0.6870 time: 0.0524s
#  Epoch: 2988 loss_train: 0.1026 loss_x_train_x: 0.0322 loss_x_train_y: 0.0659 loss_val: 1.6117 loss_x_val_x: 0.9226 loss_x_val_y: 0.6891 time: 0.0517s
#  Epoch: 2989 loss_train: 0.1000 loss_x_train_x: 0.0312 loss_x_train_y: 0.0642 loss_val: 1.6106 loss_x_val_x: 0.9221 loss_x_val_y: 0.6885 time: 0.0526s
#  Epoch: 2990 loss_train: 0.0979 loss_x_train_x: 0.0291 loss_x_train_y: 0.0643 loss_val: 1.6103 loss_x_val_x: 0.9223 loss_x_val_y: 0.6879 time: 0.0517s
#  Epoch: 2991 loss_train: 0.0951 loss_x_train_x: 0.0263 loss_x_train_y: 0.0643 loss_val: 1.6088 loss_x_val_x: 0.9227 loss_x_val_y: 0.6861 time: 0.0520s
#  Epoch: 2992 loss_train: 0.0989 loss_x_train_x: 0.0295 loss_x_train_y: 0.0650 loss_val: 1.6072 loss_x_val_x: 0.9213 loss_x_val_y: 0.6859 time: 0.0524s
#  Epoch: 2993 loss_train: 0.0935 loss_x_train_x: 0.0279 loss_x_train_y: 0.0611 loss_val: 1.6120 loss_x_val_x: 0.9244 loss_x_val_y: 0.6876 time: 0.0519s
#  Epoch: 2994 loss_train: 0.0965 loss_x_train_x: 0.0304 loss_x_train_y: 0.0616 loss_val: 1.6094 loss_x_val_x: 0.9229 loss_x_val_y: 0.6865 time: 0.0519s
#  Epoch: 2995 loss_train: 0.0942 loss_x_train_x: 0.0272 loss_x_train_y: 0.0624 loss_val: 1.6123 loss_x_val_x: 0.9233 loss_x_val_y: 0.6890 time: 0.0522s
#  Epoch: 2996 loss_train: 0.0977 loss_x_train_x: 0.0303 loss_x_train_y: 0.0630 loss_val: 1.6108 loss_x_val_x: 0.9210 loss_x_val_y: 0.6898 time: 0.0521s
#  Epoch: 2997 loss_train: 0.0983 loss_x_train_x: 0.0293 loss_x_train_y: 0.0645 loss_val: 1.6122 loss_x_val_x: 0.9220 loss_x_val_y: 0.6902 time: 0.0519s
#  Epoch: 2998 loss_train: 0.1002 loss_x_train_x: 0.0296 loss_x_train_y: 0.0661 loss_val: 1.6122 loss_x_val_x: 0.9218 loss_x_val_y: 0.6904 time: 0.0531s
#  Epoch: 2999 loss_train: 0.0978 loss_x_train_x: 0.0281 loss_x_train_y: 0.0653 loss_val: 1.6127 loss_x_val_x: 0.9252 loss_x_val_y: 0.6874 time: 0.0514s
#  total time: 168.2036s

# %%
with open(os.path.join(logsavepath,'train_loss_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_x_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_x_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_y_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss_y, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_y_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss_y, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNorm_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNormx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNormy_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm_y, output, pickle.HIGHEST_PROTOCOL)



plt.plot(np.arange(epochs),train_loss_x)
plt.plot(np.arange(epochs),val_loss_x)
# plt.plot(np.arange(epochs),train_loss_kl_ep)
plt.legend(['training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_x'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()



plt.plot(np.arange(epochs),train_loss_y)
plt.plot(np.arange(epochs),val_loss_y)
# plt.plot(np.arange(epochs),train_loss_kl_ep)
plt.legend(['training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_y'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()


plt.plot(np.arange(epochs),train_lNorm)
plt.plot(np.arange(epochs),train_lNorm_x)
plt.plot(np.arange(epochs),train_lNorm_y)
# plt.plot(np.arange(epochs),train_loss_kl_ep)
plt.legend(['shared l2','x l2','y l2'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_lNorm'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.2,3))
plt.plot(np.arange(epochs),train_loss_x)
plt.plot(np.arange(epochs),train_loss_y)
plt.legend(['Modality 1 reconstruction','Modality 2 reconstruction','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'fig_loss_xy'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.pdf'))
plt.show()



fig, ax = plt.subplots(figsize=(3,3))
plt.plot(np.arange(epochs),train_lNorm)
plt.plot(np.arange(epochs),train_lNorm_x)
plt.plot(np.arange(epochs),train_lNorm_y)
plt.legend(['Shared l2','Modality 1 l2','Modality 2 l2'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'fig_loss_lNorm'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.pdf'))
plt.show()

# %%
latent_shared=torch.nn.Embedding(X.shape[0],sharedSize)
latent_x=torch.nn.Embedding(X.shape[0],dSpecificSize)
latent_y=torch.nn.Embedding(X.shape[0],dSpecificSize)

loadEpoch='2000'
with open(os.path.join(modelsavepath,'latentx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_x.weight=pickle.load(output)
with open(os.path.join(modelsavepath,'latentShared_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_shared.weight=pickle.load( output)
with open(os.path.join(modelsavepath,'latenty_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_y.weight=pickle.load(output)
latent_x.weight.requires_grad=False
latent_shared.weight.requires_grad=False
latent_y.weight.requires_grad=False

# %%
n_neighbors=10
min_dist=0.25

reducer_sharedlatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_shared.weight[trainIdx_all].cpu().detach())

# %%
def plotembeddingbyCT(ctlist,savename,excludelist,embedding,savepath,plotname,plotdimx=0,plotdimy=1,savenameAdd='',img=None,ncolors=None,colorseq=None,s=2.5):
    
    celltypes=np.unique(ctlist)
    if ncolors is None:
        colortest=sns.color_palette("husl", celltypes.size)
        if colorseq is None:
            colorseq=np.arange(celltypes.size)
    else:
        colortest=sns.color_palette("husl", ncolors)
        if colorseq is None:
            colorseq=np.arange(ncolors)
    
    fig, ax = plt.subplots(dpi=400)
    if not img is None:
        plt.imshow(img)
    for ct in celltypes:
        if ct in excludelist:
            continue
        idx=(ctlist==ct)
        if not img is None:
            ax.scatter(
                embedding[idx, plotdimy],
                embedding[idx, plotdimx],
                color=colortest[colorseq[int(ct)]],label=ct,s=1.5,alpha=0.5
                )
        else:
            ax.scatter(
                embedding[idx, plotdimx],
                embedding[idx, plotdimy],
                color=colortest[colorseq[int(ct)]],label=ct,s=s,alpha=1
                )

    plt.gca().set_aspect('equal', 'datalim')
    fig.set_figheight(5)
    fig.set_figwidth(5)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.1,
                     box.width, box.height * 0.9])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
              fancybox=True,ncol=5, shadow=True,prop={'size': 6})
    plt.title(plotname+' embedding', fontsize=12)
    plt.savefig(os.path.join(savepath,savename+savenameAdd+'.pdf'))
    plt.close('all')
    
def plotembeddingbyCT_str(ctlist,savename,excludelist,embedding,savepath,plotname,plotdimx=0,plotdimy=1,savenameAdd=''):
    celltypes=np.unique(ctlist)
    celltypes_dict={}
    idx=0
    for ct in celltypes:
        celltypes_dict[ct]=idx
        idx+=1
        
    colortest=sns.color_palette("husl", celltypes.size)
    fig, ax = plt.subplots(dpi=400)
    for ct in celltypes:
        if ct in excludelist:
            continue
        idx=(ctlist==ct)
        ax.scatter(
            embedding[idx, plotdimx],
            embedding[idx, plotdimy],
            color=colortest[celltypes_dict[ct]],label=ct,s=1,alpha=0.5
#             color=colortest[int(ct)],label=ct,s=1.5,alpha=0.5
            )

    plt.gca().set_aspect('equal', 'datalim')
    fig.set_figheight(6)
    fig.set_figwidth(6)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.3,
                     box.width, box.height * 0.7])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), 
              fancybox=True, ncol=3, shadow=True, prop={'size': 6})
    plt.title(plotname, fontsize=12)
    plt.savefig(os.path.join(savepath,savename+savenameAdd+'.pdf'))
    plt.close('all')
    
    gc.collect()

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_shared_latent',[],reducer_sharedlatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_shared_latent',[],reducer_sharedlatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
reducer_ylatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_y.weight[trainIdx_all].cpu().detach())

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_Y_latent',[],reducer_ylatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_Y_latent',[],reducer_ylatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
reducer_xlatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_x.weight[trainIdx_all].cpu().detach())

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_X_latent',[],reducer_xlatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_X_latent',[],reducer_xlatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(latent_shared.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.4527325

# %%
silhouette_score(latent_shared.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.091711864

# %%
silhouette_score(latent_x.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.6553604

# %%
silhouette_score(latent_x.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.06427653

# %%
silhouette_score(latent_y.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.06796244

# %%
silhouette_score(latent_y.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.008013854
