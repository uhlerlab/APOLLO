# %%
import sys
sys.path.append('/home/xinyiz/c2p_dag/')
sys.path.append('/home/xinyiz/c2p_dag/img2seq/')

import numpy as np
import pickle
import os
import pandas as pd
from scipy import sparse

import time

import scanpy
import numpy as np

import torch
from torch import optim


import matplotlib.pyplot as plt
import seaborn as sns
import umap
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import anndata as ad
import gc


import gae.gae.optimizer as optimizer

import gae.gae.model
import gae.gae.model_lord
import gae.gae.preprocessing as preprocessing
# Out:
# 2025-05-27 16:42:48.731995: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nSamples= 2048

Z1 = np.random.binomial(1, 0.5, size=nSamples)

gamma2 = np.random.gamma(shape=5, scale=1, size=nSamples)
Z2 = Z1 + gamma2 * np.sqrt(0.0045) 

Z3 = np.random.binomial(1, 0.5, size=nSamples)

gamma4 = np.random.gamma(shape=2, scale=2, size=nSamples)
Z4 = 2 * Z2 + Z3 + gamma4 * np.sqrt(0.00125)

gamma5 = np.random.gamma(shape=3, scale=2, size=nSamples)
Z5 = Z2 + gamma5 * np.sqrt(0.0075)

Z = np.stack([Z1, Z2, Z3, Z4, Z5], axis=1)

# %%
variables = [Z1, Z2, Z3, Z4, Z5]
titles = ['Z1', 'Z2', 'Z3', 'Z4', 'Z5']

fig, axs = plt.subplots(1, 5, figsize=(20, 4))
for i, (z, title) in enumerate(zip(variables, titles)):
    axs[i].hist(z, bins=30, color='skyblue', edgecolor='black')
    axs[i].set_title(title)
    axs[i].set_xlabel('Value')
    axs[i].set_ylabel('Samples')
    axs[i].grid(True)

plt.tight_layout()
plt.savefig('z_distribution_childrenWeight.pdf')
plt.show()

# %%
Z
# Out:
# array([[1.        , 1.34115023, 0.        , 2.89747942, 1.65191602],
#        [0.        , 0.2020527 , 1.        , 1.66050696, 0.50674417],
#        [0.        , 0.44543555, 0.        , 0.94079424, 0.76608861],
#        ...,
#        [0.        , 0.32950244, 1.        , 2.01737627, 1.72049995],
#        [1.        , 1.37688603, 1.        , 3.89761592, 1.63835042],
#        [0.        , 0.34993491, 1.        , 1.78882582, 0.53932645]])

# %%
# Initialize X with zeros 
X = np.zeros((nSamples, 80))

Z_X = np.stack([Z1, Z2, Z3, Z4], axis=1)

# X1-X10: pure children of Z4
G1 = np.random.randn(10, 1)*4
X[:, 0:10] = Z_X[:, [3]] @ G1.T

# X11-X20: pure children of Z3
G2 = np.random.randn(10, 1)*4
X[:, 10:20] = Z_X[:, [2]] @ G2.T

# X21-X30: pure children of Z2
G3 = np.random.randn(10, 1)*4
X[:, 20:30] = Z_X[:, [1]] @ G3.T

# X31-X40: children of Z2 and Z3
G4 = np.random.randn(10, 2)
X[:, 30:40] = Z_X[:, [1, 2]] @ G4.T

# X41-X50: children of Z2 and Z4
G5 = np.random.randn(10, 2)
X[:, 40:50] = Z_X[:, [1, 3]] @ G5.T

# X51-X60: children of Z3 and Z4
G6 = np.random.randn(10, 2)
X[:, 50:60] = Z_X[:, [2, 3]] @ G6.T

# X61-X70: children of Z2, Z3, Z4
G7 = np.random.randn(10, 3)
X[:, 60:70] = Z_X[:, [1, 2, 3]] @ G7.T

G8 = np.random.randn(10, 4)
X[:, 70:80] = Z_X @ G8.T

Y = np.zeros((nSamples, 40))

Z_Y = np.stack([Z1, Z2, Z5], axis=1)

GY1 = np.random.randn(10, 1)*4
Y[:, 0:10] = Z_Y[:, [2]] @ GY1.T

GY2 = np.random.randn(10, 1)*4
Y[:, 10:20] = Z_Y[:, [1]] @ GY2.T

GY3 = np.random.randn(10, 2)
Y[:, 20:30] = Z_Y[:, [1, 2]] @ GY3.T

GY4 = np.random.randn(10, 3)
Y[:, 30:40] = Z_Y @ GY4.T

# %%
#train-test split
np.random.seed(3)
pctVal=0.05
pctTest=0.1

allIdx_all=np.arange(nSamples)
np.random.shuffle(allIdx_all)
valIdx_all=allIdx_all[:int(pctVal*nSamples)]
testIdx_all=allIdx_all[int(pctVal*nSamples):(int(pctVal*nSamples)+int(pctTest*nSamples))]
trainIdx_all=allIdx_all[(int(pctVal*nSamples)+int(pctTest*nSamples)):]

hiddenSize=20
sharedSize=2
dSpecificSize=2
seed=1
#test0: 5, 3

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
os.environ["CUDA_LAUNCH_BLOCKING"] = "2"
 

batchsize=256
saveFreq=100
epochs=3000
lr_latent=0.001
lr_decoder=0.0001
weight_decay=0

dropout=0.01
XreconWeight=20
ridgeL=0.01

addNoise=True
actDecay=0.001

testSaveName='lord_bce'
name='test5_noSharedRecon_childrenWeight'
logsavepath=os.path.join('/data/xinyi/c2p/simulation/results/log',testSaveName,name)
modelsavepath=os.path.join('/data/xinyi/c2p/simulation/results/models',testSaveName,name)
plotsavepath=os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName,name)

loss_x=torch.nn.MSELoss()
loss_y=torch.nn.MSELoss()

# %%
if not os.path.exists(os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName)):
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName))
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/models',testSaveName))
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/log',testSaveName))
if not os.path.exists(logsavepath):
    os.mkdir(logsavepath)
if not os.path.exists(modelsavepath):
    os.mkdir(modelsavepath)
if not os.path.exists(plotsavepath):
    os.mkdir(plotsavepath)
nFeatures_x=X.shape[1]
nFeatures_y=Y.shape[1]

# %%
def train(epoch):
    t = time.time()
    model_x.train()
    model_y.train()
    
    loss_all=0
    loss_x_train_all_x=0
    loss_x_train_all_y=0
    loss_lNorm_all=0
    loss_lNorm_all_x=0
    loss_lNorm_all_y=0
    
    ntrainBatches=int(np.ceil(trainIdx_all.shape[0]/batchsize))
    for i in range(ntrainBatches):
        trainIdx=trainIdx_all[i*batchsize:min((i+1)*batchsize,trainIdx_all.shape[0])]
        traintarget_x=torch.tensor(X[trainIdx]).cuda().float()
        traintarget_y=torch.tensor(Y[trainIdx]).cuda().float()
        trainIdx=torch.tensor(trainIdx)
        trainInput_shared=latent_shared(trainIdx).cuda().float()
        trainInput_x=latent_x(trainIdx).cuda().float()
        trainInput_y=latent_y(trainIdx).cuda().float()

        if addNoise:
            trainInput_shared=trainInput_shared+torch.randn_like(trainInput_shared)
            trainInput_x=trainInput_x+torch.randn_like(trainInput_x)
            trainInput_y=trainInput_y+torch.randn_like(trainInput_y)
            
        optimizer_x.zero_grad()
        optimizer_latent.zero_grad()
        optimizer_y.zero_grad()

        recon_x= model_x(torch.cat((trainInput_shared,trainInput_x),dim=1))
        y_recon = model_y(torch.cat((trainInput_shared,trainInput_y),dim=1))

        loss_x_train_x=loss_x(recon_x, traintarget_x)
        loss_x_train_y=loss_y(y_recon, traintarget_y)        
        loss=loss_x_train_x+loss_x_train_y
        
        if addNoise:
            loss_lNorm=torch.mean(torch.linalg.norm(latent_shared(trainIdx).cuda(),dim=1))/latent_shared.embedding_dim
            loss_lNorm_all+=loss_lNorm.item()
            loss+=loss_lNorm*actDecay
            
            loss_lNorm_x=torch.mean(torch.linalg.norm(latent_x(trainIdx).cuda(),dim=1))/latent_x.embedding_dim
            loss_lNorm_all_x+=loss_lNorm_x.item()
            loss+=loss_lNorm_x*actDecay
            
            loss_lNorm_y=torch.mean(torch.linalg.norm(latent_y(trainIdx).cuda(),dim=1))/latent_y.embedding_dim
            loss_lNorm_all_y+=loss_lNorm_y.item()
            loss+=loss_lNorm_y*actDecay
            
        
        loss_x_train_all_y+=loss_x_train_y.item()
        loss_x_train_all_x+=loss_x_train_x.item()
        loss_all+=loss.item()
        
            
        loss.backward()
        optimizer_x.step()
        optimizer_latent.step()
        optimizer_y.step()


    loss_x_train_all_y=loss_x_train_all_y/ntrainBatches
    loss_x_train_all_x=loss_x_train_all_x/ntrainBatches
    loss_all=loss_all/ntrainBatches
    if addNoise:
        loss_lNorm_all=loss_lNorm_all/ntrainBatches
        loss_lNorm_all_x=loss_lNorm_all_x/ntrainBatches
        loss_lNorm_all_y=loss_lNorm_all_y/ntrainBatches

    
    with torch.no_grad():
        model_x.eval()
        model_y.eval()
        loss_x_val_all_x=0
        loss_x_val_all_y=0
        loss_val_all=0
        nvalBatches=int(np.ceil(valIdx_all.shape[0]/batchsize))
        for i in range(nvalBatches):
            valIdx=valIdx_all[i*batchsize:min((i+1)*batchsize,valIdx_all.shape[0])]
            valtarget_x=torch.tensor(X[valIdx]).cuda().float()
            valtarget_y=torch.tensor(Y[valIdx]).cuda().float()
            valIdx=torch.tensor(valIdx)
            valInput_shared=latent_shared(valIdx).cuda().float()
            valInput_x=latent_x(valIdx).cuda().float()
            valInput_y=latent_y(valIdx).cuda().float()

            recon_x= model_x(torch.cat((valInput_shared,valInput_x),dim=1))
            y_recon = model_y(torch.cat((valInput_shared,valInput_y),dim=1))

            loss_x_val_x=loss_x(recon_x, valtarget_x)
            loss_x_val_y=loss_y(y_recon, valtarget_y)


            loss=loss_x_val_x+loss_x_val_y
            
            loss_x_val_all_x+=loss_x_val_x.item()
            loss_x_val_all_y+=loss_x_val_y.item()
            loss_val_all+=loss.item()

        loss_x_val_all_x=loss_x_val_all_x/nvalBatches
        loss_x_val_all_y=loss_x_val_all_y/nvalBatches
        loss_val_all=loss_val_all/nvalBatches
    
    print(' Epoch: {:04d}'.format(epoch),
          'loss_train: {:.4f}'.format(loss_all),
          'loss_x_train_x: {:.4f}'.format(loss_x_train_all_x),
          'loss_x_train_y: {:.4f}'.format(loss_x_train_all_y),
          'loss_val: {:.4f}'.format(loss_val_all),
          'loss_x_val_x: {:.4f}'.format(loss_x_val_all_x),
          'loss_x_val_y: {:.4f}'.format(loss_x_val_all_y),
          'time: {:.4f}s'.format(time.time() - t))
    return loss_all,loss_x_train_all_x,loss_x_train_all_y,loss_val_all,loss_x_val_all_x,loss_x_val_all_y,loss_lNorm_all,loss_lNorm_all_x,loss_lNorm_all_y

# %%
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.enabled = True

model_x = gae.gae.model_lord.fc_decode_l4(nFeatures_x,sharedSize+dSpecificSize,hiddenSize, dropout)
model_y = gae.gae.model_lord.fc_decode_l4(nFeatures_y, sharedSize+dSpecificSize,hiddenSize, dropout)


model_x.cuda()
model_y.cuda()

optimizer_x = optim.Adam(model_x.parameters(), lr=lr_decoder, weight_decay=weight_decay)
optimizer_y = optim.Adam(model_y.parameters(), lr=lr_decoder, weight_decay=weight_decay)

latent_shared=torch.nn.Embedding(X.shape[0],sharedSize)
latent_x=torch.nn.Embedding(X.shape[0],dSpecificSize)
latent_y=torch.nn.Embedding(X.shape[0],dSpecificSize)
optimizer_latent= torch.optim.Adam([latent_shared.weight,latent_x.weight,latent_y.weight], lr=lr_latent, weight_decay=weight_decay)

train_loss=[np.inf]*(epochs)
val_loss=[np.inf]*(epochs)

train_loss_x=[np.inf]*(epochs)
val_loss_x=[np.inf]*(epochs)

train_loss_y=[np.inf]*(epochs)
val_loss_y=[np.inf]*(epochs)

train_lNorm=[np.inf]*(epochs)
train_lNorm_x=[np.inf]*(epochs)
train_lNorm_y=[np.inf]*(epochs)

t_ep=time.time()

for ep in range(epochs):

    train_loss[ep],train_loss_x[ep],train_loss_y[ep],val_loss[ep],val_loss_x[ep],val_loss_y[ep],train_lNorm[ep],train_lNorm_x[ep],train_lNorm_y[ep]=train(ep)


    if ep%saveFreq == 0 and ep != 0:
        torch.save(model_x.cpu().state_dict(), os.path.join(modelsavepath,str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)+'_x.pt'))
        torch.save(model_y.cpu().state_dict(), os.path.join(modelsavepath,str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)+'_y.pt'))

        with open(os.path.join(modelsavepath,'latentx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_x.weight, output, pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(modelsavepath,'latentShared_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_shared.weight, output, pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(modelsavepath,'latenty_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_y.weight, output, pickle.HIGHEST_PROTOCOL)



    model_x.cuda()
    model_y.cuda()
    torch.cuda.empty_cache()
print(' total time: {:.4f}s'.format(time.time() - t_ep))
# Out:
#  Epoch: 0000 loss_train: 35.7244 loss_x_train_x: 19.6425 loss_x_train_y: 16.0800 loss_val: 35.8905 loss_x_val_x: 19.3329 loss_x_val_y: 16.5576 time: 0.6545s
#  Epoch: 0001 loss_train: 35.6768 loss_x_train_x: 19.6213 loss_x_train_y: 16.0536 loss_val: 35.9878 loss_x_val_x: 19.4326 loss_x_val_y: 16.5551 time: 0.0413s
#  Epoch: 0002 loss_train: 35.6171 loss_x_train_x: 19.5833 loss_x_train_y: 16.0319 loss_val: 36.0599 loss_x_val_x: 19.5011 loss_x_val_y: 16.5589 time: 0.0414s
#  Epoch: 0003 loss_train: 35.5629 loss_x_train_x: 19.5537 loss_x_train_y: 16.0073 loss_val: 36.1066 loss_x_val_x: 19.5365 loss_x_val_y: 16.5701 time: 0.0413s
#  Epoch: 0004 loss_train: 35.4915 loss_x_train_x: 19.5230 loss_x_train_y: 15.9666 loss_val: 36.1265 loss_x_val_x: 19.5503 loss_x_val_y: 16.5763 time: 0.0413s
#  Epoch: 0005 loss_train: 35.4404 loss_x_train_x: 19.5018 loss_x_train_y: 15.9367 loss_val: 36.1163 loss_x_val_x: 19.5446 loss_x_val_y: 16.5717 time: 0.0422s
#  Epoch: 0006 loss_train: 35.3742 loss_x_train_x: 19.4681 loss_x_train_y: 15.9043 loss_val: 36.0862 loss_x_val_x: 19.5280 loss_x_val_y: 16.5582 time: 0.0419s
#  Epoch: 0007 loss_train: 35.3181 loss_x_train_x: 19.4351 loss_x_train_y: 15.8812 loss_val: 36.0549 loss_x_val_x: 19.5098 loss_x_val_y: 16.5451 time: 0.0419s
#  Epoch: 0008 loss_train: 35.2499 loss_x_train_x: 19.4051 loss_x_train_y: 15.8430 loss_val: 36.0015 loss_x_val_x: 19.4893 loss_x_val_y: 16.5123 time: 0.0422s
#  Epoch: 0009 loss_train: 35.2101 loss_x_train_x: 19.3813 loss_x_train_y: 15.8269 loss_val: 35.9546 loss_x_val_x: 19.4677 loss_x_val_y: 16.4869 time: 0.0421s
#  Epoch: 0010 loss_train: 35.1458 loss_x_train_x: 19.3527 loss_x_train_y: 15.7913 loss_val: 35.9065 loss_x_val_x: 19.4410 loss_x_val_y: 16.4655 time: 0.0426s
#  Epoch: 0011 loss_train: 35.0721 loss_x_train_x: 19.3154 loss_x_train_y: 15.7548 loss_val: 35.8592 loss_x_val_x: 19.4147 loss_x_val_y: 16.4445 time: 0.0424s
#  Epoch: 0012 loss_train: 35.0177 loss_x_train_x: 19.2884 loss_x_train_y: 15.7274 loss_val: 35.7944 loss_x_val_x: 19.3860 loss_x_val_y: 16.4084 time: 0.0425s
#  Epoch: 0013 loss_train: 34.9707 loss_x_train_x: 19.2621 loss_x_train_y: 15.7067 loss_val: 35.7399 loss_x_val_x: 19.3623 loss_x_val_y: 16.3777 time: 0.0425s
#  Epoch: 0014 loss_train: 34.8961 loss_x_train_x: 19.2324 loss_x_train_y: 15.6619 loss_val: 35.6891 loss_x_val_x: 19.3370 loss_x_val_y: 16.3521 time: 0.0425s
#  Epoch: 0015 loss_train: 34.8553 loss_x_train_x: 19.2092 loss_x_train_y: 15.6442 loss_val: 35.6313 loss_x_val_x: 19.3070 loss_x_val_y: 16.3242 time: 0.0428s
#  Epoch: 0016 loss_train: 34.7971 loss_x_train_x: 19.1811 loss_x_train_y: 15.6141 loss_val: 35.5809 loss_x_val_x: 19.2836 loss_x_val_y: 16.2972 time: 0.0427s
#  Epoch: 0017 loss_train: 34.7352 loss_x_train_x: 19.1496 loss_x_train_y: 15.5837 loss_val: 35.5281 loss_x_val_x: 19.2610 loss_x_val_y: 16.2671 time: 0.0426s
#  Epoch: 0018 loss_train: 34.6735 loss_x_train_x: 19.1176 loss_x_train_y: 15.5540 loss_val: 35.4627 loss_x_val_x: 19.2255 loss_x_val_y: 16.2372 time: 0.0427s
#  Epoch: 0019 loss_train: 34.6162 loss_x_train_x: 19.0873 loss_x_train_y: 15.5270 loss_val: 35.4033 loss_x_val_x: 19.1935 loss_x_val_y: 16.2098 time: 0.0427s
#  Epoch: 0020 loss_train: 34.5614 loss_x_train_x: 19.0571 loss_x_train_y: 15.5024 loss_val: 35.3560 loss_x_val_x: 19.1749 loss_x_val_y: 16.1811 time: 0.0429s
#  Epoch: 0021 loss_train: 34.5030 loss_x_train_x: 19.0360 loss_x_train_y: 15.4651 loss_val: 35.2935 loss_x_val_x: 19.1421 loss_x_val_y: 16.1514 time: 0.0428s
#  Epoch: 0022 loss_train: 34.4568 loss_x_train_x: 19.0081 loss_x_train_y: 15.4468 loss_val: 35.2457 loss_x_val_x: 19.1232 loss_x_val_y: 16.1225 time: 0.0426s
#  Epoch: 0023 loss_train: 34.4082 loss_x_train_x: 18.9898 loss_x_train_y: 15.4166 loss_val: 35.1904 loss_x_val_x: 19.0937 loss_x_val_y: 16.0967 time: 0.0427s
#  Epoch: 0024 loss_train: 34.3347 loss_x_train_x: 18.9551 loss_x_train_y: 15.3777 loss_val: 35.1398 loss_x_val_x: 19.0680 loss_x_val_y: 16.0718 time: 0.0427s
#  Epoch: 0025 loss_train: 34.2825 loss_x_train_x: 18.9204 loss_x_train_y: 15.3603 loss_val: 35.0884 loss_x_val_x: 19.0386 loss_x_val_y: 16.0498 time: 0.0427s
#  Epoch: 0026 loss_train: 34.2187 loss_x_train_x: 18.8934 loss_x_train_y: 15.3234 loss_val: 35.0303 loss_x_val_x: 19.0068 loss_x_val_y: 16.0235 time: 0.0428s
#  Epoch: 0027 loss_train: 34.1745 loss_x_train_x: 18.8789 loss_x_train_y: 15.2938 loss_val: 34.9750 loss_x_val_x: 18.9856 loss_x_val_y: 15.9894 time: 0.0427s
#  Epoch: 0028 loss_train: 34.1146 loss_x_train_x: 18.8450 loss_x_train_y: 15.2676 loss_val: 34.9221 loss_x_val_x: 18.9541 loss_x_val_y: 15.9680 time: 0.0427s
#  Epoch: 0029 loss_train: 34.0535 loss_x_train_x: 18.8093 loss_x_train_y: 15.2423 loss_val: 34.8535 loss_x_val_x: 18.9252 loss_x_val_y: 15.9284 time: 0.0428s
#  Epoch: 0030 loss_train: 33.9993 loss_x_train_x: 18.7873 loss_x_train_y: 15.2102 loss_val: 34.8065 loss_x_val_x: 18.9085 loss_x_val_y: 15.8980 time: 0.0430s
#  Epoch: 0031 loss_train: 33.9426 loss_x_train_x: 18.7572 loss_x_train_y: 15.1835 loss_val: 34.7426 loss_x_val_x: 18.8727 loss_x_val_y: 15.8698 time: 0.0429s
#  Epoch: 0032 loss_train: 33.8827 loss_x_train_x: 18.7256 loss_x_train_y: 15.1552 loss_val: 34.6882 loss_x_val_x: 18.8509 loss_x_val_y: 15.8373 time: 0.0428s
#  Epoch: 0033 loss_train: 33.8386 loss_x_train_x: 18.6985 loss_x_train_y: 15.1382 loss_val: 34.6319 loss_x_val_x: 18.8235 loss_x_val_y: 15.8083 time: 0.0428s
#  Epoch: 0034 loss_train: 33.7816 loss_x_train_x: 18.6735 loss_x_train_y: 15.1062 loss_val: 34.5844 loss_x_val_x: 18.7991 loss_x_val_y: 15.7853 time: 0.0428s
#  Epoch: 0035 loss_train: 33.7371 loss_x_train_x: 18.6532 loss_x_train_y: 15.0820 loss_val: 34.5450 loss_x_val_x: 18.7820 loss_x_val_y: 15.7630 time: 0.0430s
#  Epoch: 0036 loss_train: 33.6785 loss_x_train_x: 18.6260 loss_x_train_y: 15.0507 loss_val: 34.4822 loss_x_val_x: 18.7537 loss_x_val_y: 15.7285 time: 0.0429s
#  Epoch: 0037 loss_train: 33.6225 loss_x_train_x: 18.5937 loss_x_train_y: 15.0269 loss_val: 34.4261 loss_x_val_x: 18.7278 loss_x_val_y: 15.6982 time: 0.0428s
#  Epoch: 0038 loss_train: 33.5520 loss_x_train_x: 18.5581 loss_x_train_y: 14.9920 loss_val: 34.3651 loss_x_val_x: 18.6951 loss_x_val_y: 15.6700 time: 0.0428s
#  Epoch: 0039 loss_train: 33.4888 loss_x_train_x: 18.5355 loss_x_train_y: 14.9514 loss_val: 34.3088 loss_x_val_x: 18.6661 loss_x_val_y: 15.6428 time: 0.0429s
#  Epoch: 0040 loss_train: 33.4440 loss_x_train_x: 18.5031 loss_x_train_y: 14.9390 loss_val: 34.2633 loss_x_val_x: 18.6393 loss_x_val_y: 15.6240 time: 0.0430s
#  Epoch: 0041 loss_train: 33.3938 loss_x_train_x: 18.4786 loss_x_train_y: 14.9133 loss_val: 34.2044 loss_x_val_x: 18.6113 loss_x_val_y: 15.5931 time: 0.0429s
#  Epoch: 0042 loss_train: 33.3311 loss_x_train_x: 18.4482 loss_x_train_y: 14.8810 loss_val: 34.1483 loss_x_val_x: 18.5837 loss_x_val_y: 15.5646 time: 0.0429s
#  Epoch: 0043 loss_train: 33.2774 loss_x_train_x: 18.4174 loss_x_train_y: 14.8582 loss_val: 34.1041 loss_x_val_x: 18.5594 loss_x_val_y: 15.5447 time: 0.0428s
#  Epoch: 0044 loss_train: 33.2259 loss_x_train_x: 18.4000 loss_x_train_y: 14.8241 loss_val: 34.0368 loss_x_val_x: 18.5240 loss_x_val_y: 15.5128 time: 0.0429s
#  Epoch: 0045 loss_train: 33.1582 loss_x_train_x: 18.3655 loss_x_train_y: 14.7909 loss_val: 33.9864 loss_x_val_x: 18.5028 loss_x_val_y: 15.4835 time: 0.0431s
#  Epoch: 0046 loss_train: 33.1024 loss_x_train_x: 18.3349 loss_x_train_y: 14.7656 loss_val: 33.9310 loss_x_val_x: 18.4796 loss_x_val_y: 15.4514 time: 0.0431s
#  Epoch: 0047 loss_train: 33.0609 loss_x_train_x: 18.3124 loss_x_train_y: 14.7466 loss_val: 33.8761 loss_x_val_x: 18.4543 loss_x_val_y: 15.4218 time: 0.0428s
#  Epoch: 0048 loss_train: 33.0062 loss_x_train_x: 18.2919 loss_x_train_y: 14.7124 loss_val: 33.8230 loss_x_val_x: 18.4249 loss_x_val_y: 15.3981 time: 0.0429s
#  Epoch: 0049 loss_train: 32.9425 loss_x_train_x: 18.2471 loss_x_train_y: 14.6935 loss_val: 33.7503 loss_x_val_x: 18.3958 loss_x_val_y: 15.3545 time: 0.0429s
#  Epoch: 0050 loss_train: 32.8836 loss_x_train_x: 18.2270 loss_x_train_y: 14.6547 loss_val: 33.6870 loss_x_val_x: 18.3652 loss_x_val_y: 15.3218 time: 0.0430s
#  Epoch: 0051 loss_train: 32.8473 loss_x_train_x: 18.2131 loss_x_train_y: 14.6323 loss_val: 33.6414 loss_x_val_x: 18.3466 loss_x_val_y: 15.2948 time: 0.0430s
#  Epoch: 0052 loss_train: 32.7812 loss_x_train_x: 18.1755 loss_x_train_y: 14.6038 loss_val: 33.5785 loss_x_val_x: 18.3209 loss_x_val_y: 15.2576 time: 0.0430s
#  Epoch: 0053 loss_train: 32.7087 loss_x_train_x: 18.1405 loss_x_train_y: 14.5663 loss_val: 33.5184 loss_x_val_x: 18.2900 loss_x_val_y: 15.2284 time: 0.0429s
#  Epoch: 0054 loss_train: 32.6769 loss_x_train_x: 18.1127 loss_x_train_y: 14.5623 loss_val: 33.4644 loss_x_val_x: 18.2668 loss_x_val_y: 15.1976 time: 0.0430s
#  Epoch: 0055 loss_train: 32.5919 loss_x_train_x: 18.0709 loss_x_train_y: 14.5192 loss_val: 33.4082 loss_x_val_x: 18.2374 loss_x_val_y: 15.1707 time: 0.0430s
#  Epoch: 0056 loss_train: 32.5605 loss_x_train_x: 18.0588 loss_x_train_y: 14.4998 loss_val: 33.3709 loss_x_val_x: 18.2196 loss_x_val_y: 15.1513 time: 0.0429s
#  Epoch: 0057 loss_train: 32.4794 loss_x_train_x: 18.0185 loss_x_train_y: 14.4590 loss_val: 33.3159 loss_x_val_x: 18.1890 loss_x_val_y: 15.1268 time: 0.0428s
#  Epoch: 0058 loss_train: 32.4327 loss_x_train_x: 17.9998 loss_x_train_y: 14.4310 loss_val: 33.2555 loss_x_val_x: 18.1518 loss_x_val_y: 15.1037 time: 0.0430s
#  Epoch: 0059 loss_train: 32.3772 loss_x_train_x: 17.9671 loss_x_train_y: 14.4082 loss_val: 33.2044 loss_x_val_x: 18.1287 loss_x_val_y: 15.0756 time: 0.0429s
#  Epoch: 0060 loss_train: 32.3166 loss_x_train_x: 17.9500 loss_x_train_y: 14.3647 loss_val: 33.1442 loss_x_val_x: 18.0997 loss_x_val_y: 15.0445 time: 0.0431s
#  Epoch: 0061 loss_train: 32.2818 loss_x_train_x: 17.9197 loss_x_train_y: 14.3602 loss_val: 33.0995 loss_x_val_x: 18.0791 loss_x_val_y: 15.0205 time: 0.0430s
#  Epoch: 0062 loss_train: 32.1755 loss_x_train_x: 17.8731 loss_x_train_y: 14.3005 loss_val: 33.0353 loss_x_val_x: 18.0453 loss_x_val_y: 14.9901 time: 0.0429s
#  Epoch: 0063 loss_train: 32.1455 loss_x_train_x: 17.8452 loss_x_train_y: 14.2985 loss_val: 32.9590 loss_x_val_x: 18.0064 loss_x_val_y: 14.9527 time: 0.0429s
#  Epoch: 0064 loss_train: 32.0701 loss_x_train_x: 17.8170 loss_x_train_y: 14.2513 loss_val: 32.9009 loss_x_val_x: 17.9839 loss_x_val_y: 14.9170 time: 0.0429s
#  Epoch: 0065 loss_train: 32.0300 loss_x_train_x: 17.7958 loss_x_train_y: 14.2323 loss_val: 32.8371 loss_x_val_x: 17.9453 loss_x_val_y: 14.8918 time: 0.0457s
#  Epoch: 0066 loss_train: 31.9632 loss_x_train_x: 17.7500 loss_x_train_y: 14.2113 loss_val: 32.7867 loss_x_val_x: 17.9274 loss_x_val_y: 14.8593 time: 0.0429s
#  Epoch: 0067 loss_train: 31.9115 loss_x_train_x: 17.7344 loss_x_train_y: 14.1753 loss_val: 32.7241 loss_x_val_x: 17.8969 loss_x_val_y: 14.8272 time: 0.0429s
#  Epoch: 0068 loss_train: 31.8511 loss_x_train_x: 17.6976 loss_x_train_y: 14.1516 loss_val: 32.6684 loss_x_val_x: 17.8614 loss_x_val_y: 14.8070 time: 0.0429s
#  Epoch: 0069 loss_train: 31.7942 loss_x_train_x: 17.6771 loss_x_train_y: 14.1152 loss_val: 32.6122 loss_x_val_x: 17.8402 loss_x_val_y: 14.7720 time: 0.0430s
#  Epoch: 0070 loss_train: 31.7418 loss_x_train_x: 17.6518 loss_x_train_y: 14.0881 loss_val: 32.5603 loss_x_val_x: 17.8111 loss_x_val_y: 14.7491 time: 0.0431s
#  Epoch: 0071 loss_train: 31.6892 loss_x_train_x: 17.6278 loss_x_train_y: 14.0595 loss_val: 32.5171 loss_x_val_x: 17.7824 loss_x_val_y: 14.7347 time: 0.0430s
#  Epoch: 0072 loss_train: 31.6533 loss_x_train_x: 17.6110 loss_x_train_y: 14.0404 loss_val: 32.4731 loss_x_val_x: 17.7587 loss_x_val_y: 14.7144 time: 0.0429s
#  Epoch: 0073 loss_train: 31.5668 loss_x_train_x: 17.5512 loss_x_train_y: 14.0138 loss_val: 32.3952 loss_x_val_x: 17.7301 loss_x_val_y: 14.6651 time: 0.0428s
#  Epoch: 0074 loss_train: 31.4506 loss_x_train_x: 17.5027 loss_x_train_y: 13.9460 loss_val: 32.3514 loss_x_val_x: 17.7125 loss_x_val_y: 14.6389 time: 0.0430s
#  Epoch: 0075 loss_train: 31.4412 loss_x_train_x: 17.4992 loss_x_train_y: 13.9401 loss_val: 32.2897 loss_x_val_x: 17.6774 loss_x_val_y: 14.6123 time: 0.0431s
#  Epoch: 0076 loss_train: 31.3907 loss_x_train_x: 17.4642 loss_x_train_y: 13.9246 loss_val: 32.2308 loss_x_val_x: 17.6551 loss_x_val_y: 14.5757 time: 0.0429s
#  Epoch: 0077 loss_train: 31.3479 loss_x_train_x: 17.4372 loss_x_train_y: 13.9088 loss_val: 32.1733 loss_x_val_x: 17.6213 loss_x_val_y: 14.5521 time: 0.0428s
#  Epoch: 0078 loss_train: 31.2431 loss_x_train_x: 17.3889 loss_x_train_y: 13.8524 loss_val: 32.1076 loss_x_val_x: 17.5924 loss_x_val_y: 14.5151 time: 0.0427s
#  Epoch: 0079 loss_train: 31.1893 loss_x_train_x: 17.3576 loss_x_train_y: 13.8297 loss_val: 32.0527 loss_x_val_x: 17.5628 loss_x_val_y: 14.4899 time: 0.0426s
#  Epoch: 0080 loss_train: 31.1548 loss_x_train_x: 17.3444 loss_x_train_y: 13.8085 loss_val: 31.9851 loss_x_val_x: 17.5322 loss_x_val_y: 14.4529 time: 0.0430s
#  Epoch: 0081 loss_train: 31.0925 loss_x_train_x: 17.3090 loss_x_train_y: 13.7816 loss_val: 31.9376 loss_x_val_x: 17.5112 loss_x_val_y: 14.4265 time: 0.0427s
#  Epoch: 0082 loss_train: 31.0183 loss_x_train_x: 17.2633 loss_x_train_y: 13.7531 loss_val: 31.8908 loss_x_val_x: 17.4969 loss_x_val_y: 14.3939 time: 0.0427s
#  Epoch: 0083 loss_train: 30.9509 loss_x_train_x: 17.2410 loss_x_train_y: 13.7081 loss_val: 31.8421 loss_x_val_x: 17.4744 loss_x_val_y: 14.3677 time: 0.0427s
#  Epoch: 0084 loss_train: 30.8984 loss_x_train_x: 17.2153 loss_x_train_y: 13.6813 loss_val: 31.7682 loss_x_val_x: 17.4440 loss_x_val_y: 14.3242 time: 0.0427s
#  Epoch: 0085 loss_train: 30.8400 loss_x_train_x: 17.1792 loss_x_train_y: 13.6589 loss_val: 31.7286 loss_x_val_x: 17.4109 loss_x_val_y: 14.3177 time: 0.0428s
#  Epoch: 0086 loss_train: 30.7783 loss_x_train_x: 17.1440 loss_x_train_y: 13.6324 loss_val: 31.6485 loss_x_val_x: 17.3720 loss_x_val_y: 14.2764 time: 0.0426s
#  Epoch: 0087 loss_train: 30.6962 loss_x_train_x: 17.1018 loss_x_train_y: 13.5925 loss_val: 31.5961 loss_x_val_x: 17.3333 loss_x_val_y: 14.2628 time: 0.0426s
#  Epoch: 0088 loss_train: 30.6453 loss_x_train_x: 17.0798 loss_x_train_y: 13.5636 loss_val: 31.5563 loss_x_val_x: 17.3133 loss_x_val_y: 14.2429 time: 0.0426s
#  Epoch: 0089 loss_train: 30.6092 loss_x_train_x: 17.0542 loss_x_train_y: 13.5530 loss_val: 31.4932 loss_x_val_x: 17.2776 loss_x_val_y: 14.2156 time: 0.0428s
#  Epoch: 0090 loss_train: 30.5326 loss_x_train_x: 17.0146 loss_x_train_y: 13.5161 loss_val: 31.4154 loss_x_val_x: 17.2374 loss_x_val_y: 14.1781 time: 0.0430s
#  Epoch: 0091 loss_train: 30.4715 loss_x_train_x: 16.9900 loss_x_train_y: 13.4796 loss_val: 31.3493 loss_x_val_x: 17.2160 loss_x_val_y: 14.1333 time: 0.0427s
#  Epoch: 0092 loss_train: 30.4126 loss_x_train_x: 16.9594 loss_x_train_y: 13.4513 loss_val: 31.3216 loss_x_val_x: 17.1962 loss_x_val_y: 14.1254 time: 0.0427s
#  Epoch: 0093 loss_train: 30.3478 loss_x_train_x: 16.9133 loss_x_train_y: 13.4326 loss_val: 31.2425 loss_x_val_x: 17.1619 loss_x_val_y: 14.0805 time: 0.0426s
#  Epoch: 0094 loss_train: 30.3187 loss_x_train_x: 16.9057 loss_x_train_y: 13.4111 loss_val: 31.1880 loss_x_val_x: 17.1334 loss_x_val_y: 14.0546 time: 0.0427s
#  Epoch: 0095 loss_train: 30.2241 loss_x_train_x: 16.8481 loss_x_train_y: 13.3742 loss_val: 31.1505 loss_x_val_x: 17.1294 loss_x_val_y: 14.0210 time: 0.0429s
#  Epoch: 0096 loss_train: 30.1588 loss_x_train_x: 16.8224 loss_x_train_y: 13.3345 loss_val: 31.0867 loss_x_val_x: 17.1069 loss_x_val_y: 13.9798 time: 0.0427s
#  Epoch: 0097 loss_train: 30.1099 loss_x_train_x: 16.8112 loss_x_train_y: 13.2968 loss_val: 31.0179 loss_x_val_x: 17.0722 loss_x_val_y: 13.9457 time: 0.0427s
#  Epoch: 0098 loss_train: 30.0553 loss_x_train_x: 16.7575 loss_x_train_y: 13.2959 loss_val: 30.9435 loss_x_val_x: 17.0406 loss_x_val_y: 13.9029 time: 0.0427s
#  Epoch: 0099 loss_train: 30.0212 loss_x_train_x: 16.7538 loss_x_train_y: 13.2656 loss_val: 30.8896 loss_x_val_x: 17.0119 loss_x_val_y: 13.8776 time: 0.0427s
#  Epoch: 0100 loss_train: 29.9033 loss_x_train_x: 16.6684 loss_x_train_y: 13.2330 loss_val: 30.8341 loss_x_val_x: 16.9908 loss_x_val_y: 13.8433 time: 0.0427s
#  Epoch: 0101 loss_train: 29.8435 loss_x_train_x: 16.6446 loss_x_train_y: 13.1970 loss_val: 30.7722 loss_x_val_x: 16.9357 loss_x_val_y: 13.8366 time: 0.0428s
#  Epoch: 0102 loss_train: 29.7978 loss_x_train_x: 16.6355 loss_x_train_y: 13.1603 loss_val: 30.7140 loss_x_val_x: 16.9034 loss_x_val_y: 13.8106 time: 0.0427s
#  Epoch: 0103 loss_train: 29.7307 loss_x_train_x: 16.6106 loss_x_train_y: 13.1182 loss_val: 30.6612 loss_x_val_x: 16.8833 loss_x_val_y: 13.7780 time: 0.0427s
#  Epoch: 0104 loss_train: 29.6562 loss_x_train_x: 16.5579 loss_x_train_y: 13.0964 loss_val: 30.6212 loss_x_val_x: 16.8593 loss_x_val_y: 13.7619 time: 0.0427s
#  Epoch: 0105 loss_train: 29.6176 loss_x_train_x: 16.5325 loss_x_train_y: 13.0832 loss_val: 30.5782 loss_x_val_x: 16.8386 loss_x_val_y: 13.7396 time: 0.0430s
#  Epoch: 0106 loss_train: 29.5462 loss_x_train_x: 16.5152 loss_x_train_y: 13.0291 loss_val: 30.4993 loss_x_val_x: 16.8033 loss_x_val_y: 13.6960 time: 0.0427s
#  Epoch: 0107 loss_train: 29.4750 loss_x_train_x: 16.4540 loss_x_train_y: 13.0191 loss_val: 30.4485 loss_x_val_x: 16.7721 loss_x_val_y: 13.6764 time: 0.0405s
#  Epoch: 0108 loss_train: 29.4387 loss_x_train_x: 16.4497 loss_x_train_y: 12.9872 loss_val: 30.3957 loss_x_val_x: 16.7494 loss_x_val_y: 13.6464 time: 0.0403s
#  Epoch: 0109 loss_train: 29.3848 loss_x_train_x: 16.4199 loss_x_train_y: 12.9630 loss_val: 30.3226 loss_x_val_x: 16.6958 loss_x_val_y: 13.6268 time: 0.0402s
#  Epoch: 0110 loss_train: 29.3090 loss_x_train_x: 16.3790 loss_x_train_y: 12.9282 loss_val: 30.2444 loss_x_val_x: 16.6717 loss_x_val_y: 13.5727 time: 0.0408s
#  Epoch: 0111 loss_train: 29.2349 loss_x_train_x: 16.3460 loss_x_train_y: 12.8870 loss_val: 30.1778 loss_x_val_x: 16.6256 loss_x_val_y: 13.5522 time: 0.0402s
#  Epoch: 0112 loss_train: 29.1899 loss_x_train_x: 16.3044 loss_x_train_y: 12.8836 loss_val: 30.1386 loss_x_val_x: 16.6065 loss_x_val_y: 13.5321 time: 0.0402s
#  Epoch: 0113 loss_train: 29.0871 loss_x_train_x: 16.2595 loss_x_train_y: 12.8257 loss_val: 30.0735 loss_x_val_x: 16.5686 loss_x_val_y: 13.5048 time: 0.0402s
#  Epoch: 0114 loss_train: 29.0647 loss_x_train_x: 16.2556 loss_x_train_y: 12.8073 loss_val: 30.0275 loss_x_val_x: 16.5510 loss_x_val_y: 13.4765 time: 0.0481s
#  Epoch: 0115 loss_train: 28.9803 loss_x_train_x: 16.1871 loss_x_train_y: 12.7913 loss_val: 29.9822 loss_x_val_x: 16.5316 loss_x_val_y: 13.4506 time: 0.0400s
#  Epoch: 0116 loss_train: 28.9181 loss_x_train_x: 16.1788 loss_x_train_y: 12.7374 loss_val: 29.9163 loss_x_val_x: 16.4944 loss_x_val_y: 13.4218 time: 0.0482s
#  Epoch: 0117 loss_train: 28.8561 loss_x_train_x: 16.1302 loss_x_train_y: 12.7241 loss_val: 29.8539 loss_x_val_x: 16.4787 loss_x_val_y: 13.3752 time: 0.0403s
#  Epoch: 0118 loss_train: 28.8004 loss_x_train_x: 16.1118 loss_x_train_y: 12.6867 loss_val: 29.7961 loss_x_val_x: 16.4479 loss_x_val_y: 13.3482 time: 0.0402s
#  Epoch: 0119 loss_train: 28.7745 loss_x_train_x: 16.0979 loss_x_train_y: 12.6747 loss_val: 29.7490 loss_x_val_x: 16.4199 loss_x_val_y: 13.3291 time: 0.0403s
#  Epoch: 0120 loss_train: 28.7118 loss_x_train_x: 16.0643 loss_x_train_y: 12.6456 loss_val: 29.6732 loss_x_val_x: 16.3778 loss_x_val_y: 13.2954 time: 0.0405s
#  Epoch: 0121 loss_train: 28.6048 loss_x_train_x: 15.9999 loss_x_train_y: 12.6031 loss_val: 29.6251 loss_x_val_x: 16.3535 loss_x_val_y: 13.2717 time: 0.0402s
#  Epoch: 0122 loss_train: 28.5687 loss_x_train_x: 15.9857 loss_x_train_y: 12.5812 loss_val: 29.5435 loss_x_val_x: 16.3100 loss_x_val_y: 13.2335 time: 0.0490s
#  Epoch: 0123 loss_train: 28.5022 loss_x_train_x: 15.9486 loss_x_train_y: 12.5518 loss_val: 29.4702 loss_x_val_x: 16.2761 loss_x_val_y: 13.1941 time: 0.0399s
#  Epoch: 0124 loss_train: 28.4320 loss_x_train_x: 15.9159 loss_x_train_y: 12.5142 loss_val: 29.4212 loss_x_val_x: 16.2571 loss_x_val_y: 13.1642 time: 0.0398s
#  Epoch: 0125 loss_train: 28.3567 loss_x_train_x: 15.8586 loss_x_train_y: 12.4963 loss_val: 29.3595 loss_x_val_x: 16.2181 loss_x_val_y: 13.1414 time: 0.0464s
#  Epoch: 0126 loss_train: 28.3008 loss_x_train_x: 15.8364 loss_x_train_y: 12.4625 loss_val: 29.2946 loss_x_val_x: 16.1824 loss_x_val_y: 13.1122 time: 0.0397s
#  Epoch: 0127 loss_train: 28.2618 loss_x_train_x: 15.8025 loss_x_train_y: 12.4574 loss_val: 29.2342 loss_x_val_x: 16.1507 loss_x_val_y: 13.0835 time: 0.0401s
#  Epoch: 0128 loss_train: 28.1473 loss_x_train_x: 15.7748 loss_x_train_y: 12.3706 loss_val: 29.1806 loss_x_val_x: 16.1174 loss_x_val_y: 13.0632 time: 0.0402s
#  Epoch: 0129 loss_train: 28.0880 loss_x_train_x: 15.7359 loss_x_train_y: 12.3502 loss_val: 29.1496 loss_x_val_x: 16.0965 loss_x_val_y: 13.0531 time: 0.0403s
#  Epoch: 0130 loss_train: 28.0381 loss_x_train_x: 15.6958 loss_x_train_y: 12.3404 loss_val: 29.0850 loss_x_val_x: 16.0616 loss_x_val_y: 13.0234 time: 0.0406s
#  Epoch: 0131 loss_train: 27.9650 loss_x_train_x: 15.6585 loss_x_train_y: 12.3047 loss_val: 29.0489 loss_x_val_x: 16.0439 loss_x_val_y: 13.0050 time: 0.0484s
#  Epoch: 0132 loss_train: 27.9196 loss_x_train_x: 15.6234 loss_x_train_y: 12.2944 loss_val: 28.9622 loss_x_val_x: 15.9961 loss_x_val_y: 12.9661 time: 0.0397s
#  Epoch: 0133 loss_train: 27.8813 loss_x_train_x: 15.6199 loss_x_train_y: 12.2595 loss_val: 28.8687 loss_x_val_x: 15.9554 loss_x_val_y: 12.9133 time: 0.0476s
#  Epoch: 0134 loss_train: 27.8045 loss_x_train_x: 15.5756 loss_x_train_y: 12.2271 loss_val: 28.8108 loss_x_val_x: 15.9330 loss_x_val_y: 12.8778 time: 0.0398s
#  Epoch: 0135 loss_train: 27.7410 loss_x_train_x: 15.5496 loss_x_train_y: 12.1894 loss_val: 28.7774 loss_x_val_x: 15.9165 loss_x_val_y: 12.8610 time: 0.0402s
#  Epoch: 0136 loss_train: 27.6982 loss_x_train_x: 15.5267 loss_x_train_y: 12.1696 loss_val: 28.7204 loss_x_val_x: 15.8886 loss_x_val_y: 12.8318 time: 0.0439s
#  Epoch: 0137 loss_train: 27.5639 loss_x_train_x: 15.4419 loss_x_train_y: 12.1202 loss_val: 28.6492 loss_x_val_x: 15.8443 loss_x_val_y: 12.8049 time: 0.0403s
#  Epoch: 0138 loss_train: 27.5692 loss_x_train_x: 15.4440 loss_x_train_y: 12.1233 loss_val: 28.5600 loss_x_val_x: 15.7988 loss_x_val_y: 12.7612 time: 0.0402s
#  Epoch: 0139 loss_train: 27.4957 loss_x_train_x: 15.4002 loss_x_train_y: 12.0935 loss_val: 28.5189 loss_x_val_x: 15.7760 loss_x_val_y: 12.7429 time: 0.0402s
#  Epoch: 0140 loss_train: 27.4231 loss_x_train_x: 15.3665 loss_x_train_y: 12.0547 loss_val: 28.4723 loss_x_val_x: 15.7577 loss_x_val_y: 12.7146 time: 0.0406s
#  Epoch: 0141 loss_train: 27.3532 loss_x_train_x: 15.3251 loss_x_train_y: 12.0262 loss_val: 28.3991 loss_x_val_x: 15.7213 loss_x_val_y: 12.6778 time: 0.0402s
#  Epoch: 0142 loss_train: 27.2899 loss_x_train_x: 15.2958 loss_x_train_y: 11.9923 loss_val: 28.3452 loss_x_val_x: 15.7015 loss_x_val_y: 12.6437 time: 0.0401s
#  Epoch: 0143 loss_train: 27.2587 loss_x_train_x: 15.2688 loss_x_train_y: 11.9880 loss_val: 28.3178 loss_x_val_x: 15.6740 loss_x_val_y: 12.6439 time: 0.0402s
#  Epoch: 0144 loss_train: 27.1251 loss_x_train_x: 15.2159 loss_x_train_y: 11.9073 loss_val: 28.2520 loss_x_val_x: 15.6352 loss_x_val_y: 12.6169 time: 0.0403s
#  Epoch: 0145 loss_train: 27.0820 loss_x_train_x: 15.1875 loss_x_train_y: 11.8926 loss_val: 28.2106 loss_x_val_x: 15.6366 loss_x_val_y: 12.5740 time: 0.0404s
#  Epoch: 0146 loss_train: 27.0465 loss_x_train_x: 15.1770 loss_x_train_y: 11.8676 loss_val: 28.1413 loss_x_val_x: 15.5924 loss_x_val_y: 12.5489 time: 0.0402s
#  Epoch: 0147 loss_train: 26.9820 loss_x_train_x: 15.1252 loss_x_train_y: 11.8550 loss_val: 28.0956 loss_x_val_x: 15.5604 loss_x_val_y: 12.5352 time: 0.0401s
#  Epoch: 0148 loss_train: 26.9134 loss_x_train_x: 15.0960 loss_x_train_y: 11.8156 loss_val: 28.0587 loss_x_val_x: 15.5493 loss_x_val_y: 12.5093 time: 0.0400s
#  Epoch: 0149 loss_train: 26.8514 loss_x_train_x: 15.0630 loss_x_train_y: 11.7866 loss_val: 27.9900 loss_x_val_x: 15.5150 loss_x_val_y: 12.4750 time: 0.0401s
#  Epoch: 0150 loss_train: 26.7867 loss_x_train_x: 15.0175 loss_x_train_y: 11.7674 loss_val: 27.9146 loss_x_val_x: 15.4783 loss_x_val_y: 12.4363 time: 0.0404s
#  Epoch: 0151 loss_train: 26.7351 loss_x_train_x: 15.0028 loss_x_train_y: 11.7304 loss_val: 27.8503 loss_x_val_x: 15.4416 loss_x_val_y: 12.4087 time: 0.0402s
#  Epoch: 0152 loss_train: 26.6561 loss_x_train_x: 14.9557 loss_x_train_y: 11.6985 loss_val: 27.7900 loss_x_val_x: 15.4105 loss_x_val_y: 12.3795 time: 0.0401s
#  Epoch: 0153 loss_train: 26.5925 loss_x_train_x: 14.9218 loss_x_train_y: 11.6688 loss_val: 27.7325 loss_x_val_x: 15.3852 loss_x_val_y: 12.3473 time: 0.0401s
#  Epoch: 0154 loss_train: 26.5631 loss_x_train_x: 14.9083 loss_x_train_y: 11.6529 loss_val: 27.6666 loss_x_val_x: 15.3330 loss_x_val_y: 12.3336 time: 0.0401s
#  Epoch: 0155 loss_train: 26.4600 loss_x_train_x: 14.8432 loss_x_train_y: 11.6149 loss_val: 27.6224 loss_x_val_x: 15.3176 loss_x_val_y: 12.3049 time: 0.0403s
#  Epoch: 0156 loss_train: 26.3630 loss_x_train_x: 14.8048 loss_x_train_y: 11.5563 loss_val: 27.5382 loss_x_val_x: 15.2844 loss_x_val_y: 12.2538 time: 0.0402s
#  Epoch: 0157 loss_train: 26.3296 loss_x_train_x: 14.7836 loss_x_train_y: 11.5441 loss_val: 27.4361 loss_x_val_x: 15.2213 loss_x_val_y: 12.2148 time: 0.0401s
#  Epoch: 0158 loss_train: 26.2286 loss_x_train_x: 14.7285 loss_x_train_y: 11.4982 loss_val: 27.3948 loss_x_val_x: 15.2003 loss_x_val_y: 12.1945 time: 0.0400s
#  Epoch: 0159 loss_train: 26.1663 loss_x_train_x: 14.6875 loss_x_train_y: 11.4769 loss_val: 27.3076 loss_x_val_x: 15.1574 loss_x_val_y: 12.1502 time: 0.0401s
#  Epoch: 0160 loss_train: 26.1710 loss_x_train_x: 14.6995 loss_x_train_y: 11.4696 loss_val: 27.2761 loss_x_val_x: 15.1160 loss_x_val_y: 12.1601 time: 0.0404s
#  Epoch: 0161 loss_train: 26.1148 loss_x_train_x: 14.6656 loss_x_train_y: 11.4473 loss_val: 27.2409 loss_x_val_x: 15.1207 loss_x_val_y: 12.1202 time: 0.0402s
#  Epoch: 0162 loss_train: 26.0874 loss_x_train_x: 14.6392 loss_x_train_y: 11.4463 loss_val: 27.1844 loss_x_val_x: 15.0928 loss_x_val_y: 12.0916 time: 0.0402s
#  Epoch: 0163 loss_train: 25.9503 loss_x_train_x: 14.5712 loss_x_train_y: 11.3772 loss_val: 27.1077 loss_x_val_x: 15.0525 loss_x_val_y: 12.0552 time: 0.0406s
#  Epoch: 0164 loss_train: 25.9014 loss_x_train_x: 14.5321 loss_x_train_y: 11.3674 loss_val: 27.0394 loss_x_val_x: 15.0167 loss_x_val_y: 12.0227 time: 0.0403s
#  Epoch: 0165 loss_train: 25.8601 loss_x_train_x: 14.5036 loss_x_train_y: 11.3546 loss_val: 26.9970 loss_x_val_x: 15.0007 loss_x_val_y: 11.9963 time: 0.0407s
#  Epoch: 0166 loss_train: 25.7697 loss_x_train_x: 14.4894 loss_x_train_y: 11.2785 loss_val: 26.9312 loss_x_val_x: 14.9643 loss_x_val_y: 11.9669 time: 0.0404s
#  Epoch: 0167 loss_train: 25.7144 loss_x_train_x: 14.4388 loss_x_train_y: 11.2737 loss_val: 26.8787 loss_x_val_x: 14.9224 loss_x_val_y: 11.9563 time: 0.0403s
#  Epoch: 0168 loss_train: 25.6536 loss_x_train_x: 14.4269 loss_x_train_y: 11.2248 loss_val: 26.8345 loss_x_val_x: 14.9017 loss_x_val_y: 11.9327 time: 0.0403s
#  Epoch: 0169 loss_train: 25.5638 loss_x_train_x: 14.3619 loss_x_train_y: 11.2000 loss_val: 26.7516 loss_x_val_x: 14.8672 loss_x_val_y: 11.8843 time: 0.0405s
#  Epoch: 0170 loss_train: 25.5415 loss_x_train_x: 14.3405 loss_x_train_y: 11.1991 loss_val: 26.6908 loss_x_val_x: 14.8361 loss_x_val_y: 11.8547 time: 0.0404s
#  Epoch: 0171 loss_train: 25.4303 loss_x_train_x: 14.3019 loss_x_train_y: 11.1265 loss_val: 26.6221 loss_x_val_x: 14.7998 loss_x_val_y: 11.8223 time: 0.0405s
#  Epoch: 0172 loss_train: 25.4075 loss_x_train_x: 14.2689 loss_x_train_y: 11.1367 loss_val: 26.5617 loss_x_val_x: 14.7773 loss_x_val_y: 11.7844 time: 0.0403s
#  Epoch: 0173 loss_train: 25.3135 loss_x_train_x: 14.2329 loss_x_train_y: 11.0787 loss_val: 26.5459 loss_x_val_x: 14.7717 loss_x_val_y: 11.7742 time: 0.0404s
#  Epoch: 0174 loss_train: 25.2612 loss_x_train_x: 14.1955 loss_x_train_y: 11.0638 loss_val: 26.4669 loss_x_val_x: 14.7220 loss_x_val_y: 11.7449 time: 0.0403s
#  Epoch: 0175 loss_train: 25.2317 loss_x_train_x: 14.1883 loss_x_train_y: 11.0416 loss_val: 26.4321 loss_x_val_x: 14.6782 loss_x_val_y: 11.7539 time: 0.0408s
#  Epoch: 0176 loss_train: 25.1329 loss_x_train_x: 14.1308 loss_x_train_y: 11.0001 loss_val: 26.3569 loss_x_val_x: 14.6401 loss_x_val_y: 11.7168 time: 0.0405s
#  Epoch: 0177 loss_train: 25.0883 loss_x_train_x: 14.1040 loss_x_train_y: 10.9824 loss_val: 26.2953 loss_x_val_x: 14.6122 loss_x_val_y: 11.6831 time: 0.0405s
#  Epoch: 0178 loss_train: 25.0085 loss_x_train_x: 14.0357 loss_x_train_y: 10.9709 loss_val: 26.2403 loss_x_val_x: 14.5937 loss_x_val_y: 11.6465 time: 0.0404s
#  Epoch: 0179 loss_train: 24.9954 loss_x_train_x: 14.0629 loss_x_train_y: 10.9307 loss_val: 26.1618 loss_x_val_x: 14.5388 loss_x_val_y: 11.6229 time: 0.0405s
#  Epoch: 0180 loss_train: 24.8909 loss_x_train_x: 13.9854 loss_x_train_y: 10.9036 loss_val: 26.1100 loss_x_val_x: 14.5157 loss_x_val_y: 11.5943 time: 0.0408s
#  Epoch: 0181 loss_train: 24.8741 loss_x_train_x: 13.9868 loss_x_train_y: 10.8853 loss_val: 26.0861 loss_x_val_x: 14.5075 loss_x_val_y: 11.5786 time: 0.0404s
#  Epoch: 0182 loss_train: 24.7646 loss_x_train_x: 13.9316 loss_x_train_y: 10.8311 loss_val: 26.0247 loss_x_val_x: 14.4827 loss_x_val_y: 11.5420 time: 0.0403s
#  Epoch: 0183 loss_train: 24.7064 loss_x_train_x: 13.9007 loss_x_train_y: 10.8038 loss_val: 25.9574 loss_x_val_x: 14.4449 loss_x_val_y: 11.5125 time: 0.0406s
#  Epoch: 0184 loss_train: 24.7164 loss_x_train_x: 13.8885 loss_x_train_y: 10.8259 loss_val: 25.8812 loss_x_val_x: 14.3974 loss_x_val_y: 11.4838 time: 0.0406s
#  Epoch: 0185 loss_train: 24.5792 loss_x_train_x: 13.8266 loss_x_train_y: 10.7508 loss_val: 25.8556 loss_x_val_x: 14.3881 loss_x_val_y: 11.4675 time: 0.0408s
#  Epoch: 0186 loss_train: 24.5115 loss_x_train_x: 13.7648 loss_x_train_y: 10.7448 loss_val: 25.8120 loss_x_val_x: 14.3630 loss_x_val_y: 11.4490 time: 0.0406s
#  Epoch: 0187 loss_train: 24.4696 loss_x_train_x: 13.7528 loss_x_train_y: 10.7149 loss_val: 25.7583 loss_x_val_x: 14.3280 loss_x_val_y: 11.4303 time: 0.0407s
#  Epoch: 0188 loss_train: 24.3900 loss_x_train_x: 13.7192 loss_x_train_y: 10.6689 loss_val: 25.7020 loss_x_val_x: 14.3034 loss_x_val_y: 11.3986 time: 0.0407s
#  Epoch: 0189 loss_train: 24.2925 loss_x_train_x: 13.6684 loss_x_train_y: 10.6222 loss_val: 25.6625 loss_x_val_x: 14.2887 loss_x_val_y: 11.3738 time: 0.0401s
#  Epoch: 0190 loss_train: 24.3107 loss_x_train_x: 13.6814 loss_x_train_y: 10.6274 loss_val: 25.5940 loss_x_val_x: 14.2338 loss_x_val_y: 11.3602 time: 0.0398s
#  Epoch: 0191 loss_train: 24.2312 loss_x_train_x: 13.6261 loss_x_train_y: 10.6032 loss_val: 25.5691 loss_x_val_x: 14.2342 loss_x_val_y: 11.3348 time: 0.0396s
#  Epoch: 0192 loss_train: 24.1277 loss_x_train_x: 13.5579 loss_x_train_y: 10.5679 loss_val: 25.4955 loss_x_val_x: 14.2144 loss_x_val_y: 11.2811 time: 0.0394s
#  Epoch: 0193 loss_train: 24.1205 loss_x_train_x: 13.5670 loss_x_train_y: 10.5516 loss_val: 25.4634 loss_x_val_x: 14.1827 loss_x_val_y: 11.2807 time: 0.0396s
#  Epoch: 0194 loss_train: 24.0368 loss_x_train_x: 13.5074 loss_x_train_y: 10.5275 loss_val: 25.4053 loss_x_val_x: 14.1609 loss_x_val_y: 11.2444 time: 0.0396s
#  Epoch: 0195 loss_train: 23.9651 loss_x_train_x: 13.4735 loss_x_train_y: 10.4897 loss_val: 25.3450 loss_x_val_x: 14.1124 loss_x_val_y: 11.2326 time: 0.0397s
#  Epoch: 0196 loss_train: 23.9041 loss_x_train_x: 13.4682 loss_x_train_y: 10.4340 loss_val: 25.2498 loss_x_val_x: 14.0724 loss_x_val_y: 11.1774 time: 0.0408s
#  Epoch: 0197 loss_train: 23.9225 loss_x_train_x: 13.4671 loss_x_train_y: 10.4535 loss_val: 25.1611 loss_x_val_x: 14.0263 loss_x_val_y: 11.1348 time: 0.0404s
#  Epoch: 0198 loss_train: 23.7736 loss_x_train_x: 13.3943 loss_x_train_y: 10.3775 loss_val: 25.1231 loss_x_val_x: 14.0056 loss_x_val_y: 11.1175 time: 0.0403s
#  Epoch: 0199 loss_train: 23.7450 loss_x_train_x: 13.3522 loss_x_train_y: 10.3909 loss_val: 25.0712 loss_x_val_x: 13.9752 loss_x_val_y: 11.0960 time: 0.0405s
#  Epoch: 0200 loss_train: 23.6757 loss_x_train_x: 13.3356 loss_x_train_y: 10.3382 loss_val: 25.0209 loss_x_val_x: 13.9474 loss_x_val_y: 11.0736 time: 0.0405s
#  Epoch: 0201 loss_train: 23.6460 loss_x_train_x: 13.3354 loss_x_train_y: 10.3087 loss_val: 24.9768 loss_x_val_x: 13.9284 loss_x_val_y: 11.0484 time: 0.0411s
#  Epoch: 0202 loss_train: 23.5434 loss_x_train_x: 13.2487 loss_x_train_y: 10.2929 loss_val: 24.8943 loss_x_val_x: 13.8870 loss_x_val_y: 11.0073 time: 0.0407s
#  Epoch: 0203 loss_train: 23.4887 loss_x_train_x: 13.2365 loss_x_train_y: 10.2503 loss_val: 24.8373 loss_x_val_x: 13.8624 loss_x_val_y: 10.9749 time: 0.0406s
#  Epoch: 0204 loss_train: 23.4292 loss_x_train_x: 13.1893 loss_x_train_y: 10.2380 loss_val: 24.7836 loss_x_val_x: 13.8394 loss_x_val_y: 10.9442 time: 0.0406s
#  Epoch: 0205 loss_train: 23.3467 loss_x_train_x: 13.1349 loss_x_train_y: 10.2100 loss_val: 24.7642 loss_x_val_x: 13.7996 loss_x_val_y: 10.9646 time: 0.0403s
#  Epoch: 0206 loss_train: 23.2848 loss_x_train_x: 13.1164 loss_x_train_y: 10.1666 loss_val: 24.6740 loss_x_val_x: 13.7763 loss_x_val_y: 10.8978 time: 0.0405s
#  Epoch: 0207 loss_train: 23.2686 loss_x_train_x: 13.0779 loss_x_train_y: 10.1888 loss_val: 24.6024 loss_x_val_x: 13.7336 loss_x_val_y: 10.8687 time: 0.0404s
#  Epoch: 0208 loss_train: 23.2241 loss_x_train_x: 13.0526 loss_x_train_y: 10.1696 loss_val: 24.5474 loss_x_val_x: 13.6966 loss_x_val_y: 10.8508 time: 0.0403s
#  Epoch: 0209 loss_train: 23.1945 loss_x_train_x: 13.0608 loss_x_train_y: 10.1318 loss_val: 24.4658 loss_x_val_x: 13.6505 loss_x_val_y: 10.8153 time: 0.0402s
#  Epoch: 0210 loss_train: 23.1175 loss_x_train_x: 13.0578 loss_x_train_y: 10.0578 loss_val: 24.4771 loss_x_val_x: 13.6635 loss_x_val_y: 10.8136 time: 0.0402s
#  Epoch: 0211 loss_train: 22.9954 loss_x_train_x: 12.9368 loss_x_train_y: 10.0566 loss_val: 24.4565 loss_x_val_x: 13.6494 loss_x_val_y: 10.8071 time: 0.0405s
#  Epoch: 0212 loss_train: 22.9717 loss_x_train_x: 12.9358 loss_x_train_y: 10.0340 loss_val: 24.4120 loss_x_val_x: 13.6428 loss_x_val_y: 10.7692 time: 0.0402s
#  Epoch: 0213 loss_train: 22.8611 loss_x_train_x: 12.8912 loss_x_train_y: 9.9680 loss_val: 24.3554 loss_x_val_x: 13.6062 loss_x_val_y: 10.7492 time: 0.0402s
#  Epoch: 0214 loss_train: 22.8800 loss_x_train_x: 12.8686 loss_x_train_y: 10.0094 loss_val: 24.2572 loss_x_val_x: 13.5354 loss_x_val_y: 10.7218 time: 0.0403s
#  Epoch: 0215 loss_train: 22.7881 loss_x_train_x: 12.8617 loss_x_train_y: 9.9245 loss_val: 24.2167 loss_x_val_x: 13.4948 loss_x_val_y: 10.7218 time: 0.0403s
#  Epoch: 0216 loss_train: 22.7352 loss_x_train_x: 12.7773 loss_x_train_y: 9.9560 loss_val: 24.1599 loss_x_val_x: 13.4793 loss_x_val_y: 10.6805 time: 0.0406s
#  Epoch: 0217 loss_train: 22.6646 loss_x_train_x: 12.7489 loss_x_train_y: 9.9138 loss_val: 24.1339 loss_x_val_x: 13.4632 loss_x_val_y: 10.6708 time: 0.0405s
#  Epoch: 0218 loss_train: 22.6003 loss_x_train_x: 12.7400 loss_x_train_y: 9.8584 loss_val: 24.0812 loss_x_val_x: 13.4322 loss_x_val_y: 10.6490 time: 0.0403s
#  Epoch: 0219 loss_train: 22.5375 loss_x_train_x: 12.6888 loss_x_train_y: 9.8468 loss_val: 24.0228 loss_x_val_x: 13.4103 loss_x_val_y: 10.6125 time: 0.0403s
#  Epoch: 0220 loss_train: 22.5751 loss_x_train_x: 12.7027 loss_x_train_y: 9.8705 loss_val: 23.9595 loss_x_val_x: 13.3772 loss_x_val_y: 10.5823 time: 0.0404s
#  Epoch: 0221 loss_train: 22.4482 loss_x_train_x: 12.6460 loss_x_train_y: 9.8004 loss_val: 23.9081 loss_x_val_x: 13.3535 loss_x_val_y: 10.5546 time: 0.0403s
#  Epoch: 0222 loss_train: 22.3851 loss_x_train_x: 12.6030 loss_x_train_y: 9.7803 loss_val: 23.8553 loss_x_val_x: 13.3414 loss_x_val_y: 10.5139 time: 0.0403s
#  Epoch: 0223 loss_train: 22.3508 loss_x_train_x: 12.5912 loss_x_train_y: 9.7577 loss_val: 23.7893 loss_x_val_x: 13.2955 loss_x_val_y: 10.4938 time: 0.0404s
#  Epoch: 0224 loss_train: 22.2137 loss_x_train_x: 12.5272 loss_x_train_y: 9.6847 loss_val: 23.7017 loss_x_val_x: 13.2388 loss_x_val_y: 10.4629 time: 0.0403s
#  Epoch: 0225 loss_train: 22.2506 loss_x_train_x: 12.5513 loss_x_train_y: 9.6974 loss_val: 23.6442 loss_x_val_x: 13.2111 loss_x_val_y: 10.4331 time: 0.0404s
#  Epoch: 0226 loss_train: 22.1653 loss_x_train_x: 12.5043 loss_x_train_y: 9.6591 loss_val: 23.5570 loss_x_val_x: 13.1609 loss_x_val_y: 10.3961 time: 0.0405s
#  Epoch: 0227 loss_train: 22.0547 loss_x_train_x: 12.4316 loss_x_train_y: 9.6212 loss_val: 23.5325 loss_x_val_x: 13.1372 loss_x_val_y: 10.3953 time: 0.0404s
#  Epoch: 0228 loss_train: 22.0115 loss_x_train_x: 12.4048 loss_x_train_y: 9.6048 loss_val: 23.4756 loss_x_val_x: 13.1110 loss_x_val_y: 10.3646 time: 0.0403s
#  Epoch: 0229 loss_train: 21.9734 loss_x_train_x: 12.3830 loss_x_train_y: 9.5885 loss_val: 23.4874 loss_x_val_x: 13.1253 loss_x_val_y: 10.3622 time: 0.0403s
#  Epoch: 0230 loss_train: 21.9218 loss_x_train_x: 12.3694 loss_x_train_y: 9.5505 loss_val: 23.3942 loss_x_val_x: 13.0801 loss_x_val_y: 10.3141 time: 0.0405s
#  Epoch: 0231 loss_train: 21.8951 loss_x_train_x: 12.3762 loss_x_train_y: 9.5170 loss_val: 23.3610 loss_x_val_x: 13.0578 loss_x_val_y: 10.3032 time: 0.0406s
#  Epoch: 0232 loss_train: 21.7605 loss_x_train_x: 12.2519 loss_x_train_y: 9.5067 loss_val: 23.3086 loss_x_val_x: 13.0304 loss_x_val_y: 10.2782 time: 0.0404s
#  Epoch: 0233 loss_train: 21.6930 loss_x_train_x: 12.2273 loss_x_train_y: 9.4637 loss_val: 23.2705 loss_x_val_x: 12.9943 loss_x_val_y: 10.2762 time: 0.0404s
#  Epoch: 0234 loss_train: 21.6531 loss_x_train_x: 12.1937 loss_x_train_y: 9.4575 loss_val: 23.2378 loss_x_val_x: 12.9942 loss_x_val_y: 10.2436 time: 0.0403s
#  Epoch: 0235 loss_train: 21.6591 loss_x_train_x: 12.2443 loss_x_train_y: 9.4130 loss_val: 23.1793 loss_x_val_x: 12.9531 loss_x_val_y: 10.2262 time: 0.0406s
#  Epoch: 0236 loss_train: 21.5829 loss_x_train_x: 12.1833 loss_x_train_y: 9.3976 loss_val: 23.0854 loss_x_val_x: 12.8939 loss_x_val_y: 10.1915 time: 0.0405s
#  Epoch: 0237 loss_train: 21.5667 loss_x_train_x: 12.1677 loss_x_train_y: 9.3972 loss_val: 23.0456 loss_x_val_x: 12.8809 loss_x_val_y: 10.1647 time: 0.0404s
#  Epoch: 0238 loss_train: 21.4974 loss_x_train_x: 12.0895 loss_x_train_y: 9.4060 loss_val: 23.0149 loss_x_val_x: 12.8862 loss_x_val_y: 10.1287 time: 0.0402s
#  Epoch: 0239 loss_train: 21.3758 loss_x_train_x: 12.0688 loss_x_train_y: 9.3051 loss_val: 22.9780 loss_x_val_x: 12.8749 loss_x_val_y: 10.1031 time: 0.0403s
#  Epoch: 0240 loss_train: 21.3575 loss_x_train_x: 12.0548 loss_x_train_y: 9.3008 loss_val: 22.9344 loss_x_val_x: 12.8484 loss_x_val_y: 10.0860 time: 0.0403s
#  Epoch: 0241 loss_train: 21.3408 loss_x_train_x: 12.0475 loss_x_train_y: 9.2915 loss_val: 22.8787 loss_x_val_x: 12.8131 loss_x_val_y: 10.0655 time: 0.0405s
#  Epoch: 0242 loss_train: 21.2006 loss_x_train_x: 11.9658 loss_x_train_y: 9.2330 loss_val: 22.8258 loss_x_val_x: 12.7789 loss_x_val_y: 10.0470 time: 0.0423s
#  Epoch: 0243 loss_train: 21.1486 loss_x_train_x: 11.9005 loss_x_train_y: 9.2462 loss_val: 22.7403 loss_x_val_x: 12.7358 loss_x_val_y: 10.0045 time: 0.0402s
#  Epoch: 0244 loss_train: 21.1145 loss_x_train_x: 11.9063 loss_x_train_y: 9.2063 loss_val: 22.6757 loss_x_val_x: 12.6958 loss_x_val_y: 9.9798 time: 0.0404s
#  Epoch: 0245 loss_train: 21.0936 loss_x_train_x: 11.8997 loss_x_train_y: 9.1920 loss_val: 22.6598 loss_x_val_x: 12.6809 loss_x_val_y: 9.9790 time: 0.0403s
#  Epoch: 0246 loss_train: 20.9870 loss_x_train_x: 11.8459 loss_x_train_y: 9.1392 loss_val: 22.5553 loss_x_val_x: 12.6228 loss_x_val_y: 9.9326 time: 0.0406s
#  Epoch: 0247 loss_train: 20.9441 loss_x_train_x: 11.8180 loss_x_train_y: 9.1242 loss_val: 22.5273 loss_x_val_x: 12.5996 loss_x_val_y: 9.9276 time: 0.0403s
#  Epoch: 0248 loss_train: 20.9333 loss_x_train_x: 11.8180 loss_x_train_y: 9.1134 loss_val: 22.5345 loss_x_val_x: 12.5807 loss_x_val_y: 9.9538 time: 0.0403s
#  Epoch: 0249 loss_train: 20.8165 loss_x_train_x: 11.7390 loss_x_train_y: 9.0756 loss_val: 22.4803 loss_x_val_x: 12.5673 loss_x_val_y: 9.9130 time: 0.0402s
#  Epoch: 0250 loss_train: 20.7871 loss_x_train_x: 11.7210 loss_x_train_y: 9.0642 loss_val: 22.4294 loss_x_val_x: 12.5476 loss_x_val_y: 9.8818 time: 0.0403s
#  Epoch: 0251 loss_train: 20.7125 loss_x_train_x: 11.6836 loss_x_train_y: 9.0270 loss_val: 22.3369 loss_x_val_x: 12.5049 loss_x_val_y: 9.8321 time: 0.0404s
#  Epoch: 0252 loss_train: 20.7207 loss_x_train_x: 11.6921 loss_x_train_y: 9.0267 loss_val: 22.2827 loss_x_val_x: 12.4977 loss_x_val_y: 9.7850 time: 0.0402s
#  Epoch: 0253 loss_train: 20.5954 loss_x_train_x: 11.6431 loss_x_train_y: 8.9504 loss_val: 22.2510 loss_x_val_x: 12.4725 loss_x_val_y: 9.7786 time: 0.0403s
#  Epoch: 0254 loss_train: 20.5417 loss_x_train_x: 11.5747 loss_x_train_y: 8.9651 loss_val: 22.2048 loss_x_val_x: 12.4426 loss_x_val_y: 9.7623 time: 0.0401s
#  Epoch: 0255 loss_train: 20.5545 loss_x_train_x: 11.6245 loss_x_train_y: 8.9282 loss_val: 22.1423 loss_x_val_x: 12.3981 loss_x_val_y: 9.7442 time: 0.0432s
#  Epoch: 0256 loss_train: 20.4628 loss_x_train_x: 11.5469 loss_x_train_y: 8.9140 loss_val: 22.1641 loss_x_val_x: 12.4173 loss_x_val_y: 9.7468 time: 0.0403s
#  Epoch: 0257 loss_train: 20.3495 loss_x_train_x: 11.4647 loss_x_train_y: 8.8829 loss_val: 22.1020 loss_x_val_x: 12.3690 loss_x_val_y: 9.7330 time: 0.0401s
#  Epoch: 0258 loss_train: 20.2560 loss_x_train_x: 11.4503 loss_x_train_y: 8.8038 loss_val: 22.0307 loss_x_val_x: 12.3356 loss_x_val_y: 9.6951 time: 0.0401s
#  Epoch: 0259 loss_train: 20.2681 loss_x_train_x: 11.4270 loss_x_train_y: 8.8392 loss_val: 21.9835 loss_x_val_x: 12.3306 loss_x_val_y: 9.6529 time: 0.0400s
#  Epoch: 0260 loss_train: 20.2428 loss_x_train_x: 11.4124 loss_x_train_y: 8.8285 loss_val: 21.8970 loss_x_val_x: 12.2723 loss_x_val_y: 9.6247 time: 0.0403s
#  Epoch: 0261 loss_train: 20.2237 loss_x_train_x: 11.4382 loss_x_train_y: 8.7836 loss_val: 21.8966 loss_x_val_x: 12.2833 loss_x_val_y: 9.6133 time: 0.0404s
#  Epoch: 0262 loss_train: 20.1414 loss_x_train_x: 11.3945 loss_x_train_y: 8.7450 loss_val: 21.8684 loss_x_val_x: 12.2697 loss_x_val_y: 9.5987 time: 0.0403s
#  Epoch: 0263 loss_train: 20.0935 loss_x_train_x: 11.3634 loss_x_train_y: 8.7282 loss_val: 21.7805 loss_x_val_x: 12.2217 loss_x_val_y: 9.5588 time: 0.0402s
#  Epoch: 0264 loss_train: 20.0843 loss_x_train_x: 11.3541 loss_x_train_y: 8.7283 loss_val: 21.7230 loss_x_val_x: 12.2052 loss_x_val_y: 9.5178 time: 0.0402s
#  Epoch: 0265 loss_train: 19.9918 loss_x_train_x: 11.2839 loss_x_train_y: 8.7060 loss_val: 21.6840 loss_x_val_x: 12.1675 loss_x_val_y: 9.5165 time: 0.0403s
#  Epoch: 0266 loss_train: 19.9963 loss_x_train_x: 11.3256 loss_x_train_y: 8.6687 loss_val: 21.6406 loss_x_val_x: 12.1260 loss_x_val_y: 9.5147 time: 0.0404s
#  Epoch: 0267 loss_train: 19.8602 loss_x_train_x: 11.2125 loss_x_train_y: 8.6458 loss_val: 21.6100 loss_x_val_x: 12.1104 loss_x_val_y: 9.4997 time: 0.0404s
#  Epoch: 0268 loss_train: 19.8111 loss_x_train_x: 11.1642 loss_x_train_y: 8.6450 loss_val: 21.5327 loss_x_val_x: 12.0699 loss_x_val_y: 9.4628 time: 0.0401s
#  Epoch: 0269 loss_train: 19.8118 loss_x_train_x: 11.2111 loss_x_train_y: 8.5988 loss_val: 21.4865 loss_x_val_x: 12.0559 loss_x_val_y: 9.4307 time: 0.0403s
#  Epoch: 0270 loss_train: 19.7391 loss_x_train_x: 11.1376 loss_x_train_y: 8.5995 loss_val: 21.4243 loss_x_val_x: 12.0476 loss_x_val_y: 9.3767 time: 0.0401s
#  Epoch: 0271 loss_train: 19.6444 loss_x_train_x: 11.1032 loss_x_train_y: 8.5392 loss_val: 21.4398 loss_x_val_x: 12.0501 loss_x_val_y: 9.3897 time: 0.0404s
#  Epoch: 0272 loss_train: 19.6107 loss_x_train_x: 11.0597 loss_x_train_y: 8.5490 loss_val: 21.4587 loss_x_val_x: 12.0615 loss_x_val_y: 9.3972 time: 0.0404s
#  Epoch: 0273 loss_train: 19.5460 loss_x_train_x: 11.0477 loss_x_train_y: 8.4963 loss_val: 21.4042 loss_x_val_x: 12.0468 loss_x_val_y: 9.3574 time: 0.0401s
#  Epoch: 0274 loss_train: 19.5181 loss_x_train_x: 11.0312 loss_x_train_y: 8.4850 loss_val: 21.3271 loss_x_val_x: 11.9966 loss_x_val_y: 9.3305 time: 0.0401s
#  Epoch: 0275 loss_train: 19.5288 loss_x_train_x: 11.0419 loss_x_train_y: 8.4850 loss_val: 21.2554 loss_x_val_x: 11.9520 loss_x_val_y: 9.3035 time: 0.0400s
#  Epoch: 0276 loss_train: 19.3641 loss_x_train_x: 10.9183 loss_x_train_y: 8.4439 loss_val: 21.1947 loss_x_val_x: 11.9093 loss_x_val_y: 9.2854 time: 0.0405s
#  Epoch: 0277 loss_train: 19.3719 loss_x_train_x: 10.9291 loss_x_train_y: 8.4409 loss_val: 21.1202 loss_x_val_x: 11.8625 loss_x_val_y: 9.2576 time: 0.0402s
#  Epoch: 0278 loss_train: 19.2677 loss_x_train_x: 10.9114 loss_x_train_y: 8.3544 loss_val: 21.0879 loss_x_val_x: 11.8427 loss_x_val_y: 9.2453 time: 0.0403s
#  Epoch: 0279 loss_train: 19.3051 loss_x_train_x: 10.9243 loss_x_train_y: 8.3789 loss_val: 21.0698 loss_x_val_x: 11.8312 loss_x_val_y: 9.2386 time: 0.0401s
#  Epoch: 0280 loss_train: 19.2792 loss_x_train_x: 10.9193 loss_x_train_y: 8.3580 loss_val: 21.0180 loss_x_val_x: 11.8047 loss_x_val_y: 9.2133 time: 0.0402s
#  Epoch: 0281 loss_train: 19.1422 loss_x_train_x: 10.8278 loss_x_train_y: 8.3124 loss_val: 20.9335 loss_x_val_x: 11.7688 loss_x_val_y: 9.1648 time: 0.0405s
#  Epoch: 0282 loss_train: 19.1435 loss_x_train_x: 10.8263 loss_x_train_y: 8.3153 loss_val: 20.8795 loss_x_val_x: 11.7354 loss_x_val_y: 9.1441 time: 0.0371s
#  Epoch: 0283 loss_train: 19.0237 loss_x_train_x: 10.7732 loss_x_train_y: 8.2486 loss_val: 20.8459 loss_x_val_x: 11.7296 loss_x_val_y: 9.1163 time: 0.0339s
#  Epoch: 0284 loss_train: 19.0261 loss_x_train_x: 10.7676 loss_x_train_y: 8.2566 loss_val: 20.8214 loss_x_val_x: 11.7065 loss_x_val_y: 9.1149 time: 0.0340s
#  Epoch: 0285 loss_train: 18.9644 loss_x_train_x: 10.7300 loss_x_train_y: 8.2325 loss_val: 20.7646 loss_x_val_x: 11.6624 loss_x_val_y: 9.1022 time: 0.0339s
#  Epoch: 0286 loss_train: 18.9118 loss_x_train_x: 10.6790 loss_x_train_y: 8.2309 loss_val: 20.7267 loss_x_val_x: 11.6573 loss_x_val_y: 9.0694 time: 0.0339s
#  Epoch: 0287 loss_train: 18.8046 loss_x_train_x: 10.6380 loss_x_train_y: 8.1646 loss_val: 20.6275 loss_x_val_x: 11.5932 loss_x_val_y: 9.0343 time: 0.0347s
#  Epoch: 0288 loss_train: 18.8549 loss_x_train_x: 10.6683 loss_x_train_y: 8.1846 loss_val: 20.5619 loss_x_val_x: 11.5533 loss_x_val_y: 9.0086 time: 0.0350s
#  Epoch: 0289 loss_train: 18.7705 loss_x_train_x: 10.6059 loss_x_train_y: 8.1627 loss_val: 20.5215 loss_x_val_x: 11.5408 loss_x_val_y: 8.9806 time: 0.0332s
#  Epoch: 0290 loss_train: 18.7457 loss_x_train_x: 10.5891 loss_x_train_y: 8.1547 loss_val: 20.5183 loss_x_val_x: 11.5363 loss_x_val_y: 8.9820 time: 0.0332s
#  Epoch: 0291 loss_train: 18.6259 loss_x_train_x: 10.5254 loss_x_train_y: 8.0986 loss_val: 20.4737 loss_x_val_x: 11.5292 loss_x_val_y: 8.9445 time: 0.0331s
#  Epoch: 0292 loss_train: 18.5763 loss_x_train_x: 10.5055 loss_x_train_y: 8.0689 loss_val: 20.4530 loss_x_val_x: 11.5005 loss_x_val_y: 8.9525 time: 0.0332s
#  Epoch: 0293 loss_train: 18.5582 loss_x_train_x: 10.5177 loss_x_train_y: 8.0385 loss_val: 20.3806 loss_x_val_x: 11.4664 loss_x_val_y: 8.9142 time: 0.0438s
#  Epoch: 0294 loss_train: 18.5342 loss_x_train_x: 10.4820 loss_x_train_y: 8.0503 loss_val: 20.3431 loss_x_val_x: 11.4636 loss_x_val_y: 8.8795 time: 0.0345s
#  Epoch: 0295 loss_train: 18.4323 loss_x_train_x: 10.3946 loss_x_train_y: 8.0357 loss_val: 20.2700 loss_x_val_x: 11.4184 loss_x_val_y: 8.8516 time: 0.0335s
#  Epoch: 0296 loss_train: 18.3607 loss_x_train_x: 10.3834 loss_x_train_y: 7.9754 loss_val: 20.2299 loss_x_val_x: 11.3887 loss_x_val_y: 8.8411 time: 0.0363s
#  Epoch: 0297 loss_train: 18.3297 loss_x_train_x: 10.3679 loss_x_train_y: 7.9599 loss_val: 20.2044 loss_x_val_x: 11.3675 loss_x_val_y: 8.8369 time: 0.0362s
#  Epoch: 0298 loss_train: 18.2625 loss_x_train_x: 10.3541 loss_x_train_y: 7.9065 loss_val: 20.1825 loss_x_val_x: 11.3625 loss_x_val_y: 8.8200 time: 0.0357s
#  Epoch: 0299 loss_train: 18.1828 loss_x_train_x: 10.2681 loss_x_train_y: 7.9127 loss_val: 20.1310 loss_x_val_x: 11.3318 loss_x_val_y: 8.7992 time: 0.0360s
#  Epoch: 0300 loss_train: 18.1944 loss_x_train_x: 10.2927 loss_x_train_y: 7.8998 loss_val: 20.0943 loss_x_val_x: 11.3253 loss_x_val_y: 8.7691 time: 0.0352s
#  Epoch: 0301 loss_train: 18.1216 loss_x_train_x: 10.2569 loss_x_train_y: 7.8627 loss_val: 20.0387 loss_x_val_x: 11.2917 loss_x_val_y: 8.7470 time: 0.0338s
#  Epoch: 0302 loss_train: 18.1195 loss_x_train_x: 10.2754 loss_x_train_y: 7.8422 loss_val: 20.0108 loss_x_val_x: 11.2528 loss_x_val_y: 8.7580 time: 0.0349s
#  Epoch: 0303 loss_train: 18.0731 loss_x_train_x: 10.2280 loss_x_train_y: 7.8431 loss_val: 19.9825 loss_x_val_x: 11.2640 loss_x_val_y: 8.7185 time: 0.0350s
#  Epoch: 0304 loss_train: 18.0373 loss_x_train_x: 10.2036 loss_x_train_y: 7.8318 loss_val: 19.9489 loss_x_val_x: 11.2396 loss_x_val_y: 8.7093 time: 0.0337s
#  Epoch: 0305 loss_train: 17.9263 loss_x_train_x: 10.1593 loss_x_train_y: 7.7650 loss_val: 19.8997 loss_x_val_x: 11.2264 loss_x_val_y: 8.6733 time: 0.0341s
# ...
#  Epoch: 2895 loss_train: 0.7549 loss_x_train_x: 0.4191 loss_x_train_y: 0.3318 loss_val: 8.1139 loss_x_val_x: 4.9575 loss_x_val_y: 3.1564 time: 0.0353s
#  Epoch: 2896 loss_train: 0.7407 loss_x_train_x: 0.4041 loss_x_train_y: 0.3326 loss_val: 8.1173 loss_x_val_x: 4.9532 loss_x_val_y: 3.1642 time: 0.0350s
#  Epoch: 2897 loss_train: 0.7551 loss_x_train_x: 0.4206 loss_x_train_y: 0.3304 loss_val: 8.1080 loss_x_val_x: 4.9521 loss_x_val_y: 3.1560 time: 0.0360s
#  Epoch: 2898 loss_train: 0.7292 loss_x_train_x: 0.4183 loss_x_train_y: 0.3068 loss_val: 8.1354 loss_x_val_x: 4.9563 loss_x_val_y: 3.1792 time: 0.0359s
#  Epoch: 2899 loss_train: 0.7665 loss_x_train_x: 0.4279 loss_x_train_y: 0.3345 loss_val: 8.1202 loss_x_val_x: 4.9507 loss_x_val_y: 3.1695 time: 0.0349s
#  Epoch: 2900 loss_train: 0.7448 loss_x_train_x: 0.4312 loss_x_train_y: 0.3095 loss_val: 8.1109 loss_x_val_x: 4.9508 loss_x_val_y: 3.1601 time: 0.0365s
#  Epoch: 2901 loss_train: 0.7605 loss_x_train_x: 0.4252 loss_x_train_y: 0.3313 loss_val: 8.0979 loss_x_val_x: 4.9476 loss_x_val_y: 3.1504 time: 0.0368s
#  Epoch: 2902 loss_train: 0.7771 loss_x_train_x: 0.4428 loss_x_train_y: 0.3303 loss_val: 8.1159 loss_x_val_x: 4.9545 loss_x_val_y: 3.1613 time: 0.0350s
#  Epoch: 2903 loss_train: 0.7701 loss_x_train_x: 0.4404 loss_x_train_y: 0.3257 loss_val: 8.1026 loss_x_val_x: 4.9484 loss_x_val_y: 3.1543 time: 0.0345s
#  Epoch: 2904 loss_train: 0.7465 loss_x_train_x: 0.4160 loss_x_train_y: 0.3264 loss_val: 8.1176 loss_x_val_x: 4.9552 loss_x_val_y: 3.1624 time: 0.0360s
#  Epoch: 2905 loss_train: 0.7251 loss_x_train_x: 0.4134 loss_x_train_y: 0.3075 loss_val: 8.1094 loss_x_val_x: 4.9541 loss_x_val_y: 3.1552 time: 0.0359s
#  Epoch: 2906 loss_train: 0.7558 loss_x_train_x: 0.4156 loss_x_train_y: 0.3361 loss_val: 8.0905 loss_x_val_x: 4.9431 loss_x_val_y: 3.1474 time: 0.0354s
#  Epoch: 2907 loss_train: 0.7488 loss_x_train_x: 0.4307 loss_x_train_y: 0.3140 loss_val: 8.1094 loss_x_val_x: 4.9427 loss_x_val_y: 3.1667 time: 0.0360s
#  Epoch: 2908 loss_train: 0.7235 loss_x_train_x: 0.4125 loss_x_train_y: 0.3070 loss_val: 8.1149 loss_x_val_x: 4.9419 loss_x_val_y: 3.1730 time: 0.0336s
#  Epoch: 2909 loss_train: 0.7755 loss_x_train_x: 0.4533 loss_x_train_y: 0.3181 loss_val: 8.0925 loss_x_val_x: 4.9377 loss_x_val_y: 3.1548 time: 0.0334s
#  Epoch: 2910 loss_train: 0.7321 loss_x_train_x: 0.4218 loss_x_train_y: 0.3062 loss_val: 8.0940 loss_x_val_x: 4.9381 loss_x_val_y: 3.1559 time: 0.0335s
#  Epoch: 2911 loss_train: 0.7492 loss_x_train_x: 0.4191 loss_x_train_y: 0.3260 loss_val: 8.0954 loss_x_val_x: 4.9464 loss_x_val_y: 3.1490 time: 0.0342s
#  Epoch: 2912 loss_train: 0.7165 loss_x_train_x: 0.4055 loss_x_train_y: 0.3070 loss_val: 8.1174 loss_x_val_x: 4.9485 loss_x_val_y: 3.1689 time: 0.0354s
#  Epoch: 2913 loss_train: 0.7314 loss_x_train_x: 0.4024 loss_x_train_y: 0.3250 loss_val: 8.1239 loss_x_val_x: 4.9504 loss_x_val_y: 3.1735 time: 0.0352s
#  Epoch: 2914 loss_train: 0.7267 loss_x_train_x: 0.4087 loss_x_train_y: 0.3139 loss_val: 8.1096 loss_x_val_x: 4.9521 loss_x_val_y: 3.1575 time: 0.0360s
#  Epoch: 2915 loss_train: 0.7496 loss_x_train_x: 0.4245 loss_x_train_y: 0.3211 loss_val: 8.1012 loss_x_val_x: 4.9473 loss_x_val_y: 3.1539 time: 0.0360s
#  Epoch: 2916 loss_train: 0.7621 loss_x_train_x: 0.4397 loss_x_train_y: 0.3183 loss_val: 8.1099 loss_x_val_x: 4.9498 loss_x_val_y: 3.1601 time: 0.0352s
#  Epoch: 2917 loss_train: 0.7500 loss_x_train_x: 0.4197 loss_x_train_y: 0.3262 loss_val: 8.1124 loss_x_val_x: 4.9521 loss_x_val_y: 3.1603 time: 0.0364s
#  Epoch: 2918 loss_train: 0.7722 loss_x_train_x: 0.4297 loss_x_train_y: 0.3384 loss_val: 8.1134 loss_x_val_x: 4.9473 loss_x_val_y: 3.1661 time: 0.0354s
#  Epoch: 2919 loss_train: 0.7826 loss_x_train_x: 0.4470 loss_x_train_y: 0.3315 loss_val: 8.1224 loss_x_val_x: 4.9508 loss_x_val_y: 3.1716 time: 0.0352s
#  Epoch: 2920 loss_train: 0.7302 loss_x_train_x: 0.4004 loss_x_train_y: 0.3257 loss_val: 8.1360 loss_x_val_x: 4.9608 loss_x_val_y: 3.1753 time: 0.0360s
#  Epoch: 2921 loss_train: 0.7209 loss_x_train_x: 0.3903 loss_x_train_y: 0.3265 loss_val: 8.1154 loss_x_val_x: 4.9594 loss_x_val_y: 3.1561 time: 0.0363s
#  Epoch: 2922 loss_train: 0.7595 loss_x_train_x: 0.4237 loss_x_train_y: 0.3317 loss_val: 8.1398 loss_x_val_x: 4.9700 loss_x_val_y: 3.1698 time: 0.0350s
#  Epoch: 2923 loss_train: 0.7482 loss_x_train_x: 0.4189 loss_x_train_y: 0.3253 loss_val: 8.1387 loss_x_val_x: 4.9629 loss_x_val_y: 3.1758 time: 0.0352s
#  Epoch: 2924 loss_train: 0.7719 loss_x_train_x: 0.4335 loss_x_train_y: 0.3343 loss_val: 8.1327 loss_x_val_x: 4.9578 loss_x_val_y: 3.1748 time: 0.0356s
#  Epoch: 2925 loss_train: 0.7701 loss_x_train_x: 0.4350 loss_x_train_y: 0.3310 loss_val: 8.0957 loss_x_val_x: 4.9417 loss_x_val_y: 3.1540 time: 0.0366s
#  Epoch: 2926 loss_train: 0.7726 loss_x_train_x: 0.4328 loss_x_train_y: 0.3356 loss_val: 8.1386 loss_x_val_x: 4.9587 loss_x_val_y: 3.1798 time: 0.0343s
#  Epoch: 2927 loss_train: 0.7378 loss_x_train_x: 0.4163 loss_x_train_y: 0.3175 loss_val: 8.1587 loss_x_val_x: 4.9657 loss_x_val_y: 3.1931 time: 0.0366s
#  Epoch: 2928 loss_train: 0.7275 loss_x_train_x: 0.3993 loss_x_train_y: 0.3242 loss_val: 8.1190 loss_x_val_x: 4.9531 loss_x_val_y: 3.1659 time: 0.0364s
#  Epoch: 2929 loss_train: 0.7147 loss_x_train_x: 0.4025 loss_x_train_y: 0.3082 loss_val: 8.1087 loss_x_val_x: 4.9463 loss_x_val_y: 3.1624 time: 0.0361s
#  Epoch: 2930 loss_train: 0.7433 loss_x_train_x: 0.4118 loss_x_train_y: 0.3274 loss_val: 8.1110 loss_x_val_x: 4.9579 loss_x_val_y: 3.1531 time: 0.0367s
#  Epoch: 2931 loss_train: 0.7151 loss_x_train_x: 0.3946 loss_x_train_y: 0.3165 loss_val: 8.1269 loss_x_val_x: 4.9605 loss_x_val_y: 3.1664 time: 0.0338s
#  Epoch: 2932 loss_train: 0.7221 loss_x_train_x: 0.4148 loss_x_train_y: 0.3033 loss_val: 8.1303 loss_x_val_x: 4.9547 loss_x_val_y: 3.1756 time: 0.0338s
#  Epoch: 2933 loss_train: 0.7438 loss_x_train_x: 0.4269 loss_x_train_y: 0.3129 loss_val: 8.1073 loss_x_val_x: 4.9552 loss_x_val_y: 3.1521 time: 0.0339s
#  Epoch: 2934 loss_train: 0.7483 loss_x_train_x: 0.4244 loss_x_train_y: 0.3199 loss_val: 8.0979 loss_x_val_x: 4.9414 loss_x_val_y: 3.1565 time: 0.0338s
#  Epoch: 2935 loss_train: 0.7421 loss_x_train_x: 0.4113 loss_x_train_y: 0.3266 loss_val: 8.1118 loss_x_val_x: 4.9493 loss_x_val_y: 3.1624 time: 0.0338s
#  Epoch: 2936 loss_train: 0.7623 loss_x_train_x: 0.4225 loss_x_train_y: 0.3357 loss_val: 8.1323 loss_x_val_x: 4.9550 loss_x_val_y: 3.1773 time: 0.0341s
#  Epoch: 2937 loss_train: 0.7570 loss_x_train_x: 0.4244 loss_x_train_y: 0.3285 loss_val: 8.1139 loss_x_val_x: 4.9544 loss_x_val_y: 3.1596 time: 0.0339s
#  Epoch: 2938 loss_train: 0.7540 loss_x_train_x: 0.4242 loss_x_train_y: 0.3257 loss_val: 8.1345 loss_x_val_x: 4.9625 loss_x_val_y: 3.1719 time: 0.0337s
#  Epoch: 2939 loss_train: 0.7392 loss_x_train_x: 0.4106 loss_x_train_y: 0.3245 loss_val: 8.1184 loss_x_val_x: 4.9602 loss_x_val_y: 3.1582 time: 0.0338s
#  Epoch: 2940 loss_train: 0.7362 loss_x_train_x: 0.4189 loss_x_train_y: 0.3132 loss_val: 8.1051 loss_x_val_x: 4.9598 loss_x_val_y: 3.1453 time: 0.0337s
#  Epoch: 2941 loss_train: 0.7414 loss_x_train_x: 0.4173 loss_x_train_y: 0.3200 loss_val: 8.1195 loss_x_val_x: 4.9582 loss_x_val_y: 3.1613 time: 0.0338s
#  Epoch: 2942 loss_train: 0.7212 loss_x_train_x: 0.4069 loss_x_train_y: 0.3102 loss_val: 8.1174 loss_x_val_x: 4.9547 loss_x_val_y: 3.1627 time: 0.0359s
#  Epoch: 2943 loss_train: 0.7628 loss_x_train_x: 0.4404 loss_x_train_y: 0.3183 loss_val: 8.1092 loss_x_val_x: 4.9536 loss_x_val_y: 3.1557 time: 0.0350s
#  Epoch: 2944 loss_train: 0.7377 loss_x_train_x: 0.3952 loss_x_train_y: 0.3384 loss_val: 8.1313 loss_x_val_x: 4.9556 loss_x_val_y: 3.1757 time: 0.0338s
#  Epoch: 2945 loss_train: 0.7577 loss_x_train_x: 0.4164 loss_x_train_y: 0.3372 loss_val: 8.1348 loss_x_val_x: 4.9548 loss_x_val_y: 3.1800 time: 0.0342s
#  Epoch: 2946 loss_train: 0.7228 loss_x_train_x: 0.4212 loss_x_train_y: 0.2975 loss_val: 8.1183 loss_x_val_x: 4.9480 loss_x_val_y: 3.1703 time: 0.0360s
#  Epoch: 2947 loss_train: 0.7258 loss_x_train_x: 0.4000 loss_x_train_y: 0.3216 loss_val: 8.1289 loss_x_val_x: 4.9511 loss_x_val_y: 3.1778 time: 0.0351s
#  Epoch: 2948 loss_train: 0.7200 loss_x_train_x: 0.4069 loss_x_train_y: 0.3090 loss_val: 8.1147 loss_x_val_x: 4.9421 loss_x_val_y: 3.1726 time: 0.0359s
#  Epoch: 2949 loss_train: 0.7116 loss_x_train_x: 0.3965 loss_x_train_y: 0.3109 loss_val: 8.1267 loss_x_val_x: 4.9411 loss_x_val_y: 3.1856 time: 0.0409s
#  Epoch: 2950 loss_train: 0.7475 loss_x_train_x: 0.4145 loss_x_train_y: 0.3288 loss_val: 8.1170 loss_x_val_x: 4.9429 loss_x_val_y: 3.1741 time: 0.0353s
#  Epoch: 2951 loss_train: 0.7198 loss_x_train_x: 0.4093 loss_x_train_y: 0.3065 loss_val: 8.0969 loss_x_val_x: 4.9324 loss_x_val_y: 3.1645 time: 0.0351s
#  Epoch: 2952 loss_train: 0.7276 loss_x_train_x: 0.4149 loss_x_train_y: 0.3086 loss_val: 8.1340 loss_x_val_x: 4.9443 loss_x_val_y: 3.1897 time: 0.0361s
#  Epoch: 2953 loss_train: 0.7460 loss_x_train_x: 0.4217 loss_x_train_y: 0.3201 loss_val: 8.1187 loss_x_val_x: 4.9466 loss_x_val_y: 3.1721 time: 0.0399s
#  Epoch: 2954 loss_train: 0.7281 loss_x_train_x: 0.4042 loss_x_train_y: 0.3198 loss_val: 8.1254 loss_x_val_x: 4.9489 loss_x_val_y: 3.1765 time: 0.0375s
#  Epoch: 2955 loss_train: 0.7601 loss_x_train_x: 0.4365 loss_x_train_y: 0.3195 loss_val: 8.1173 loss_x_val_x: 4.9501 loss_x_val_y: 3.1672 time: 0.0370s
#  Epoch: 2956 loss_train: 0.7458 loss_x_train_x: 0.4283 loss_x_train_y: 0.3134 loss_val: 8.1406 loss_x_val_x: 4.9574 loss_x_val_y: 3.1832 time: 0.0362s
#  Epoch: 2957 loss_train: 0.7577 loss_x_train_x: 0.4340 loss_x_train_y: 0.3196 loss_val: 8.1092 loss_x_val_x: 4.9433 loss_x_val_y: 3.1659 time: 0.0352s
#  Epoch: 2958 loss_train: 0.7544 loss_x_train_x: 0.4414 loss_x_train_y: 0.3089 loss_val: 8.1388 loss_x_val_x: 4.9548 loss_x_val_y: 3.1840 time: 0.0360s
#  Epoch: 2959 loss_train: 0.7256 loss_x_train_x: 0.4223 loss_x_train_y: 0.2991 loss_val: 8.1454 loss_x_val_x: 4.9655 loss_x_val_y: 3.1799 time: 0.0354s
#  Epoch: 2960 loss_train: 0.7391 loss_x_train_x: 0.4147 loss_x_train_y: 0.3202 loss_val: 8.1215 loss_x_val_x: 4.9620 loss_x_val_y: 3.1595 time: 0.0370s
#  Epoch: 2961 loss_train: 0.7355 loss_x_train_x: 0.4138 loss_x_train_y: 0.3176 loss_val: 8.1464 loss_x_val_x: 4.9661 loss_x_val_y: 3.1803 time: 0.0341s
#  Epoch: 2962 loss_train: 0.7079 loss_x_train_x: 0.4009 loss_x_train_y: 0.3029 loss_val: 8.1358 loss_x_val_x: 4.9595 loss_x_val_y: 3.1763 time: 0.0352s
#  Epoch: 2963 loss_train: 0.7559 loss_x_train_x: 0.4307 loss_x_train_y: 0.3210 loss_val: 8.1419 loss_x_val_x: 4.9577 loss_x_val_y: 3.1842 time: 0.0360s
#  Epoch: 2964 loss_train: 0.7244 loss_x_train_x: 0.4073 loss_x_train_y: 0.3130 loss_val: 8.1548 loss_x_val_x: 4.9641 loss_x_val_y: 3.1906 time: 0.0360s
#  Epoch: 2965 loss_train: 0.6957 loss_x_train_x: 0.4014 loss_x_train_y: 0.2902 loss_val: 8.1308 loss_x_val_x: 4.9580 loss_x_val_y: 3.1728 time: 0.0351s
#  Epoch: 2966 loss_train: 0.6934 loss_x_train_x: 0.3890 loss_x_train_y: 0.3003 loss_val: 8.1203 loss_x_val_x: 4.9564 loss_x_val_y: 3.1638 time: 0.0368s
#  Epoch: 2967 loss_train: 0.7338 loss_x_train_x: 0.4130 loss_x_train_y: 0.3168 loss_val: 8.1135 loss_x_val_x: 4.9516 loss_x_val_y: 3.1619 time: 0.0351s
#  Epoch: 2968 loss_train: 0.7240 loss_x_train_x: 0.4025 loss_x_train_y: 0.3173 loss_val: 8.1034 loss_x_val_x: 4.9467 loss_x_val_y: 3.1567 time: 0.0360s
#  Epoch: 2969 loss_train: 0.7281 loss_x_train_x: 0.4128 loss_x_train_y: 0.3112 loss_val: 8.1360 loss_x_val_x: 4.9526 loss_x_val_y: 3.1834 time: 0.0350s
#  Epoch: 2970 loss_train: 0.7477 loss_x_train_x: 0.4292 loss_x_train_y: 0.3144 loss_val: 8.1436 loss_x_val_x: 4.9626 loss_x_val_y: 3.1810 time: 0.0360s
#  Epoch: 2971 loss_train: 0.7312 loss_x_train_x: 0.4166 loss_x_train_y: 0.3105 loss_val: 8.1461 loss_x_val_x: 4.9680 loss_x_val_y: 3.1781 time: 0.0364s
#  Epoch: 2972 loss_train: 0.7213 loss_x_train_x: 0.4188 loss_x_train_y: 0.2984 loss_val: 8.1117 loss_x_val_x: 4.9513 loss_x_val_y: 3.1604 time: 0.0368s
#  Epoch: 2973 loss_train: 0.7112 loss_x_train_x: 0.4080 loss_x_train_y: 0.2992 loss_val: 8.1431 loss_x_val_x: 4.9595 loss_x_val_y: 3.1836 time: 0.0352s
#  Epoch: 2974 loss_train: 0.6898 loss_x_train_x: 0.3892 loss_x_train_y: 0.2965 loss_val: 8.1170 loss_x_val_x: 4.9412 loss_x_val_y: 3.1757 time: 0.0361s
#  Epoch: 2975 loss_train: 0.7369 loss_x_train_x: 0.4155 loss_x_train_y: 0.3173 loss_val: 8.1274 loss_x_val_x: 4.9393 loss_x_val_y: 3.1882 time: 0.0361s
#  Epoch: 2976 loss_train: 0.7159 loss_x_train_x: 0.4131 loss_x_train_y: 0.2987 loss_val: 8.1249 loss_x_val_x: 4.9449 loss_x_val_y: 3.1800 time: 0.0351s
#  Epoch: 2977 loss_train: 0.7269 loss_x_train_x: 0.3980 loss_x_train_y: 0.3247 loss_val: 8.1034 loss_x_val_x: 4.9410 loss_x_val_y: 3.1625 time: 0.0362s
#  Epoch: 2978 loss_train: 0.7441 loss_x_train_x: 0.4215 loss_x_train_y: 0.3184 loss_val: 8.1089 loss_x_val_x: 4.9492 loss_x_val_y: 3.1597 time: 0.0364s
#  Epoch: 2979 loss_train: 0.7148 loss_x_train_x: 0.4136 loss_x_train_y: 0.2970 loss_val: 8.1156 loss_x_val_x: 4.9554 loss_x_val_y: 3.1601 time: 0.0360s
#  Epoch: 2980 loss_train: 0.7351 loss_x_train_x: 0.4241 loss_x_train_y: 0.3068 loss_val: 8.1261 loss_x_val_x: 4.9471 loss_x_val_y: 3.1790 time: 0.0346s
#  Epoch: 2981 loss_train: 0.7257 loss_x_train_x: 0.4122 loss_x_train_y: 0.3093 loss_val: 8.1124 loss_x_val_x: 4.9517 loss_x_val_y: 3.1606 time: 0.0351s
#  Epoch: 2982 loss_train: 0.6837 loss_x_train_x: 0.3906 loss_x_train_y: 0.2890 loss_val: 8.1170 loss_x_val_x: 4.9527 loss_x_val_y: 3.1643 time: 0.0348s
#  Epoch: 2983 loss_train: 0.7157 loss_x_train_x: 0.3953 loss_x_train_y: 0.3163 loss_val: 8.1047 loss_x_val_x: 4.9481 loss_x_val_y: 3.1566 time: 0.0341s
#  Epoch: 2984 loss_train: 0.7393 loss_x_train_x: 0.4046 loss_x_train_y: 0.3306 loss_val: 8.1291 loss_x_val_x: 4.9601 loss_x_val_y: 3.1690 time: 0.0368s
#  Epoch: 2985 loss_train: 0.7327 loss_x_train_x: 0.4154 loss_x_train_y: 0.3131 loss_val: 8.1250 loss_x_val_x: 4.9591 loss_x_val_y: 3.1659 time: 0.0354s
#  Epoch: 2986 loss_train: 0.7171 loss_x_train_x: 0.4140 loss_x_train_y: 0.2990 loss_val: 8.1355 loss_x_val_x: 4.9670 loss_x_val_y: 3.1685 time: 0.0359s
#  Epoch: 2987 loss_train: 0.7314 loss_x_train_x: 0.4036 loss_x_train_y: 0.3237 loss_val: 8.1110 loss_x_val_x: 4.9614 loss_x_val_y: 3.1495 time: 0.0361s
#  Epoch: 2988 loss_train: 0.7156 loss_x_train_x: 0.3939 loss_x_train_y: 0.3176 loss_val: 8.1360 loss_x_val_x: 4.9559 loss_x_val_y: 3.1801 time: 0.0341s
#  Epoch: 2989 loss_train: 0.7138 loss_x_train_x: 0.4103 loss_x_train_y: 0.2994 loss_val: 8.1195 loss_x_val_x: 4.9607 loss_x_val_y: 3.1587 time: 0.0349s
#  Epoch: 2990 loss_train: 0.7279 loss_x_train_x: 0.4117 loss_x_train_y: 0.3121 loss_val: 8.1105 loss_x_val_x: 4.9534 loss_x_val_y: 3.1571 time: 0.0353s
#  Epoch: 2991 loss_train: 0.7187 loss_x_train_x: 0.4059 loss_x_train_y: 0.3087 loss_val: 8.1232 loss_x_val_x: 4.9453 loss_x_val_y: 3.1779 time: 0.0342s
#  Epoch: 2992 loss_train: 0.7266 loss_x_train_x: 0.3866 loss_x_train_y: 0.3358 loss_val: 8.1201 loss_x_val_x: 4.9572 loss_x_val_y: 3.1629 time: 0.0351s
#  Epoch: 2993 loss_train: 0.7030 loss_x_train_x: 0.4019 loss_x_train_y: 0.2969 loss_val: 8.1394 loss_x_val_x: 4.9568 loss_x_val_y: 3.1827 time: 0.0368s
#  Epoch: 2994 loss_train: 0.7301 loss_x_train_x: 0.4039 loss_x_train_y: 0.3220 loss_val: 8.1437 loss_x_val_x: 4.9610 loss_x_val_y: 3.1827 time: 0.0359s
#  Epoch: 2995 loss_train: 0.7339 loss_x_train_x: 0.4166 loss_x_train_y: 0.3132 loss_val: 8.1377 loss_x_val_x: 4.9594 loss_x_val_y: 3.1784 time: 0.0351s
#  Epoch: 2996 loss_train: 0.7406 loss_x_train_x: 0.4213 loss_x_train_y: 0.3152 loss_val: 8.1077 loss_x_val_x: 4.9497 loss_x_val_y: 3.1579 time: 0.0369s
#  Epoch: 2997 loss_train: 0.7085 loss_x_train_x: 0.4050 loss_x_train_y: 0.2994 loss_val: 8.1151 loss_x_val_x: 4.9628 loss_x_val_y: 3.1523 time: 0.0342s
#  Epoch: 2998 loss_train: 0.7162 loss_x_train_x: 0.3951 loss_x_train_y: 0.3169 loss_val: 8.1250 loss_x_val_x: 4.9541 loss_x_val_y: 3.1709 time: 0.0351s
#  Epoch: 2999 loss_train: 0.7247 loss_x_train_x: 0.4244 loss_x_train_y: 0.2961 loss_val: 8.0889 loss_x_val_x: 4.9569 loss_x_val_y: 3.1320 time: 0.0350s
#  total time: 114.6176s

# %%
with open(os.path.join(logsavepath,'train_loss_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_x_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_x_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_y_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss_y, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_y_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss_y, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNorm_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNormx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNormy_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm_y, output, pickle.HIGHEST_PROTOCOL)



plt.plot(np.arange(epochs),train_loss_x)
plt.plot(np.arange(epochs),val_loss_x)
# plt.plot(np.arange(epochs),train_loss_kl_ep)
plt.legend(['training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_x'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()



plt.plot(np.arange(epochs),train_loss_y)
plt.plot(np.arange(epochs),val_loss_y)
# plt.plot(np.arange(epochs),train_loss_kl_ep)
plt.legend(['training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_y'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()


plt.plot(np.arange(epochs),train_lNorm)
plt.plot(np.arange(epochs),train_lNorm_x)
plt.plot(np.arange(epochs),train_lNorm_y)
# plt.plot(np.arange(epochs),train_loss_kl_ep)
plt.legend(['shared l2','x l2','y l2'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_lNorm'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.2,3))
plt.plot(np.arange(epochs),train_loss_x)
plt.plot(np.arange(epochs),train_loss_y)
plt.legend(['Modality 1 reconstruction','Modality 2 reconstruction','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'fig_loss_xy'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.pdf'))
plt.show()

fig, ax = plt.subplots(figsize=(3.2,3))
plt.plot(np.arange(epochs),train_lNorm)
plt.plot(np.arange(epochs),train_lNorm_x)
plt.plot(np.arange(epochs),train_lNorm_y)
plt.legend(['Shared l2','Modality 1 l2','Modality 2 l2'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'fig_loss_lNorm'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.pdf'))
plt.show()

# %%
latent_shared=torch.nn.Embedding(X.shape[0],sharedSize)
latent_x=torch.nn.Embedding(X.shape[0],dSpecificSize)
latent_y=torch.nn.Embedding(X.shape[0],dSpecificSize)

loadEpoch='2900'
with open(os.path.join(modelsavepath,'latentx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_x.weight=pickle.load(output)
with open(os.path.join(modelsavepath,'latentShared_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_shared.weight=pickle.load( output)
with open(os.path.join(modelsavepath,'latenty_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_y.weight=pickle.load(output)
latent_x.weight.requires_grad=False
latent_shared.weight.requires_grad=False
latent_y.weight.requires_grad=False

# %%
n_neighbors=10
min_dist=0.25

reducer_sharedlatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_shared.weight[trainIdx_all].cpu().detach())

# %%
def plotembeddingbyCT(ctlist,savename,excludelist,embedding,savepath,plotname,plotdimx=0,plotdimy=1,savenameAdd='',img=None,ncolors=None,colorseq=None,s=2.5):
    
    celltypes=np.unique(ctlist)
    if ncolors is None:
        colortest=sns.color_palette("husl", celltypes.size)
        if colorseq is None:
            colorseq=np.arange(celltypes.size)
    else:
        colortest=sns.color_palette("husl", ncolors)
        if colorseq is None:
            colorseq=np.arange(ncolors)
    
    fig, ax = plt.subplots(dpi=400)
    if not img is None:
        plt.imshow(img)
    for ct in celltypes:
        if ct in excludelist:
            continue
        idx=(ctlist==ct)
        if not img is None:
            ax.scatter(
                embedding[idx, plotdimy],
                embedding[idx, plotdimx],
                color=colortest[colorseq[int(ct)]],label=ct,s=1.5,alpha=0.5
                )
        else:
            ax.scatter(
                embedding[idx, plotdimx],
                embedding[idx, plotdimy],
                color=colortest[colorseq[int(ct)]],label=ct,s=s,alpha=1
                )

    plt.gca().set_aspect('equal', 'datalim')
    fig.set_figheight(5)
    fig.set_figwidth(5)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.1,
                     box.width, box.height * 0.9])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
              fancybox=True,ncol=5, shadow=True,prop={'size': 6})
    plt.title(plotname+' embedding', fontsize=12)
    plt.savefig(os.path.join(savepath,savename+savenameAdd+'.pdf'))
    plt.close('all')
    
def plotembeddingbyCT_str(ctlist,savename,excludelist,embedding,savepath,plotname,plotdimx=0,plotdimy=1,savenameAdd=''):
    celltypes=np.unique(ctlist)
    celltypes_dict={}
    idx=0
    for ct in celltypes:
        celltypes_dict[ct]=idx
        idx+=1
        
    colortest=sns.color_palette("husl", celltypes.size)
    fig, ax = plt.subplots(dpi=400)
    for ct in celltypes:
        if ct in excludelist:
            continue
        idx=(ctlist==ct)
        ax.scatter(
            embedding[idx, plotdimx],
            embedding[idx, plotdimy],
            color=colortest[celltypes_dict[ct]],label=ct,s=1,alpha=0.5
            )

    plt.gca().set_aspect('equal', 'datalim')
    fig.set_figheight(6)
    fig.set_figwidth(6)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.3,
                     box.width, box.height * 0.7])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), 
              fancybox=True, ncol=3, shadow=True, prop={'size': 6})
    plt.title(plotname, fontsize=12)
    plt.savefig(os.path.join(savepath,savename+savenameAdd+'.pdf'))
    plt.close('all')
    
    gc.collect()

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_shared_latent',[],reducer_sharedlatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_shared_latent',[],reducer_sharedlatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
reducer_ylatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_y.weight[trainIdx_all].cpu().detach())

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_Y_latent',[],reducer_ylatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_Y_latent',[],reducer_ylatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
reducer_xlatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_x.weight[trainIdx_all].cpu().detach())

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_X_latent',[],reducer_xlatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_X_latent',[],reducer_xlatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(latent_shared.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.5310596

# %%
silhouette_score(latent_shared.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.010599193

# %%
silhouette_score(latent_x.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.2092404

# %%
silhouette_score(latent_x.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.29300824

# %%
silhouette_score(latent_y.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.110805444

# %%
silhouette_score(latent_y.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.0031954572
