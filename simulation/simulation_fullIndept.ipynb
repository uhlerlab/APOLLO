# %%
import sys
sys.path.append('/home/xinyiz/c2p_dag/')
sys.path.append('/home/xinyiz/c2p_dag/img2seq/')

import numpy as np
import pickle
import os
import pandas as pd
from scipy import sparse

import time

import scanpy
import numpy as np

import torch
from torch import optim


import matplotlib.pyplot as plt
import seaborn as sns
import umap
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import anndata as ad
import gc


import gae.gae.optimizer as optimizer

import gae.gae.model
import gae.gae.model_lord
import gae.gae.preprocessing as preprocessing
# Out:
# 2025-06-04 19:05:32.505550: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nSamples= 2048

Z1 = np.random.binomial(1, 0.5, size=nSamples)

gamma2 = np.random.gamma(shape=5, scale=1, size=nSamples)
Z2 = Z1 + gamma2 * np.sqrt(0.0045) 

Z3 = np.random.binomial(1, 0.5, size=nSamples)

gamma4 = np.random.gamma(shape=2, scale=2, size=nSamples)
Z4 = Z3 + gamma4 * np.sqrt(0.00125)

gamma5 = np.random.gamma(shape=3, scale=2, size=nSamples)
Z5 = np.random.binomial(1, 0.5, size=nSamples)+gamma5 * np.sqrt(0.0075)

Z = np.stack([Z1, Z2, Z3, Z4, Z5], axis=1)

# %%
variables = [Z1, Z2, Z3, Z4, Z5]
titles = ['Z1', 'Z2', 'Z3', 'Z4', 'Z5']

fig, axs = plt.subplots(1, 5, figsize=(20, 4))
for i, (z, title) in enumerate(zip(variables, titles)):
    axs[i].hist(z, bins=30, color='skyblue', edgecolor='black')
    axs[i].set_title(title)
    axs[i].set_xlabel('Value')
    axs[i].set_ylabel('Samples')
    axs[i].grid(True)

plt.tight_layout()
plt.savefig('z_distribution_fullIndept_2.pdf')
plt.show()

# %%
Z
# Out:
# array([[1.        , 1.29174956, 0.        , 0.30498511, 0.45179487],
#        [0.        , 0.11849029, 0.        , 0.07173903, 0.51496424],
#        [1.        , 1.29339519, 0.        , 0.04660916, 1.53494319],
#        ...,
#        [0.        , 0.34858235, 1.        , 1.23953843, 1.22468637],
#        [1.        , 1.43586101, 1.        , 1.08334518, 1.34593189],
#        [0.        , 0.40263761, 0.        , 0.00421593, 0.51530004]])

# %%
# Initialize X with zeros 
X = np.zeros((nSamples, 40))

Z_X = np.stack([Z1, Z2, Z3, Z4], axis=1)

# X1-X10: pure children of Z4
G1 = np.random.randn(10, 1)
X[:, 0:10] = Z_X[:, [3]] @ G1.T

# X11-X20: pure children of Z3
G2 = np.random.randn(10, 1)
X[:, 10:20] = Z_X[:, [2]] @ G2.T

# X21-X30: pure children of Z2
G3 = np.random.randn(10, 1)
X[:, 20:30] = Z_X[:, [1]] @ G3.T

# X31-X40: children of Z2 and Z3
G4 = np.random.randn(10, 1)
X[:, 30:40] = Z_X[:, [0]] @ G4.T

Y = np.zeros((nSamples, 30))

Z_Y = np.stack([Z1, Z2, Z5], axis=1)

GY1 = np.random.randn(10, 1)
Y[:, 0:10] = Z_Y[:, [2]] @ GY1.T

GY2 = np.random.randn(10, 1)
Y[:, 10:20] = Z_Y[:, [1]] @ GY2.T

GY3 = np.random.randn(10, 1)
Y[:, 20:30] = Z_Y[:, [0]] @ GY3.T

# %%
#train-test split
np.random.seed(3)
pctVal=0.05
pctTest=0.1

allIdx_all=np.arange(nSamples)
np.random.shuffle(allIdx_all)
valIdx_all=allIdx_all[:int(pctVal*nSamples)]
testIdx_all=allIdx_all[int(pctVal*nSamples):(int(pctVal*nSamples)+int(pctTest*nSamples))]
trainIdx_all=allIdx_all[(int(pctVal*nSamples)+int(pctTest*nSamples)):]

hiddenSize=20
sharedSize=2
dSpecificSize=2
seed=1
#test0: 5, 3

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
os.environ["CUDA_LAUNCH_BLOCKING"] = "2"
 

batchsize=256
saveFreq=100
epochs=3000
lr_latent=0.001
lr_decoder=0.0001
weight_decay=0

dropout=0.01
XreconWeight=20
ridgeL=0.01

addNoise=True
actDecay=0.001

testSaveName='lord_bce'
name='test2_noSharedRecon_fullIndept_2'
logsavepath=os.path.join('/data/xinyi/c2p/simulation/results/log',testSaveName,name)
modelsavepath=os.path.join('/data/xinyi/c2p/simulation/results/models',testSaveName,name)
plotsavepath=os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName,name)

loss_x=torch.nn.MSELoss()
loss_y=torch.nn.MSELoss()

# %%
if not os.path.exists(os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName)):
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/plots',testSaveName))
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/models',testSaveName))
    os.mkdir(os.path.join('/data/xinyi/c2p/simulation/results/log',testSaveName))
if not os.path.exists(logsavepath):
    os.mkdir(logsavepath)
if not os.path.exists(modelsavepath):
    os.mkdir(modelsavepath)
if not os.path.exists(plotsavepath):
    os.mkdir(plotsavepath)
nFeatures_x=X.shape[1]
nFeatures_y=Y.shape[1]

# %%
def train(epoch):
    t = time.time()
    model_x.train()
    model_y.train()
    
    loss_all=0
    loss_x_train_all_x=0
    loss_x_train_all_y=0
    loss_lNorm_all=0
    loss_lNorm_all_x=0
    loss_lNorm_all_y=0
    
    ntrainBatches=int(np.ceil(trainIdx_all.shape[0]/batchsize))
    for i in range(ntrainBatches):
        trainIdx=trainIdx_all[i*batchsize:min((i+1)*batchsize,trainIdx_all.shape[0])]
        traintarget_x=torch.tensor(X[trainIdx]).cuda().float()
        traintarget_y=torch.tensor(Y[trainIdx]).cuda().float()
        trainIdx=torch.tensor(trainIdx)
        trainInput_shared=latent_shared(trainIdx).cuda().float()
        trainInput_x=latent_x(trainIdx).cuda().float()
        trainInput_y=latent_y(trainIdx).cuda().float()

        if addNoise:
            trainInput_shared=trainInput_shared+torch.randn_like(trainInput_shared)
            trainInput_x=trainInput_x+torch.randn_like(trainInput_x)
            trainInput_y=trainInput_y+torch.randn_like(trainInput_y)
            
        optimizer_x.zero_grad()
        optimizer_latent.zero_grad()
        optimizer_y.zero_grad()

        recon_x= model_x(torch.cat((trainInput_shared,trainInput_x),dim=1))
        y_recon = model_y(torch.cat((trainInput_shared,trainInput_y),dim=1))

        loss_x_train_x=loss_x(recon_x, traintarget_x)
        loss_x_train_y=loss_y(y_recon, traintarget_y)        
        loss=loss_x_train_x+loss_x_train_y
        
        if addNoise:
            loss_lNorm=torch.mean(torch.linalg.norm(latent_shared(trainIdx).cuda(),dim=1))/latent_shared.embedding_dim
            loss_lNorm_all+=loss_lNorm.item()
            loss+=loss_lNorm*actDecay
            
            loss_lNorm_x=torch.mean(torch.linalg.norm(latent_x(trainIdx).cuda(),dim=1))/latent_x.embedding_dim
            loss_lNorm_all_x+=loss_lNorm_x.item()
            loss+=loss_lNorm_x*actDecay
            
            loss_lNorm_y=torch.mean(torch.linalg.norm(latent_y(trainIdx).cuda(),dim=1))/latent_y.embedding_dim
            loss_lNorm_all_y+=loss_lNorm_y.item()
            loss+=loss_lNorm_y*actDecay
            
        
        loss_x_train_all_y+=loss_x_train_y.item()
        loss_x_train_all_x+=loss_x_train_x.item()
        loss_all+=loss.item()
        
            
        loss.backward()
        optimizer_x.step()
        optimizer_latent.step()
        optimizer_y.step()


    loss_x_train_all_y=loss_x_train_all_y/ntrainBatches
    loss_x_train_all_x=loss_x_train_all_x/ntrainBatches
    loss_all=loss_all/ntrainBatches
    if addNoise:
        loss_lNorm_all=loss_lNorm_all/ntrainBatches
        loss_lNorm_all_x=loss_lNorm_all_x/ntrainBatches
        loss_lNorm_all_y=loss_lNorm_all_y/ntrainBatches

    
    with torch.no_grad():
        model_x.eval()
        model_y.eval()
        loss_x_val_all_x=0
        loss_x_val_all_y=0
        loss_val_all=0
        nvalBatches=int(np.ceil(valIdx_all.shape[0]/batchsize))
        for i in range(nvalBatches):
            valIdx=valIdx_all[i*batchsize:min((i+1)*batchsize,valIdx_all.shape[0])]
            valtarget_x=torch.tensor(X[valIdx]).cuda().float()
            valtarget_y=torch.tensor(Y[valIdx]).cuda().float()
            valIdx=torch.tensor(valIdx)
            valInput_shared=latent_shared(valIdx).cuda().float()
            valInput_x=latent_x(valIdx).cuda().float()
            valInput_y=latent_y(valIdx).cuda().float()

            recon_x= model_x(torch.cat((valInput_shared,valInput_x),dim=1))
            y_recon = model_y(torch.cat((valInput_shared,valInput_y),dim=1))

            loss_x_val_x=loss_x(recon_x, valtarget_x)
            loss_x_val_y=loss_y(y_recon, valtarget_y)


            loss=loss_x_val_x+loss_x_val_y
            
            loss_x_val_all_x+=loss_x_val_x.item()
            loss_x_val_all_y+=loss_x_val_y.item()
            loss_val_all+=loss.item()

        loss_x_val_all_x=loss_x_val_all_x/nvalBatches
        loss_x_val_all_y=loss_x_val_all_y/nvalBatches
        loss_val_all=loss_val_all/nvalBatches
    
    print(' Epoch: {:04d}'.format(epoch),
          'loss_train: {:.4f}'.format(loss_all),
          'loss_x_train_x: {:.4f}'.format(loss_x_train_all_x),
          'loss_x_train_y: {:.4f}'.format(loss_x_train_all_y),
          'loss_val: {:.4f}'.format(loss_val_all),
          'loss_x_val_x: {:.4f}'.format(loss_x_val_all_x),
          'loss_x_val_y: {:.4f}'.format(loss_x_val_all_y),
          'time: {:.4f}s'.format(time.time() - t))
    return loss_all,loss_x_train_all_x,loss_x_train_all_y,loss_val_all,loss_x_val_all_x,loss_x_val_all_y,loss_lNorm_all,loss_lNorm_all_x,loss_lNorm_all_y

# %%
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.enabled = True

model_x = gae.gae.model_lord.fc_decode_l4(nFeatures_x,sharedSize+dSpecificSize,hiddenSize, dropout)
model_y = gae.gae.model_lord.fc_decode_l4(nFeatures_y, sharedSize+dSpecificSize,hiddenSize, dropout)


model_x.cuda()
model_y.cuda()

optimizer_x = optim.Adam(model_x.parameters(), lr=lr_decoder, weight_decay=weight_decay)
optimizer_y = optim.Adam(model_y.parameters(), lr=lr_decoder, weight_decay=weight_decay)

latent_shared=torch.nn.Embedding(X.shape[0],sharedSize)
latent_x=torch.nn.Embedding(X.shape[0],dSpecificSize)
latent_y=torch.nn.Embedding(X.shape[0],dSpecificSize)
optimizer_latent= torch.optim.Adam([latent_shared.weight,latent_x.weight,latent_y.weight], lr=lr_latent, weight_decay=weight_decay)

train_loss=[np.inf]*(epochs)
val_loss=[np.inf]*(epochs)

train_loss_x=[np.inf]*(epochs)
val_loss_x=[np.inf]*(epochs)

train_loss_y=[np.inf]*(epochs)
val_loss_y=[np.inf]*(epochs)

train_lNorm=[np.inf]*(epochs)
train_lNorm_x=[np.inf]*(epochs)
train_lNorm_y=[np.inf]*(epochs)

t_ep=time.time()

for ep in range(epochs):

    train_loss[ep],train_loss_x[ep],train_loss_y[ep],val_loss[ep],val_loss_x[ep],val_loss_y[ep],train_lNorm[ep],train_lNorm_x[ep],train_lNorm_y[ep]=train(ep)


    if ep%saveFreq == 0 and ep != 0:
        torch.save(model_x.cpu().state_dict(), os.path.join(modelsavepath,str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)+'_x.pt'))
        torch.save(model_y.cpu().state_dict(), os.path.join(modelsavepath,str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)+'_y.pt'))

        with open(os.path.join(modelsavepath,'latentx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_x.weight, output, pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(modelsavepath,'latentShared_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_shared.weight, output, pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(modelsavepath,'latenty_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(ep)), 'wb') as output:
            pickle.dump(latent_y.weight, output, pickle.HIGHEST_PROTOCOL)



    model_x.cuda()
    model_y.cuda()
    torch.cuda.empty_cache()
print(' total time: {:.4f}s'.format(time.time() - t_ep))
# Out:
#  Epoch: 0000 loss_train: 1.7516 loss_x_train_x: 0.7840 loss_x_train_y: 0.9657 loss_val: 1.4197 loss_x_val_x: 0.6636 loss_x_val_y: 0.7560 time: 0.6518s
#  Epoch: 0001 loss_train: 1.7359 loss_x_train_x: 0.7762 loss_x_train_y: 0.9578 loss_val: 1.4338 loss_x_val_x: 0.6790 loss_x_val_y: 0.7548 time: 0.0406s
#  Epoch: 0002 loss_train: 1.7222 loss_x_train_x: 0.7700 loss_x_train_y: 0.9504 loss_val: 1.4606 loss_x_val_x: 0.6987 loss_x_val_y: 0.7619 time: 0.0416s
#  Epoch: 0003 loss_train: 1.7057 loss_x_train_x: 0.7636 loss_x_train_y: 0.9403 loss_val: 1.4886 loss_x_val_x: 0.7164 loss_x_val_y: 0.7722 time: 0.0404s
#  Epoch: 0004 loss_train: 1.6869 loss_x_train_x: 0.7538 loss_x_train_y: 0.9312 loss_val: 1.5088 loss_x_val_x: 0.7279 loss_x_val_y: 0.7809 time: 0.0399s
#  Epoch: 0005 loss_train: 1.6710 loss_x_train_x: 0.7460 loss_x_train_y: 0.9231 loss_val: 1.5182 loss_x_val_x: 0.7330 loss_x_val_y: 0.7851 time: 0.0405s
#  Epoch: 0006 loss_train: 1.6583 loss_x_train_x: 0.7405 loss_x_train_y: 0.9160 loss_val: 1.5195 loss_x_val_x: 0.7339 loss_x_val_y: 0.7857 time: 0.0404s
#  Epoch: 0007 loss_train: 1.6419 loss_x_train_x: 0.7349 loss_x_train_y: 0.9050 loss_val: 1.5173 loss_x_val_x: 0.7339 loss_x_val_y: 0.7834 time: 0.0417s
#  Epoch: 0008 loss_train: 1.6282 loss_x_train_x: 0.7262 loss_x_train_y: 0.9001 loss_val: 1.5097 loss_x_val_x: 0.7299 loss_x_val_y: 0.7798 time: 0.0427s
#  Epoch: 0009 loss_train: 1.6105 loss_x_train_x: 0.7195 loss_x_train_y: 0.8891 loss_val: 1.5006 loss_x_val_x: 0.7255 loss_x_val_y: 0.7751 time: 0.0422s
#  Epoch: 0010 loss_train: 1.5965 loss_x_train_x: 0.7132 loss_x_train_y: 0.8814 loss_val: 1.4907 loss_x_val_x: 0.7203 loss_x_val_y: 0.7704 time: 0.0426s
#  Epoch: 0011 loss_train: 1.5806 loss_x_train_x: 0.7046 loss_x_train_y: 0.8741 loss_val: 1.4798 loss_x_val_x: 0.7129 loss_x_val_y: 0.7669 time: 0.0425s
#  Epoch: 0012 loss_train: 1.5705 loss_x_train_x: 0.7001 loss_x_train_y: 0.8686 loss_val: 1.4704 loss_x_val_x: 0.7090 loss_x_val_y: 0.7613 time: 0.0425s
#  Epoch: 0013 loss_train: 1.5534 loss_x_train_x: 0.6936 loss_x_train_y: 0.8580 loss_val: 1.4573 loss_x_val_x: 0.7025 loss_x_val_y: 0.7548 time: 0.0425s
#  Epoch: 0014 loss_train: 1.5415 loss_x_train_x: 0.6878 loss_x_train_y: 0.8518 loss_val: 1.4473 loss_x_val_x: 0.6985 loss_x_val_y: 0.7488 time: 0.0425s
#  Epoch: 0015 loss_train: 1.5323 loss_x_train_x: 0.6846 loss_x_train_y: 0.8458 loss_val: 1.4380 loss_x_val_x: 0.6940 loss_x_val_y: 0.7440 time: 0.0430s
#  Epoch: 0016 loss_train: 1.5195 loss_x_train_x: 0.6790 loss_x_train_y: 0.8386 loss_val: 1.4289 loss_x_val_x: 0.6894 loss_x_val_y: 0.7395 time: 0.0427s
#  Epoch: 0017 loss_train: 1.5072 loss_x_train_x: 0.6723 loss_x_train_y: 0.8330 loss_val: 1.4179 loss_x_val_x: 0.6843 loss_x_val_y: 0.7336 time: 0.0428s
#  Epoch: 0018 loss_train: 1.4923 loss_x_train_x: 0.6672 loss_x_train_y: 0.8232 loss_val: 1.4084 loss_x_val_x: 0.6801 loss_x_val_y: 0.7283 time: 0.0431s
#  Epoch: 0019 loss_train: 1.4823 loss_x_train_x: 0.6616 loss_x_train_y: 0.8188 loss_val: 1.3983 loss_x_val_x: 0.6752 loss_x_val_y: 0.7231 time: 0.0411s
#  Epoch: 0020 loss_train: 1.4696 loss_x_train_x: 0.6566 loss_x_train_y: 0.8111 loss_val: 1.3876 loss_x_val_x: 0.6702 loss_x_val_y: 0.7174 time: 0.0428s
#  Epoch: 0021 loss_train: 1.4581 loss_x_train_x: 0.6520 loss_x_train_y: 0.8043 loss_val: 1.3775 loss_x_val_x: 0.6658 loss_x_val_y: 0.7117 time: 0.0431s
#  Epoch: 0022 loss_train: 1.4465 loss_x_train_x: 0.6462 loss_x_train_y: 0.7984 loss_val: 1.3670 loss_x_val_x: 0.6602 loss_x_val_y: 0.7069 time: 0.0430s
#  Epoch: 0023 loss_train: 1.4369 loss_x_train_x: 0.6440 loss_x_train_y: 0.7909 loss_val: 1.3579 loss_x_val_x: 0.6556 loss_x_val_y: 0.7022 time: 0.0430s
#  Epoch: 0024 loss_train: 1.4239 loss_x_train_x: 0.6365 loss_x_train_y: 0.7855 loss_val: 1.3497 loss_x_val_x: 0.6510 loss_x_val_y: 0.6987 time: 0.0431s
#  Epoch: 0025 loss_train: 1.4146 loss_x_train_x: 0.6318 loss_x_train_y: 0.7809 loss_val: 1.3393 loss_x_val_x: 0.6461 loss_x_val_y: 0.6933 time: 0.0434s
#  Epoch: 0026 loss_train: 1.4053 loss_x_train_x: 0.6286 loss_x_train_y: 0.7748 loss_val: 1.3307 loss_x_val_x: 0.6417 loss_x_val_y: 0.6889 time: 0.0429s
#  Epoch: 0027 loss_train: 1.3924 loss_x_train_x: 0.6236 loss_x_train_y: 0.7669 loss_val: 1.3210 loss_x_val_x: 0.6375 loss_x_val_y: 0.6836 time: 0.0429s
#  Epoch: 0028 loss_train: 1.3820 loss_x_train_x: 0.6178 loss_x_train_y: 0.7623 loss_val: 1.3111 loss_x_val_x: 0.6329 loss_x_val_y: 0.6782 time: 0.0429s
#  Epoch: 0029 loss_train: 1.3720 loss_x_train_x: 0.6140 loss_x_train_y: 0.7561 loss_val: 1.3010 loss_x_val_x: 0.6277 loss_x_val_y: 0.6733 time: 0.0429s
#  Epoch: 0030 loss_train: 1.3613 loss_x_train_x: 0.6087 loss_x_train_y: 0.7507 loss_val: 1.2925 loss_x_val_x: 0.6233 loss_x_val_y: 0.6693 time: 0.0432s
#  Epoch: 0031 loss_train: 1.3545 loss_x_train_x: 0.6063 loss_x_train_y: 0.7463 loss_val: 1.2839 loss_x_val_x: 0.6192 loss_x_val_y: 0.6647 time: 0.0429s
#  Epoch: 0032 loss_train: 1.3394 loss_x_train_x: 0.6006 loss_x_train_y: 0.7369 loss_val: 1.2737 loss_x_val_x: 0.6147 loss_x_val_y: 0.6590 time: 0.0429s
#  Epoch: 0033 loss_train: 1.3322 loss_x_train_x: 0.5974 loss_x_train_y: 0.7329 loss_val: 1.2648 loss_x_val_x: 0.6107 loss_x_val_y: 0.6541 time: 0.0427s
#  Epoch: 0034 loss_train: 1.3260 loss_x_train_x: 0.5948 loss_x_train_y: 0.7294 loss_val: 1.2551 loss_x_val_x: 0.6065 loss_x_val_y: 0.6486 time: 0.0430s
#  Epoch: 0035 loss_train: 1.3136 loss_x_train_x: 0.5887 loss_x_train_y: 0.7230 loss_val: 1.2479 loss_x_val_x: 0.6027 loss_x_val_y: 0.6452 time: 0.0432s
#  Epoch: 0036 loss_train: 1.3051 loss_x_train_x: 0.5855 loss_x_train_y: 0.7178 loss_val: 1.2400 loss_x_val_x: 0.5984 loss_x_val_y: 0.6416 time: 0.0429s
#  Epoch: 0037 loss_train: 1.2934 loss_x_train_x: 0.5814 loss_x_train_y: 0.7101 loss_val: 1.2310 loss_x_val_x: 0.5949 loss_x_val_y: 0.6361 time: 0.0429s
#  Epoch: 0038 loss_train: 1.2872 loss_x_train_x: 0.5770 loss_x_train_y: 0.7083 loss_val: 1.2217 loss_x_val_x: 0.5909 loss_x_val_y: 0.6308 time: 0.0429s
#  Epoch: 0039 loss_train: 1.2764 loss_x_train_x: 0.5730 loss_x_train_y: 0.7015 loss_val: 1.2131 loss_x_val_x: 0.5867 loss_x_val_y: 0.6264 time: 0.0428s
#  Epoch: 0040 loss_train: 1.2667 loss_x_train_x: 0.5695 loss_x_train_y: 0.6953 loss_val: 1.2042 loss_x_val_x: 0.5829 loss_x_val_y: 0.6213 time: 0.0433s
#  Epoch: 0041 loss_train: 1.2578 loss_x_train_x: 0.5650 loss_x_train_y: 0.6910 loss_val: 1.1950 loss_x_val_x: 0.5786 loss_x_val_y: 0.6164 time: 0.0430s
#  Epoch: 0042 loss_train: 1.2514 loss_x_train_x: 0.5625 loss_x_train_y: 0.6870 loss_val: 1.1859 loss_x_val_x: 0.5744 loss_x_val_y: 0.6115 time: 0.0430s
#  Epoch: 0043 loss_train: 1.2433 loss_x_train_x: 0.5598 loss_x_train_y: 0.6817 loss_val: 1.1790 loss_x_val_x: 0.5706 loss_x_val_y: 0.6084 time: 0.0429s
#  Epoch: 0044 loss_train: 1.2323 loss_x_train_x: 0.5553 loss_x_train_y: 0.6751 loss_val: 1.1700 loss_x_val_x: 0.5662 loss_x_val_y: 0.6037 time: 0.0428s
#  Epoch: 0045 loss_train: 1.2255 loss_x_train_x: 0.5519 loss_x_train_y: 0.6717 loss_val: 1.1624 loss_x_val_x: 0.5621 loss_x_val_y: 0.6003 time: 0.0448s
#  Epoch: 0046 loss_train: 1.2212 loss_x_train_x: 0.5512 loss_x_train_y: 0.6681 loss_val: 1.1554 loss_x_val_x: 0.5590 loss_x_val_y: 0.5964 time: 0.0430s
#  Epoch: 0047 loss_train: 1.2097 loss_x_train_x: 0.5448 loss_x_train_y: 0.6631 loss_val: 1.1482 loss_x_val_x: 0.5552 loss_x_val_y: 0.5930 time: 0.0428s
#  Epoch: 0048 loss_train: 1.2011 loss_x_train_x: 0.5418 loss_x_train_y: 0.6574 loss_val: 1.1395 loss_x_val_x: 0.5508 loss_x_val_y: 0.5886 time: 0.0428s
#  Epoch: 0049 loss_train: 1.1967 loss_x_train_x: 0.5396 loss_x_train_y: 0.6552 loss_val: 1.1309 loss_x_val_x: 0.5473 loss_x_val_y: 0.5836 time: 0.0431s
#  Epoch: 0050 loss_train: 1.1867 loss_x_train_x: 0.5351 loss_x_train_y: 0.6497 loss_val: 1.1218 loss_x_val_x: 0.5434 loss_x_val_y: 0.5784 time: 0.0433s
#  Epoch: 0051 loss_train: 1.1770 loss_x_train_x: 0.5321 loss_x_train_y: 0.6430 loss_val: 1.1142 loss_x_val_x: 0.5402 loss_x_val_y: 0.5739 time: 0.0429s
#  Epoch: 0052 loss_train: 1.1699 loss_x_train_x: 0.5294 loss_x_train_y: 0.6386 loss_val: 1.1064 loss_x_val_x: 0.5374 loss_x_val_y: 0.5690 time: 0.0427s
#  Epoch: 0053 loss_train: 1.1648 loss_x_train_x: 0.5276 loss_x_train_y: 0.6352 loss_val: 1.0992 loss_x_val_x: 0.5337 loss_x_val_y: 0.5655 time: 0.0428s
#  Epoch: 0054 loss_train: 1.1559 loss_x_train_x: 0.5248 loss_x_train_y: 0.6293 loss_val: 1.0928 loss_x_val_x: 0.5305 loss_x_val_y: 0.5622 time: 0.0426s
#  Epoch: 0055 loss_train: 1.1464 loss_x_train_x: 0.5187 loss_x_train_y: 0.6259 loss_val: 1.0844 loss_x_val_x: 0.5276 loss_x_val_y: 0.5568 time: 0.0436s
#  Epoch: 0056 loss_train: 1.1392 loss_x_train_x: 0.5178 loss_x_train_y: 0.6196 loss_val: 1.0776 loss_x_val_x: 0.5242 loss_x_val_y: 0.5534 time: 0.0448s
#  Epoch: 0057 loss_train: 1.1338 loss_x_train_x: 0.5147 loss_x_train_y: 0.6172 loss_val: 1.0709 loss_x_val_x: 0.5206 loss_x_val_y: 0.5502 time: 0.0443s
#  Epoch: 0058 loss_train: 1.1259 loss_x_train_x: 0.5116 loss_x_train_y: 0.6124 loss_val: 1.0631 loss_x_val_x: 0.5169 loss_x_val_y: 0.5462 time: 0.0450s
#  Epoch: 0059 loss_train: 1.1204 loss_x_train_x: 0.5106 loss_x_train_y: 0.6079 loss_val: 1.0566 loss_x_val_x: 0.5144 loss_x_val_y: 0.5422 time: 0.0446s
#  Epoch: 0060 loss_train: 1.1110 loss_x_train_x: 0.5050 loss_x_train_y: 0.6041 loss_val: 1.0493 loss_x_val_x: 0.5101 loss_x_val_y: 0.5392 time: 0.0454s
#  Epoch: 0061 loss_train: 1.1070 loss_x_train_x: 0.5039 loss_x_train_y: 0.6012 loss_val: 1.0421 loss_x_val_x: 0.5067 loss_x_val_y: 0.5353 time: 0.0443s
#  Epoch: 0062 loss_train: 1.0969 loss_x_train_x: 0.5006 loss_x_train_y: 0.5944 loss_val: 1.0340 loss_x_val_x: 0.5037 loss_x_val_y: 0.5304 time: 0.0512s
#  Epoch: 0063 loss_train: 1.0922 loss_x_train_x: 0.4991 loss_x_train_y: 0.5912 loss_val: 1.0266 loss_x_val_x: 0.5000 loss_x_val_y: 0.5266 time: 0.0449s
#  Epoch: 0064 loss_train: 1.0843 loss_x_train_x: 0.4944 loss_x_train_y: 0.5880 loss_val: 1.0200 loss_x_val_x: 0.4977 loss_x_val_y: 0.5223 time: 0.0409s
#  Epoch: 0065 loss_train: 1.0764 loss_x_train_x: 0.4928 loss_x_train_y: 0.5817 loss_val: 1.0125 loss_x_val_x: 0.4943 loss_x_val_y: 0.5182 time: 0.0411s
#  Epoch: 0066 loss_train: 1.0725 loss_x_train_x: 0.4914 loss_x_train_y: 0.5792 loss_val: 1.0071 loss_x_val_x: 0.4918 loss_x_val_y: 0.5153 time: 0.0406s
#  Epoch: 0067 loss_train: 1.0633 loss_x_train_x: 0.4863 loss_x_train_y: 0.5751 loss_val: 1.0005 loss_x_val_x: 0.4895 loss_x_val_y: 0.5110 time: 0.0406s
#  Epoch: 0068 loss_train: 1.0589 loss_x_train_x: 0.4858 loss_x_train_y: 0.5712 loss_val: 0.9928 loss_x_val_x: 0.4852 loss_x_val_y: 0.5076 time: 0.0400s
#  Epoch: 0069 loss_train: 1.0519 loss_x_train_x: 0.4819 loss_x_train_y: 0.5682 loss_val: 0.9861 loss_x_val_x: 0.4828 loss_x_val_y: 0.5032 time: 0.0401s
#  Epoch: 0070 loss_train: 1.0453 loss_x_train_x: 0.4788 loss_x_train_y: 0.5646 loss_val: 0.9813 loss_x_val_x: 0.4795 loss_x_val_y: 0.5018 time: 0.0403s
#  Epoch: 0071 loss_train: 1.0382 loss_x_train_x: 0.4762 loss_x_train_y: 0.5600 loss_val: 0.9760 loss_x_val_x: 0.4767 loss_x_val_y: 0.4993 time: 0.0400s
#  Epoch: 0072 loss_train: 1.0340 loss_x_train_x: 0.4750 loss_x_train_y: 0.5571 loss_val: 0.9688 loss_x_val_x: 0.4734 loss_x_val_y: 0.4954 time: 0.0401s
#  Epoch: 0073 loss_train: 1.0272 loss_x_train_x: 0.4729 loss_x_train_y: 0.5523 loss_val: 0.9634 loss_x_val_x: 0.4715 loss_x_val_y: 0.4919 time: 0.0399s
#  Epoch: 0074 loss_train: 1.0197 loss_x_train_x: 0.4703 loss_x_train_y: 0.5475 loss_val: 0.9586 loss_x_val_x: 0.4701 loss_x_val_y: 0.4886 time: 0.0399s
#  Epoch: 0075 loss_train: 1.0128 loss_x_train_x: 0.4659 loss_x_train_y: 0.5451 loss_val: 0.9520 loss_x_val_x: 0.4660 loss_x_val_y: 0.4859 time: 0.0403s
#  Epoch: 0076 loss_train: 1.0056 loss_x_train_x: 0.4650 loss_x_train_y: 0.5388 loss_val: 0.9444 loss_x_val_x: 0.4634 loss_x_val_y: 0.4811 time: 0.0399s
#  Epoch: 0077 loss_train: 1.0014 loss_x_train_x: 0.4620 loss_x_train_y: 0.5375 loss_val: 0.9391 loss_x_val_x: 0.4608 loss_x_val_y: 0.4782 time: 0.0399s
#  Epoch: 0078 loss_train: 0.9960 loss_x_train_x: 0.4598 loss_x_train_y: 0.5344 loss_val: 0.9323 loss_x_val_x: 0.4579 loss_x_val_y: 0.4744 time: 0.0398s
#  Epoch: 0079 loss_train: 0.9898 loss_x_train_x: 0.4573 loss_x_train_y: 0.5306 loss_val: 0.9266 loss_x_val_x: 0.4555 loss_x_val_y: 0.4711 time: 0.0399s
#  Epoch: 0080 loss_train: 0.9848 loss_x_train_x: 0.4561 loss_x_train_y: 0.5268 loss_val: 0.9212 loss_x_val_x: 0.4538 loss_x_val_y: 0.4674 time: 0.0403s
#  Epoch: 0081 loss_train: 0.9763 loss_x_train_x: 0.4516 loss_x_train_y: 0.5228 loss_val: 0.9168 loss_x_val_x: 0.4511 loss_x_val_y: 0.4657 time: 0.0402s
#  Epoch: 0082 loss_train: 0.9738 loss_x_train_x: 0.4511 loss_x_train_y: 0.5208 loss_val: 0.9112 loss_x_val_x: 0.4494 loss_x_val_y: 0.4618 time: 0.0402s
#  Epoch: 0083 loss_train: 0.9638 loss_x_train_x: 0.4474 loss_x_train_y: 0.5146 loss_val: 0.9039 loss_x_val_x: 0.4455 loss_x_val_y: 0.4583 time: 0.0402s
#  Epoch: 0084 loss_train: 0.9629 loss_x_train_x: 0.4491 loss_x_train_y: 0.5119 loss_val: 0.8985 loss_x_val_x: 0.4437 loss_x_val_y: 0.4548 time: 0.0401s
#  Epoch: 0085 loss_train: 0.9548 loss_x_train_x: 0.4438 loss_x_train_y: 0.5091 loss_val: 0.8929 loss_x_val_x: 0.4399 loss_x_val_y: 0.4531 time: 0.0405s
#  Epoch: 0086 loss_train: 0.9506 loss_x_train_x: 0.4413 loss_x_train_y: 0.5073 loss_val: 0.8861 loss_x_val_x: 0.4369 loss_x_val_y: 0.4492 time: 0.0402s
#  Epoch: 0087 loss_train: 0.9470 loss_x_train_x: 0.4402 loss_x_train_y: 0.5048 loss_val: 0.8817 loss_x_val_x: 0.4341 loss_x_val_y: 0.4476 time: 0.0402s
#  Epoch: 0088 loss_train: 0.9393 loss_x_train_x: 0.4387 loss_x_train_y: 0.4987 loss_val: 0.8762 loss_x_val_x: 0.4326 loss_x_val_y: 0.4436 time: 0.0400s
#  Epoch: 0089 loss_train: 0.9362 loss_x_train_x: 0.4355 loss_x_train_y: 0.4988 loss_val: 0.8727 loss_x_val_x: 0.4300 loss_x_val_y: 0.4426 time: 0.0401s
#  Epoch: 0090 loss_train: 0.9320 loss_x_train_x: 0.4352 loss_x_train_y: 0.4950 loss_val: 0.8669 loss_x_val_x: 0.4272 loss_x_val_y: 0.4396 time: 0.0405s
#  Epoch: 0091 loss_train: 0.9269 loss_x_train_x: 0.4341 loss_x_train_y: 0.4909 loss_val: 0.8607 loss_x_val_x: 0.4255 loss_x_val_y: 0.4353 time: 0.0402s
#  Epoch: 0092 loss_train: 0.9189 loss_x_train_x: 0.4306 loss_x_train_y: 0.4864 loss_val: 0.8553 loss_x_val_x: 0.4234 loss_x_val_y: 0.4319 time: 0.0401s
#  Epoch: 0093 loss_train: 0.9142 loss_x_train_x: 0.4279 loss_x_train_y: 0.4844 loss_val: 0.8535 loss_x_val_x: 0.4221 loss_x_val_y: 0.4314 time: 0.0401s
#  Epoch: 0094 loss_train: 0.9066 loss_x_train_x: 0.4249 loss_x_train_y: 0.4798 loss_val: 0.8485 loss_x_val_x: 0.4198 loss_x_val_y: 0.4288 time: 0.0403s
#  Epoch: 0095 loss_train: 0.9018 loss_x_train_x: 0.4237 loss_x_train_y: 0.4762 loss_val: 0.8434 loss_x_val_x: 0.4177 loss_x_val_y: 0.4257 time: 0.0405s
#  Epoch: 0096 loss_train: 0.9002 loss_x_train_x: 0.4235 loss_x_train_y: 0.4748 loss_val: 0.8383 loss_x_val_x: 0.4163 loss_x_val_y: 0.4220 time: 0.0406s
#  Epoch: 0097 loss_train: 0.8945 loss_x_train_x: 0.4187 loss_x_train_y: 0.4739 loss_val: 0.8351 loss_x_val_x: 0.4149 loss_x_val_y: 0.4201 time: 0.0400s
#  Epoch: 0098 loss_train: 0.8876 loss_x_train_x: 0.4181 loss_x_train_y: 0.4676 loss_val: 0.8291 loss_x_val_x: 0.4134 loss_x_val_y: 0.4158 time: 0.0408s
#  Epoch: 0099 loss_train: 0.8808 loss_x_train_x: 0.4150 loss_x_train_y: 0.4639 loss_val: 0.8249 loss_x_val_x: 0.4112 loss_x_val_y: 0.4137 time: 0.0402s
#  Epoch: 0100 loss_train: 0.8808 loss_x_train_x: 0.4137 loss_x_train_y: 0.4653 loss_val: 0.8217 loss_x_val_x: 0.4090 loss_x_val_y: 0.4127 time: 0.0406s
#  Epoch: 0101 loss_train: 0.8745 loss_x_train_x: 0.4120 loss_x_train_y: 0.4607 loss_val: 0.8155 loss_x_val_x: 0.4061 loss_x_val_y: 0.4095 time: 0.0404s
#  Epoch: 0102 loss_train: 0.8675 loss_x_train_x: 0.4097 loss_x_train_y: 0.4559 loss_val: 0.8094 loss_x_val_x: 0.4034 loss_x_val_y: 0.4061 time: 0.0403s
#  Epoch: 0103 loss_train: 0.8667 loss_x_train_x: 0.4094 loss_x_train_y: 0.4554 loss_val: 0.8062 loss_x_val_x: 0.4021 loss_x_val_y: 0.4041 time: 0.0402s
#  Epoch: 0104 loss_train: 0.8610 loss_x_train_x: 0.4078 loss_x_train_y: 0.4513 loss_val: 0.8025 loss_x_val_x: 0.3999 loss_x_val_y: 0.4026 time: 0.0402s
#  Epoch: 0105 loss_train: 0.8535 loss_x_train_x: 0.4048 loss_x_train_y: 0.4468 loss_val: 0.7983 loss_x_val_x: 0.3993 loss_x_val_y: 0.3990 time: 0.0406s
#  Epoch: 0106 loss_train: 0.8484 loss_x_train_x: 0.4017 loss_x_train_y: 0.4448 loss_val: 0.7925 loss_x_val_x: 0.3969 loss_x_val_y: 0.3956 time: 0.0403s
#  Epoch: 0107 loss_train: 0.8465 loss_x_train_x: 0.4024 loss_x_train_y: 0.4422 loss_val: 0.7873 loss_x_val_x: 0.3948 loss_x_val_y: 0.3925 time: 0.0402s
#  Epoch: 0108 loss_train: 0.8428 loss_x_train_x: 0.3993 loss_x_train_y: 0.4416 loss_val: 0.7844 loss_x_val_x: 0.3941 loss_x_val_y: 0.3903 time: 0.0401s
#  Epoch: 0109 loss_train: 0.8356 loss_x_train_x: 0.3976 loss_x_train_y: 0.4361 loss_val: 0.7810 loss_x_val_x: 0.3914 loss_x_val_y: 0.3897 time: 0.0402s
#  Epoch: 0110 loss_train: 0.8317 loss_x_train_x: 0.3969 loss_x_train_y: 0.4329 loss_val: 0.7759 loss_x_val_x: 0.3893 loss_x_val_y: 0.3866 time: 0.0405s
#  Epoch: 0111 loss_train: 0.8303 loss_x_train_x: 0.3955 loss_x_train_y: 0.4328 loss_val: 0.7732 loss_x_val_x: 0.3889 loss_x_val_y: 0.3844 time: 0.0402s
#  Epoch: 0112 loss_train: 0.8222 loss_x_train_x: 0.3909 loss_x_train_y: 0.4294 loss_val: 0.7686 loss_x_val_x: 0.3862 loss_x_val_y: 0.3824 time: 0.0401s
#  Epoch: 0113 loss_train: 0.8173 loss_x_train_x: 0.3896 loss_x_train_y: 0.4259 loss_val: 0.7625 loss_x_val_x: 0.3832 loss_x_val_y: 0.3793 time: 0.0401s
#  Epoch: 0114 loss_train: 0.8169 loss_x_train_x: 0.3905 loss_x_train_y: 0.4245 loss_val: 0.7580 loss_x_val_x: 0.3818 loss_x_val_y: 0.3762 time: 0.0402s
#  Epoch: 0115 loss_train: 0.8092 loss_x_train_x: 0.3863 loss_x_train_y: 0.4209 loss_val: 0.7543 loss_x_val_x: 0.3807 loss_x_val_y: 0.3736 time: 0.0407s
#  Epoch: 0116 loss_train: 0.8067 loss_x_train_x: 0.3863 loss_x_train_y: 0.4185 loss_val: 0.7509 loss_x_val_x: 0.3792 loss_x_val_y: 0.3718 time: 0.0403s
#  Epoch: 0117 loss_train: 0.8030 loss_x_train_x: 0.3835 loss_x_train_y: 0.4176 loss_val: 0.7453 loss_x_val_x: 0.3764 loss_x_val_y: 0.3689 time: 0.0403s
#  Epoch: 0118 loss_train: 0.7951 loss_x_train_x: 0.3806 loss_x_train_y: 0.4126 loss_val: 0.7432 loss_x_val_x: 0.3757 loss_x_val_y: 0.3675 time: 0.0428s
#  Epoch: 0119 loss_train: 0.7932 loss_x_train_x: 0.3799 loss_x_train_y: 0.4115 loss_val: 0.7387 loss_x_val_x: 0.3732 loss_x_val_y: 0.3655 time: 0.0398s
#  Epoch: 0120 loss_train: 0.7907 loss_x_train_x: 0.3796 loss_x_train_y: 0.4092 loss_val: 0.7346 loss_x_val_x: 0.3711 loss_x_val_y: 0.3636 time: 0.0402s
#  Epoch: 0121 loss_train: 0.7859 loss_x_train_x: 0.3753 loss_x_train_y: 0.4087 loss_val: 0.7327 loss_x_val_x: 0.3705 loss_x_val_y: 0.3622 time: 0.0406s
#  Epoch: 0122 loss_train: 0.7794 loss_x_train_x: 0.3734 loss_x_train_y: 0.4041 loss_val: 0.7304 loss_x_val_x: 0.3688 loss_x_val_y: 0.3616 time: 0.0405s
#  Epoch: 0123 loss_train: 0.7802 loss_x_train_x: 0.3747 loss_x_train_y: 0.4036 loss_val: 0.7276 loss_x_val_x: 0.3673 loss_x_val_y: 0.3603 time: 0.0404s
#  Epoch: 0124 loss_train: 0.7782 loss_x_train_x: 0.3726 loss_x_train_y: 0.4036 loss_val: 0.7237 loss_x_val_x: 0.3658 loss_x_val_y: 0.3578 time: 0.0402s
#  Epoch: 0125 loss_train: 0.7709 loss_x_train_x: 0.3718 loss_x_train_y: 0.3972 loss_val: 0.7201 loss_x_val_x: 0.3646 loss_x_val_y: 0.3555 time: 0.0407s
#  Epoch: 0126 loss_train: 0.7631 loss_x_train_x: 0.3656 loss_x_train_y: 0.3957 loss_val: 0.7166 loss_x_val_x: 0.3630 loss_x_val_y: 0.3536 time: 0.0405s
#  Epoch: 0127 loss_train: 0.7611 loss_x_train_x: 0.3646 loss_x_train_y: 0.3946 loss_val: 0.7136 loss_x_val_x: 0.3615 loss_x_val_y: 0.3521 time: 0.0402s
#  Epoch: 0128 loss_train: 0.7559 loss_x_train_x: 0.3643 loss_x_train_y: 0.3897 loss_val: 0.7097 loss_x_val_x: 0.3593 loss_x_val_y: 0.3504 time: 0.0401s
#  Epoch: 0129 loss_train: 0.7541 loss_x_train_x: 0.3638 loss_x_train_y: 0.3884 loss_val: 0.7067 loss_x_val_x: 0.3585 loss_x_val_y: 0.3482 time: 0.0402s
#  Epoch: 0130 loss_train: 0.7479 loss_x_train_x: 0.3604 loss_x_train_y: 0.3856 loss_val: 0.7028 loss_x_val_x: 0.3562 loss_x_val_y: 0.3467 time: 0.0406s
#  Epoch: 0131 loss_train: 0.7491 loss_x_train_x: 0.3599 loss_x_train_y: 0.3873 loss_val: 0.7005 loss_x_val_x: 0.3558 loss_x_val_y: 0.3447 time: 0.0401s
#  Epoch: 0132 loss_train: 0.7476 loss_x_train_x: 0.3601 loss_x_train_y: 0.3855 loss_val: 0.6973 loss_x_val_x: 0.3539 loss_x_val_y: 0.3434 time: 0.0401s
#  Epoch: 0133 loss_train: 0.7386 loss_x_train_x: 0.3579 loss_x_train_y: 0.3788 loss_val: 0.6925 loss_x_val_x: 0.3523 loss_x_val_y: 0.3402 time: 0.0402s
#  Epoch: 0134 loss_train: 0.7377 loss_x_train_x: 0.3596 loss_x_train_y: 0.3762 loss_val: 0.6901 loss_x_val_x: 0.3512 loss_x_val_y: 0.3389 time: 0.0405s
#  Epoch: 0135 loss_train: 0.7336 loss_x_train_x: 0.3551 loss_x_train_y: 0.3766 loss_val: 0.6870 loss_x_val_x: 0.3505 loss_x_val_y: 0.3365 time: 0.0409s
#  Epoch: 0136 loss_train: 0.7307 loss_x_train_x: 0.3542 loss_x_train_y: 0.3746 loss_val: 0.6841 loss_x_val_x: 0.3493 loss_x_val_y: 0.3348 time: 0.0406s
#  Epoch: 0137 loss_train: 0.7251 loss_x_train_x: 0.3527 loss_x_train_y: 0.3706 loss_val: 0.6807 loss_x_val_x: 0.3462 loss_x_val_y: 0.3344 time: 0.0405s
#  Epoch: 0138 loss_train: 0.7211 loss_x_train_x: 0.3486 loss_x_train_y: 0.3706 loss_val: 0.6775 loss_x_val_x: 0.3448 loss_x_val_y: 0.3328 time: 0.0417s
#  Epoch: 0139 loss_train: 0.7216 loss_x_train_x: 0.3506 loss_x_train_y: 0.3691 loss_val: 0.6737 loss_x_val_x: 0.3429 loss_x_val_y: 0.3308 time: 0.0416s
#  Epoch: 0140 loss_train: 0.7155 loss_x_train_x: 0.3480 loss_x_train_y: 0.3656 loss_val: 0.6700 loss_x_val_x: 0.3418 loss_x_val_y: 0.3282 time: 0.0479s
#  Epoch: 0141 loss_train: 0.7143 loss_x_train_x: 0.3475 loss_x_train_y: 0.3648 loss_val: 0.6689 loss_x_val_x: 0.3410 loss_x_val_y: 0.3278 time: 0.0446s
#  Epoch: 0142 loss_train: 0.7104 loss_x_train_x: 0.3454 loss_x_train_y: 0.3631 loss_val: 0.6663 loss_x_val_x: 0.3411 loss_x_val_y: 0.3252 time: 0.0465s
#  Epoch: 0143 loss_train: 0.7112 loss_x_train_x: 0.3466 loss_x_train_y: 0.3627 loss_val: 0.6647 loss_x_val_x: 0.3393 loss_x_val_y: 0.3254 time: 0.0410s
#  Epoch: 0144 loss_train: 0.7050 loss_x_train_x: 0.3445 loss_x_train_y: 0.3586 loss_val: 0.6613 loss_x_val_x: 0.3377 loss_x_val_y: 0.3236 time: 0.0408s
#  Epoch: 0145 loss_train: 0.7028 loss_x_train_x: 0.3415 loss_x_train_y: 0.3594 loss_val: 0.6587 loss_x_val_x: 0.3377 loss_x_val_y: 0.3210 time: 0.0409s
#  Epoch: 0146 loss_train: 0.6987 loss_x_train_x: 0.3403 loss_x_train_y: 0.3565 loss_val: 0.6554 loss_x_val_x: 0.3351 loss_x_val_y: 0.3202 time: 0.0406s
#  Epoch: 0147 loss_train: 0.6970 loss_x_train_x: 0.3428 loss_x_train_y: 0.3523 loss_val: 0.6532 loss_x_val_x: 0.3340 loss_x_val_y: 0.3192 time: 0.0407s
#  Epoch: 0148 loss_train: 0.6920 loss_x_train_x: 0.3382 loss_x_train_y: 0.3519 loss_val: 0.6499 loss_x_val_x: 0.3323 loss_x_val_y: 0.3175 time: 0.0406s
#  Epoch: 0149 loss_train: 0.6947 loss_x_train_x: 0.3390 loss_x_train_y: 0.3538 loss_val: 0.6474 loss_x_val_x: 0.3311 loss_x_val_y: 0.3163 time: 0.0405s
#  Epoch: 0150 loss_train: 0.6893 loss_x_train_x: 0.3375 loss_x_train_y: 0.3499 loss_val: 0.6454 loss_x_val_x: 0.3307 loss_x_val_y: 0.3147 time: 0.0408s
#  Epoch: 0151 loss_train: 0.6847 loss_x_train_x: 0.3342 loss_x_train_y: 0.3486 loss_val: 0.6430 loss_x_val_x: 0.3298 loss_x_val_y: 0.3132 time: 0.0405s
#  Epoch: 0152 loss_train: 0.6820 loss_x_train_x: 0.3326 loss_x_train_y: 0.3476 loss_val: 0.6409 loss_x_val_x: 0.3290 loss_x_val_y: 0.3119 time: 0.0406s
#  Epoch: 0153 loss_train: 0.6761 loss_x_train_x: 0.3320 loss_x_train_y: 0.3422 loss_val: 0.6384 loss_x_val_x: 0.3277 loss_x_val_y: 0.3107 time: 0.0398s
#  Epoch: 0154 loss_train: 0.6746 loss_x_train_x: 0.3313 loss_x_train_y: 0.3414 loss_val: 0.6346 loss_x_val_x: 0.3259 loss_x_val_y: 0.3087 time: 0.0397s
#  Epoch: 0155 loss_train: 0.6728 loss_x_train_x: 0.3304 loss_x_train_y: 0.3405 loss_val: 0.6321 loss_x_val_x: 0.3246 loss_x_val_y: 0.3075 time: 0.0401s
#  Epoch: 0156 loss_train: 0.6719 loss_x_train_x: 0.3306 loss_x_train_y: 0.3394 loss_val: 0.6297 loss_x_val_x: 0.3230 loss_x_val_y: 0.3067 time: 0.0411s
#  Epoch: 0157 loss_train: 0.6633 loss_x_train_x: 0.3244 loss_x_train_y: 0.3370 loss_val: 0.6269 loss_x_val_x: 0.3216 loss_x_val_y: 0.3053 time: 0.0406s
#  Epoch: 0158 loss_train: 0.6646 loss_x_train_x: 0.3257 loss_x_train_y: 0.3370 loss_val: 0.6248 loss_x_val_x: 0.3208 loss_x_val_y: 0.3041 time: 0.0406s
#  Epoch: 0159 loss_train: 0.6636 loss_x_train_x: 0.3261 loss_x_train_y: 0.3356 loss_val: 0.6205 loss_x_val_x: 0.3188 loss_x_val_y: 0.3018 time: 0.0407s
#  Epoch: 0160 loss_train: 0.6595 loss_x_train_x: 0.3238 loss_x_train_y: 0.3338 loss_val: 0.6197 loss_x_val_x: 0.3178 loss_x_val_y: 0.3019 time: 0.0412s
#  Epoch: 0161 loss_train: 0.6558 loss_x_train_x: 0.3245 loss_x_train_y: 0.3294 loss_val: 0.6178 loss_x_val_x: 0.3168 loss_x_val_y: 0.3010 time: 0.0408s
#  Epoch: 0162 loss_train: 0.6574 loss_x_train_x: 0.3242 loss_x_train_y: 0.3313 loss_val: 0.6162 loss_x_val_x: 0.3167 loss_x_val_y: 0.2995 time: 0.0405s
#  Epoch: 0163 loss_train: 0.6522 loss_x_train_x: 0.3183 loss_x_train_y: 0.3320 loss_val: 0.6143 loss_x_val_x: 0.3152 loss_x_val_y: 0.2991 time: 0.0404s
#  Epoch: 0164 loss_train: 0.6496 loss_x_train_x: 0.3194 loss_x_train_y: 0.3283 loss_val: 0.6122 loss_x_val_x: 0.3143 loss_x_val_y: 0.2979 time: 0.0405s
#  Epoch: 0165 loss_train: 0.6502 loss_x_train_x: 0.3187 loss_x_train_y: 0.3296 loss_val: 0.6097 loss_x_val_x: 0.3133 loss_x_val_y: 0.2964 time: 0.0410s
#  Epoch: 0166 loss_train: 0.6460 loss_x_train_x: 0.3183 loss_x_train_y: 0.3258 loss_val: 0.6079 loss_x_val_x: 0.3124 loss_x_val_y: 0.2955 time: 0.0409s
#  Epoch: 0167 loss_train: 0.6446 loss_x_train_x: 0.3179 loss_x_train_y: 0.3248 loss_val: 0.6050 loss_x_val_x: 0.3102 loss_x_val_y: 0.2948 time: 0.0432s
#  Epoch: 0168 loss_train: 0.6392 loss_x_train_x: 0.3154 loss_x_train_y: 0.3219 loss_val: 0.6035 loss_x_val_x: 0.3094 loss_x_val_y: 0.2941 time: 0.0405s
#  Epoch: 0169 loss_train: 0.6372 loss_x_train_x: 0.3138 loss_x_train_y: 0.3215 loss_val: 0.6012 loss_x_val_x: 0.3082 loss_x_val_y: 0.2930 time: 0.0405s
#  Epoch: 0170 loss_train: 0.6367 loss_x_train_x: 0.3123 loss_x_train_y: 0.3225 loss_val: 0.5996 loss_x_val_x: 0.3077 loss_x_val_y: 0.2918 time: 0.0408s
#  Epoch: 0171 loss_train: 0.6348 loss_x_train_x: 0.3131 loss_x_train_y: 0.3198 loss_val: 0.5966 loss_x_val_x: 0.3069 loss_x_val_y: 0.2898 time: 0.0404s
#  Epoch: 0172 loss_train: 0.6326 loss_x_train_x: 0.3107 loss_x_train_y: 0.3200 loss_val: 0.5942 loss_x_val_x: 0.3056 loss_x_val_y: 0.2885 time: 0.0406s
#  Epoch: 0173 loss_train: 0.6283 loss_x_train_x: 0.3100 loss_x_train_y: 0.3164 loss_val: 0.5928 loss_x_val_x: 0.3048 loss_x_val_y: 0.2880 time: 0.0405s
#  Epoch: 0174 loss_train: 0.6301 loss_x_train_x: 0.3112 loss_x_train_y: 0.3170 loss_val: 0.5906 loss_x_val_x: 0.3032 loss_x_val_y: 0.2873 time: 0.0405s
#  Epoch: 0175 loss_train: 0.6248 loss_x_train_x: 0.3091 loss_x_train_y: 0.3138 loss_val: 0.5889 loss_x_val_x: 0.3020 loss_x_val_y: 0.2869 time: 0.0408s
#  Epoch: 0176 loss_train: 0.6251 loss_x_train_x: 0.3094 loss_x_train_y: 0.3138 loss_val: 0.5875 loss_x_val_x: 0.3014 loss_x_val_y: 0.2861 time: 0.0405s
#  Epoch: 0177 loss_train: 0.6199 loss_x_train_x: 0.3067 loss_x_train_y: 0.3112 loss_val: 0.5852 loss_x_val_x: 0.3006 loss_x_val_y: 0.2847 time: 0.0404s
#  Epoch: 0178 loss_train: 0.6208 loss_x_train_x: 0.3064 loss_x_train_y: 0.3125 loss_val: 0.5845 loss_x_val_x: 0.3002 loss_x_val_y: 0.2843 time: 0.0404s
#  Epoch: 0179 loss_train: 0.6152 loss_x_train_x: 0.3042 loss_x_train_y: 0.3090 loss_val: 0.5824 loss_x_val_x: 0.2989 loss_x_val_y: 0.2835 time: 0.0407s
#  Epoch: 0180 loss_train: 0.6168 loss_x_train_x: 0.3058 loss_x_train_y: 0.3091 loss_val: 0.5825 loss_x_val_x: 0.3000 loss_x_val_y: 0.2826 time: 0.0408s
#  Epoch: 0181 loss_train: 0.6164 loss_x_train_x: 0.3044 loss_x_train_y: 0.3101 loss_val: 0.5801 loss_x_val_x: 0.2987 loss_x_val_y: 0.2814 time: 0.0406s
#  Epoch: 0182 loss_train: 0.6148 loss_x_train_x: 0.3054 loss_x_train_y: 0.3075 loss_val: 0.5788 loss_x_val_x: 0.2981 loss_x_val_y: 0.2807 time: 0.0406s
#  Epoch: 0183 loss_train: 0.6085 loss_x_train_x: 0.3023 loss_x_train_y: 0.3043 loss_val: 0.5762 loss_x_val_x: 0.2962 loss_x_val_y: 0.2801 time: 0.0366s
#  Epoch: 0184 loss_train: 0.6093 loss_x_train_x: 0.3008 loss_x_train_y: 0.3066 loss_val: 0.5741 loss_x_val_x: 0.2951 loss_x_val_y: 0.2791 time: 0.0347s
#  Epoch: 0185 loss_train: 0.6059 loss_x_train_x: 0.3008 loss_x_train_y: 0.3032 loss_val: 0.5728 loss_x_val_x: 0.2950 loss_x_val_y: 0.2777 time: 0.0347s
#  Epoch: 0186 loss_train: 0.6012 loss_x_train_x: 0.2980 loss_x_train_y: 0.3013 loss_val: 0.5703 loss_x_val_x: 0.2937 loss_x_val_y: 0.2766 time: 0.0350s
#  Epoch: 0187 loss_train: 0.6038 loss_x_train_x: 0.2983 loss_x_train_y: 0.3036 loss_val: 0.5703 loss_x_val_x: 0.2938 loss_x_val_y: 0.2765 time: 0.0345s
#  Epoch: 0188 loss_train: 0.6007 loss_x_train_x: 0.2976 loss_x_train_y: 0.3011 loss_val: 0.5690 loss_x_val_x: 0.2932 loss_x_val_y: 0.2758 time: 0.0344s
#  Epoch: 0189 loss_train: 0.5951 loss_x_train_x: 0.2963 loss_x_train_y: 0.2968 loss_val: 0.5670 loss_x_val_x: 0.2920 loss_x_val_y: 0.2750 time: 0.0344s
#  Epoch: 0190 loss_train: 0.5990 loss_x_train_x: 0.2969 loss_x_train_y: 0.3002 loss_val: 0.5662 loss_x_val_x: 0.2912 loss_x_val_y: 0.2750 time: 0.0344s
#  Epoch: 0191 loss_train: 0.5968 loss_x_train_x: 0.2960 loss_x_train_y: 0.2988 loss_val: 0.5647 loss_x_val_x: 0.2905 loss_x_val_y: 0.2742 time: 0.0345s
#  Epoch: 0192 loss_train: 0.5932 loss_x_train_x: 0.2945 loss_x_train_y: 0.2968 loss_val: 0.5625 loss_x_val_x: 0.2896 loss_x_val_y: 0.2729 time: 0.0350s
#  Epoch: 0193 loss_train: 0.5891 loss_x_train_x: 0.2923 loss_x_train_y: 0.2948 loss_val: 0.5600 loss_x_val_x: 0.2881 loss_x_val_y: 0.2719 time: 0.0347s
#  Epoch: 0194 loss_train: 0.5902 loss_x_train_x: 0.2928 loss_x_train_y: 0.2955 loss_val: 0.5592 loss_x_val_x: 0.2873 loss_x_val_y: 0.2718 time: 0.0345s
#  Epoch: 0195 loss_train: 0.5872 loss_x_train_x: 0.2921 loss_x_train_y: 0.2932 loss_val: 0.5586 loss_x_val_x: 0.2873 loss_x_val_y: 0.2713 time: 0.0346s
#  Epoch: 0196 loss_train: 0.5848 loss_x_train_x: 0.2906 loss_x_train_y: 0.2923 loss_val: 0.5574 loss_x_val_x: 0.2866 loss_x_val_y: 0.2707 time: 0.0346s
#  Epoch: 0197 loss_train: 0.5860 loss_x_train_x: 0.2921 loss_x_train_y: 0.2920 loss_val: 0.5565 loss_x_val_x: 0.2863 loss_x_val_y: 0.2702 time: 0.0342s
#  Epoch: 0198 loss_train: 0.5816 loss_x_train_x: 0.2882 loss_x_train_y: 0.2915 loss_val: 0.5552 loss_x_val_x: 0.2851 loss_x_val_y: 0.2701 time: 0.0345s
#  Epoch: 0199 loss_train: 0.5827 loss_x_train_x: 0.2892 loss_x_train_y: 0.2916 loss_val: 0.5535 loss_x_val_x: 0.2835 loss_x_val_y: 0.2700 time: 0.0339s
#  Epoch: 0200 loss_train: 0.5775 loss_x_train_x: 0.2883 loss_x_train_y: 0.2873 loss_val: 0.5528 loss_x_val_x: 0.2836 loss_x_val_y: 0.2692 time: 0.0339s
#  Epoch: 0201 loss_train: 0.5759 loss_x_train_x: 0.2867 loss_x_train_y: 0.2872 loss_val: 0.5502 loss_x_val_x: 0.2821 loss_x_val_y: 0.2681 time: 0.0351s
#  Epoch: 0202 loss_train: 0.5801 loss_x_train_x: 0.2885 loss_x_train_y: 0.2897 loss_val: 0.5484 loss_x_val_x: 0.2817 loss_x_val_y: 0.2667 time: 0.0368s
#  Epoch: 0203 loss_train: 0.5718 loss_x_train_x: 0.2835 loss_x_train_y: 0.2864 loss_val: 0.5477 loss_x_val_x: 0.2811 loss_x_val_y: 0.2666 time: 0.0358s
#  Epoch: 0204 loss_train: 0.5729 loss_x_train_x: 0.2843 loss_x_train_y: 0.2867 loss_val: 0.5472 loss_x_val_x: 0.2807 loss_x_val_y: 0.2665 time: 0.0357s
#  Epoch: 0205 loss_train: 0.5706 loss_x_train_x: 0.2836 loss_x_train_y: 0.2852 loss_val: 0.5456 loss_x_val_x: 0.2800 loss_x_val_y: 0.2655 time: 0.0354s
#  Epoch: 0206 loss_train: 0.5693 loss_x_train_x: 0.2834 loss_x_train_y: 0.2840 loss_val: 0.5438 loss_x_val_x: 0.2792 loss_x_val_y: 0.2646 time: 0.0363s
#  Epoch: 0207 loss_train: 0.5668 loss_x_train_x: 0.2819 loss_x_train_y: 0.2830 loss_val: 0.5428 loss_x_val_x: 0.2788 loss_x_val_y: 0.2640 time: 0.0345s
#  Epoch: 0208 loss_train: 0.5673 loss_x_train_x: 0.2818 loss_x_train_y: 0.2836 loss_val: 0.5419 loss_x_val_x: 0.2781 loss_x_val_y: 0.2638 time: 0.0438s
#  Epoch: 0209 loss_train: 0.5665 loss_x_train_x: 0.2818 loss_x_train_y: 0.2828 loss_val: 0.5402 loss_x_val_x: 0.2769 loss_x_val_y: 0.2633 time: 0.0371s
#  Epoch: 0210 loss_train: 0.5673 loss_x_train_x: 0.2830 loss_x_train_y: 0.2823 loss_val: 0.5404 loss_x_val_x: 0.2772 loss_x_val_y: 0.2632 time: 0.0369s
#  Epoch: 0211 loss_train: 0.5621 loss_x_train_x: 0.2812 loss_x_train_y: 0.2790 loss_val: 0.5385 loss_x_val_x: 0.2755 loss_x_val_y: 0.2629 time: 0.0341s
#  Epoch: 0212 loss_train: 0.5583 loss_x_train_x: 0.2785 loss_x_train_y: 0.2779 loss_val: 0.5380 loss_x_val_x: 0.2755 loss_x_val_y: 0.2626 time: 0.0332s
#  Epoch: 0213 loss_train: 0.5600 loss_x_train_x: 0.2784 loss_x_train_y: 0.2796 loss_val: 0.5378 loss_x_val_x: 0.2757 loss_x_val_y: 0.2621 time: 0.0332s
#  Epoch: 0214 loss_train: 0.5576 loss_x_train_x: 0.2762 loss_x_train_y: 0.2795 loss_val: 0.5366 loss_x_val_x: 0.2749 loss_x_val_y: 0.2617 time: 0.0333s
#  Epoch: 0215 loss_train: 0.5606 loss_x_train_x: 0.2783 loss_x_train_y: 0.2803 loss_val: 0.5369 loss_x_val_x: 0.2748 loss_x_val_y: 0.2621 time: 0.0392s
#  Epoch: 0216 loss_train: 0.5561 loss_x_train_x: 0.2761 loss_x_train_y: 0.2781 loss_val: 0.5341 loss_x_val_x: 0.2735 loss_x_val_y: 0.2606 time: 0.0396s
#  Epoch: 0217 loss_train: 0.5543 loss_x_train_x: 0.2758 loss_x_train_y: 0.2765 loss_val: 0.5344 loss_x_val_x: 0.2743 loss_x_val_y: 0.2602 time: 0.0392s
#  Epoch: 0218 loss_train: 0.5564 loss_x_train_x: 0.2764 loss_x_train_y: 0.2781 loss_val: 0.5331 loss_x_val_x: 0.2735 loss_x_val_y: 0.2597 time: 0.0392s
#  Epoch: 0219 loss_train: 0.5503 loss_x_train_x: 0.2750 loss_x_train_y: 0.2734 loss_val: 0.5324 loss_x_val_x: 0.2729 loss_x_val_y: 0.2594 time: 0.0392s
#  Epoch: 0220 loss_train: 0.5540 loss_x_train_x: 0.2761 loss_x_train_y: 0.2760 loss_val: 0.5311 loss_x_val_x: 0.2716 loss_x_val_y: 0.2595 time: 0.0450s
#  Epoch: 0221 loss_train: 0.5527 loss_x_train_x: 0.2763 loss_x_train_y: 0.2745 loss_val: 0.5293 loss_x_val_x: 0.2706 loss_x_val_y: 0.2587 time: 0.0396s
#  Epoch: 0222 loss_train: 0.5491 loss_x_train_x: 0.2738 loss_x_train_y: 0.2733 loss_val: 0.5279 loss_x_val_x: 0.2698 loss_x_val_y: 0.2581 time: 0.0392s
#  Epoch: 0223 loss_train: 0.5451 loss_x_train_x: 0.2702 loss_x_train_y: 0.2730 loss_val: 0.5274 loss_x_val_x: 0.2700 loss_x_val_y: 0.2574 time: 0.0392s
#  Epoch: 0224 loss_train: 0.5468 loss_x_train_x: 0.2719 loss_x_train_y: 0.2731 loss_val: 0.5267 loss_x_val_x: 0.2693 loss_x_val_y: 0.2574 time: 0.0392s
#  Epoch: 0225 loss_train: 0.5447 loss_x_train_x: 0.2701 loss_x_train_y: 0.2727 loss_val: 0.5256 loss_x_val_x: 0.2685 loss_x_val_y: 0.2570 time: 0.0392s
#  Epoch: 0226 loss_train: 0.5464 loss_x_train_x: 0.2716 loss_x_train_y: 0.2729 loss_val: 0.5249 loss_x_val_x: 0.2682 loss_x_val_y: 0.2567 time: 0.0392s
#  Epoch: 0227 loss_train: 0.5448 loss_x_train_x: 0.2713 loss_x_train_y: 0.2716 loss_val: 0.5231 loss_x_val_x: 0.2666 loss_x_val_y: 0.2566 time: 0.0396s
#  Epoch: 0228 loss_train: 0.5426 loss_x_train_x: 0.2685 loss_x_train_y: 0.2721 loss_val: 0.5224 loss_x_val_x: 0.2660 loss_x_val_y: 0.2564 time: 0.0392s
#  Epoch: 0229 loss_train: 0.5413 loss_x_train_x: 0.2690 loss_x_train_y: 0.2704 loss_val: 0.5228 loss_x_val_x: 0.2667 loss_x_val_y: 0.2561 time: 0.0396s
#  Epoch: 0230 loss_train: 0.5401 loss_x_train_x: 0.2687 loss_x_train_y: 0.2695 loss_val: 0.5213 loss_x_val_x: 0.2659 loss_x_val_y: 0.2555 time: 0.0406s
#  Epoch: 0231 loss_train: 0.5398 loss_x_train_x: 0.2687 loss_x_train_y: 0.2692 loss_val: 0.5213 loss_x_val_x: 0.2658 loss_x_val_y: 0.2555 time: 0.0400s
#  Epoch: 0232 loss_train: 0.5388 loss_x_train_x: 0.2661 loss_x_train_y: 0.2708 loss_val: 0.5207 loss_x_val_x: 0.2655 loss_x_val_y: 0.2552 time: 0.0405s
#  Epoch: 0233 loss_train: 0.5389 loss_x_train_x: 0.2678 loss_x_train_y: 0.2693 loss_val: 0.5197 loss_x_val_x: 0.2647 loss_x_val_y: 0.2550 time: 0.0402s
#  Epoch: 0234 loss_train: 0.5378 loss_x_train_x: 0.2678 loss_x_train_y: 0.2681 loss_val: 0.5193 loss_x_val_x: 0.2648 loss_x_val_y: 0.2546 time: 0.0401s
#  Epoch: 0235 loss_train: 0.5339 loss_x_train_x: 0.2661 loss_x_train_y: 0.2659 loss_val: 0.5181 loss_x_val_x: 0.2637 loss_x_val_y: 0.2544 time: 0.0401s
#  Epoch: 0236 loss_train: 0.5359 loss_x_train_x: 0.2662 loss_x_train_y: 0.2678 loss_val: 0.5170 loss_x_val_x: 0.2629 loss_x_val_y: 0.2541 time: 0.0401s
#  Epoch: 0237 loss_train: 0.5367 loss_x_train_x: 0.2665 loss_x_train_y: 0.2683 loss_val: 0.5169 loss_x_val_x: 0.2635 loss_x_val_y: 0.2534 time: 0.0406s
#  Epoch: 0238 loss_train: 0.5317 loss_x_train_x: 0.2639 loss_x_train_y: 0.2659 loss_val: 0.5156 loss_x_val_x: 0.2627 loss_x_val_y: 0.2529 time: 0.0402s
#  Epoch: 0239 loss_train: 0.5330 loss_x_train_x: 0.2665 loss_x_train_y: 0.2646 loss_val: 0.5147 loss_x_val_x: 0.2627 loss_x_val_y: 0.2521 time: 0.0401s
#  Epoch: 0240 loss_train: 0.5299 loss_x_train_x: 0.2613 loss_x_train_y: 0.2667 loss_val: 0.5147 loss_x_val_x: 0.2630 loss_x_val_y: 0.2518 time: 0.0401s
#  Epoch: 0241 loss_train: 0.5306 loss_x_train_x: 0.2639 loss_x_train_y: 0.2648 loss_val: 0.5134 loss_x_val_x: 0.2618 loss_x_val_y: 0.2516 time: 0.0401s
#  Epoch: 0242 loss_train: 0.5321 loss_x_train_x: 0.2655 loss_x_train_y: 0.2647 loss_val: 0.5139 loss_x_val_x: 0.2619 loss_x_val_y: 0.2520 time: 0.0405s
#  Epoch: 0243 loss_train: 0.5272 loss_x_train_x: 0.2619 loss_x_train_y: 0.2633 loss_val: 0.5140 loss_x_val_x: 0.2619 loss_x_val_y: 0.2521 time: 0.0402s
#  Epoch: 0244 loss_train: 0.5281 loss_x_train_x: 0.2631 loss_x_train_y: 0.2631 loss_val: 0.5123 loss_x_val_x: 0.2609 loss_x_val_y: 0.2514 time: 0.0401s
#  Epoch: 0245 loss_train: 0.5259 loss_x_train_x: 0.2604 loss_x_train_y: 0.2636 loss_val: 0.5123 loss_x_val_x: 0.2610 loss_x_val_y: 0.2513 time: 0.0634s
#  Epoch: 0246 loss_train: 0.5261 loss_x_train_x: 0.2594 loss_x_train_y: 0.2649 loss_val: 0.5114 loss_x_val_x: 0.2603 loss_x_val_y: 0.2512 time: 0.0341s
#  Epoch: 0247 loss_train: 0.5278 loss_x_train_x: 0.2635 loss_x_train_y: 0.2624 loss_val: 0.5098 loss_x_val_x: 0.2596 loss_x_val_y: 0.2502 time: 0.0395s
#  Epoch: 0248 loss_train: 0.5271 loss_x_train_x: 0.2612 loss_x_train_y: 0.2640 loss_val: 0.5099 loss_x_val_x: 0.2597 loss_x_val_y: 0.2502 time: 0.0404s
#  Epoch: 0249 loss_train: 0.5269 loss_x_train_x: 0.2618 loss_x_train_y: 0.2631 loss_val: 0.5088 loss_x_val_x: 0.2589 loss_x_val_y: 0.2499 time: 0.0403s
#  Epoch: 0250 loss_train: 0.5223 loss_x_train_x: 0.2577 loss_x_train_y: 0.2627 loss_val: 0.5081 loss_x_val_x: 0.2585 loss_x_val_y: 0.2497 time: 0.0403s
#  Epoch: 0251 loss_train: 0.5234 loss_x_train_x: 0.2597 loss_x_train_y: 0.2617 loss_val: 0.5067 loss_x_val_x: 0.2575 loss_x_val_y: 0.2492 time: 0.0403s
#  Epoch: 0252 loss_train: 0.5217 loss_x_train_x: 0.2594 loss_x_train_y: 0.2604 loss_val: 0.5069 loss_x_val_x: 0.2578 loss_x_val_y: 0.2492 time: 0.0408s
#  Epoch: 0253 loss_train: 0.5210 loss_x_train_x: 0.2592 loss_x_train_y: 0.2599 loss_val: 0.5066 loss_x_val_x: 0.2576 loss_x_val_y: 0.2489 time: 0.0403s
#  Epoch: 0254 loss_train: 0.5187 loss_x_train_x: 0.2582 loss_x_train_y: 0.2586 loss_val: 0.5048 loss_x_val_x: 0.2564 loss_x_val_y: 0.2485 time: 0.0403s
#  Epoch: 0255 loss_train: 0.5212 loss_x_train_x: 0.2594 loss_x_train_y: 0.2598 loss_val: 0.5052 loss_x_val_x: 0.2568 loss_x_val_y: 0.2484 time: 0.0403s
#  Epoch: 0256 loss_train: 0.5144 loss_x_train_x: 0.2547 loss_x_train_y: 0.2579 loss_val: 0.5050 loss_x_val_x: 0.2567 loss_x_val_y: 0.2483 time: 0.0403s
#  Epoch: 0257 loss_train: 0.5162 loss_x_train_x: 0.2569 loss_x_train_y: 0.2573 loss_val: 0.5047 loss_x_val_x: 0.2564 loss_x_val_y: 0.2483 time: 0.0407s
#  Epoch: 0258 loss_train: 0.5158 loss_x_train_x: 0.2570 loss_x_train_y: 0.2568 loss_val: 0.5043 loss_x_val_x: 0.2562 loss_x_val_y: 0.2481 time: 0.0403s
#  Epoch: 0259 loss_train: 0.5172 loss_x_train_x: 0.2585 loss_x_train_y: 0.2568 loss_val: 0.5041 loss_x_val_x: 0.2560 loss_x_val_y: 0.2480 time: 0.0403s
#  Epoch: 0260 loss_train: 0.5174 loss_x_train_x: 0.2566 loss_x_train_y: 0.2588 loss_val: 0.5027 loss_x_val_x: 0.2550 loss_x_val_y: 0.2477 time: 0.0398s
#  Epoch: 0261 loss_train: 0.5147 loss_x_train_x: 0.2570 loss_x_train_y: 0.2559 loss_val: 0.5025 loss_x_val_x: 0.2551 loss_x_val_y: 0.2474 time: 0.0341s
#  Epoch: 0262 loss_train: 0.5166 loss_x_train_x: 0.2582 loss_x_train_y: 0.2564 loss_val: 0.5027 loss_x_val_x: 0.2552 loss_x_val_y: 0.2475 time: 0.0345s
#  Epoch: 0263 loss_train: 0.5116 loss_x_train_x: 0.2547 loss_x_train_y: 0.2549 loss_val: 0.5017 loss_x_val_x: 0.2544 loss_x_val_y: 0.2473 time: 0.0353s
#  Epoch: 0264 loss_train: 0.5130 loss_x_train_x: 0.2552 loss_x_train_y: 0.2559 loss_val: 0.5010 loss_x_val_x: 0.2540 loss_x_val_y: 0.2470 time: 0.0350s
#  Epoch: 0265 loss_train: 0.5109 loss_x_train_x: 0.2531 loss_x_train_y: 0.2558 loss_val: 0.5003 loss_x_val_x: 0.2534 loss_x_val_y: 0.2469 time: 0.0338s
#  Epoch: 0266 loss_train: 0.5115 loss_x_train_x: 0.2529 loss_x_train_y: 0.2567 loss_val: 0.4999 loss_x_val_x: 0.2532 loss_x_val_y: 0.2467 time: 0.0337s
#  Epoch: 0267 loss_train: 0.5108 loss_x_train_x: 0.2551 loss_x_train_y: 0.2539 loss_val: 0.4995 loss_x_val_x: 0.2531 loss_x_val_y: 0.2464 time: 0.0366s
#  Epoch: 0268 loss_train: 0.5105 loss_x_train_x: 0.2539 loss_x_train_y: 0.2547 loss_val: 0.4991 loss_x_val_x: 0.2527 loss_x_val_y: 0.2464 time: 0.0352s
#  Epoch: 0269 loss_train: 0.5078 loss_x_train_x: 0.2523 loss_x_train_y: 0.2536 loss_val: 0.4987 loss_x_val_x: 0.2523 loss_x_val_y: 0.2464 time: 0.0360s
#  Epoch: 0270 loss_train: 0.5078 loss_x_train_x: 0.2518 loss_x_train_y: 0.2540 loss_val: 0.4977 loss_x_val_x: 0.2517 loss_x_val_y: 0.2460 time: 0.0378s
#  Epoch: 0271 loss_train: 0.5066 loss_x_train_x: 0.2530 loss_x_train_y: 0.2517 loss_val: 0.4991 loss_x_val_x: 0.2527 loss_x_val_y: 0.2464 time: 0.0348s
#  Epoch: 0272 loss_train: 0.5090 loss_x_train_x: 0.2522 loss_x_train_y: 0.2548 loss_val: 0.4987 loss_x_val_x: 0.2522 loss_x_val_y: 0.2465 time: 0.0354s
#  Epoch: 0273 loss_train: 0.5076 loss_x_train_x: 0.2522 loss_x_train_y: 0.2535 loss_val: 0.4983 loss_x_val_x: 0.2520 loss_x_val_y: 0.2464 time: 0.0363s
#  Epoch: 0274 loss_train: 0.5068 loss_x_train_x: 0.2510 loss_x_train_y: 0.2540 loss_val: 0.4980 loss_x_val_x: 0.2517 loss_x_val_y: 0.2463 time: 0.0355s
#  Epoch: 0275 loss_train: 0.5066 loss_x_train_x: 0.2525 loss_x_train_y: 0.2522 loss_val: 0.4967 loss_x_val_x: 0.2506 loss_x_val_y: 0.2461 time: 0.0345s
#  Epoch: 0276 loss_train: 0.5068 loss_x_train_x: 0.2513 loss_x_train_y: 0.2536 loss_val: 0.4964 loss_x_val_x: 0.2507 loss_x_val_y: 0.2457 time: 0.0339s
#  Epoch: 0277 loss_train: 0.5026 loss_x_train_x: 0.2481 loss_x_train_y: 0.2525 loss_val: 0.4951 loss_x_val_x: 0.2503 loss_x_val_y: 0.2447 time: 0.0363s
#  Epoch: 0278 loss_train: 0.5064 loss_x_train_x: 0.2523 loss_x_train_y: 0.2521 loss_val: 0.4948 loss_x_val_x: 0.2502 loss_x_val_y: 0.2447 time: 0.0365s
#  Epoch: 0279 loss_train: 0.5014 loss_x_train_x: 0.2499 loss_x_train_y: 0.2496 loss_val: 0.4949 loss_x_val_x: 0.2502 loss_x_val_y: 0.2447 time: 0.0336s
#  Epoch: 0280 loss_train: 0.5013 loss_x_train_x: 0.2480 loss_x_train_y: 0.2514 loss_val: 0.4951 loss_x_val_x: 0.2504 loss_x_val_y: 0.2448 time: 0.0410s
#  Epoch: 0281 loss_train: 0.5042 loss_x_train_x: 0.2499 loss_x_train_y: 0.2523 loss_val: 0.4942 loss_x_val_x: 0.2498 loss_x_val_y: 0.2444 time: 0.0339s
#  Epoch: 0282 loss_train: 0.5034 loss_x_train_x: 0.2492 loss_x_train_y: 0.2523 loss_val: 0.4948 loss_x_val_x: 0.2503 loss_x_val_y: 0.2445 time: 0.0346s
#  Epoch: 0283 loss_train: 0.4982 loss_x_train_x: 0.2476 loss_x_train_y: 0.2487 loss_val: 0.4938 loss_x_val_x: 0.2497 loss_x_val_y: 0.2441 time: 0.0360s
#  Epoch: 0284 loss_train: 0.5027 loss_x_train_x: 0.2501 loss_x_train_y: 0.2506 loss_val: 0.4932 loss_x_val_x: 0.2491 loss_x_val_y: 0.2441 time: 0.0357s
#  Epoch: 0285 loss_train: 0.4973 loss_x_train_x: 0.2461 loss_x_train_y: 0.2493 loss_val: 0.4926 loss_x_val_x: 0.2488 loss_x_val_y: 0.2438 time: 0.0344s
#  Epoch: 0286 loss_train: 0.5010 loss_x_train_x: 0.2473 loss_x_train_y: 0.2518 loss_val: 0.4931 loss_x_val_x: 0.2493 loss_x_val_y: 0.2438 time: 0.0373s
#  Epoch: 0287 loss_train: 0.4999 loss_x_train_x: 0.2495 loss_x_train_y: 0.2484 loss_val: 0.4917 loss_x_val_x: 0.2481 loss_x_val_y: 0.2437 time: 0.0364s
#  Epoch: 0288 loss_train: 0.4993 loss_x_train_x: 0.2495 loss_x_train_y: 0.2478 loss_val: 0.4922 loss_x_val_x: 0.2483 loss_x_val_y: 0.2438 time: 0.0352s
#  Epoch: 0289 loss_train: 0.4987 loss_x_train_x: 0.2473 loss_x_train_y: 0.2495 loss_val: 0.4913 loss_x_val_x: 0.2476 loss_x_val_y: 0.2437 time: 0.0401s
#  Epoch: 0290 loss_train: 0.4972 loss_x_train_x: 0.2465 loss_x_train_y: 0.2487 loss_val: 0.4914 loss_x_val_x: 0.2476 loss_x_val_y: 0.2438 time: 0.0347s
#  Epoch: 0291 loss_train: 0.5005 loss_x_train_x: 0.2469 loss_x_train_y: 0.2517 loss_val: 0.4911 loss_x_val_x: 0.2474 loss_x_val_y: 0.2437 time: 0.0349s
#  Epoch: 0292 loss_train: 0.4938 loss_x_train_x: 0.2432 loss_x_train_y: 0.2486 loss_val: 0.4902 loss_x_val_x: 0.2466 loss_x_val_y: 0.2435 time: 0.0384s
#  Epoch: 0293 loss_train: 0.4964 loss_x_train_x: 0.2468 loss_x_train_y: 0.2477 loss_val: 0.4901 loss_x_val_x: 0.2466 loss_x_val_y: 0.2434 time: 0.0364s
#  Epoch: 0294 loss_train: 0.4961 loss_x_train_x: 0.2453 loss_x_train_y: 0.2489 loss_val: 0.4906 loss_x_val_x: 0.2474 loss_x_val_y: 0.2432 time: 0.0347s
#  Epoch: 0295 loss_train: 0.4975 loss_x_train_x: 0.2463 loss_x_train_y: 0.2492 loss_val: 0.4898 loss_x_val_x: 0.2469 loss_x_val_y: 0.2429 time: 0.0362s
#  Epoch: 0296 loss_train: 0.4955 loss_x_train_x: 0.2465 loss_x_train_y: 0.2470 loss_val: 0.4898 loss_x_val_x: 0.2466 loss_x_val_y: 0.2431 time: 0.0360s
#  Epoch: 0297 loss_train: 0.4922 loss_x_train_x: 0.2450 loss_x_train_y: 0.2453 loss_val: 0.4899 loss_x_val_x: 0.2469 loss_x_val_y: 0.2430 time: 0.0360s
#  Epoch: 0298 loss_train: 0.4958 loss_x_train_x: 0.2441 loss_x_train_y: 0.2497 loss_val: 0.4892 loss_x_val_x: 0.2464 loss_x_val_y: 0.2427 time: 0.0377s
#  Epoch: 0299 loss_train: 0.4975 loss_x_train_x: 0.2452 loss_x_train_y: 0.2504 loss_val: 0.4887 loss_x_val_x: 0.2462 loss_x_val_y: 0.2424 time: 0.0359s
#  Epoch: 0300 loss_train: 0.4924 loss_x_train_x: 0.2447 loss_x_train_y: 0.2458 loss_val: 0.4889 loss_x_val_x: 0.2464 loss_x_val_y: 0.2425 time: 0.0369s
#  Epoch: 0301 loss_train: 0.4934 loss_x_train_x: 0.2429 loss_x_train_y: 0.2486 loss_val: 0.4886 loss_x_val_x: 0.2463 loss_x_val_y: 0.2423 time: 0.0364s
#  Epoch: 0302 loss_train: 0.4939 loss_x_train_x: 0.2434 loss_x_train_y: 0.2485 loss_val: 0.4881 loss_x_val_x: 0.2460 loss_x_val_y: 0.2421 time: 0.0364s
#  Epoch: 0303 loss_train: 0.4919 loss_x_train_x: 0.2429 loss_x_train_y: 0.2470 loss_val: 0.4879 loss_x_val_x: 0.2460 loss_x_val_y: 0.2419 time: 0.0352s
#  Epoch: 0304 loss_train: 0.4929 loss_x_train_x: 0.2445 loss_x_train_y: 0.2465 loss_val: 0.4873 loss_x_val_x: 0.2456 loss_x_val_y: 0.2418 time: 0.0359s
#  Epoch: 0305 loss_train: 0.4920 loss_x_train_x: 0.2424 loss_x_train_y: 0.2477 loss_val: 0.4876 loss_x_val_x: 0.2457 loss_x_val_y: 0.2419 time: 0.0368s
#  Epoch: 0306 loss_train: 0.4903 loss_x_train_x: 0.2438 loss_x_train_y: 0.2446 loss_val: 0.4875 loss_x_val_x: 0.2456 loss_x_val_y: 0.2419 time: 0.0364s
#  Epoch: 0307 loss_train: 0.4881 loss_x_train_x: 0.2415 loss_x_train_y: 0.2446 loss_val: 0.4869 loss_x_val_x: 0.2451 loss_x_val_y: 0.2417 time: 0.0369s
#  Epoch: 0308 loss_train: 0.4866 loss_x_train_x: 0.2392 loss_x_train_y: 0.2455 loss_val: 0.4864 loss_x_val_x: 0.2448 loss_x_val_y: 0.2417 time: 0.0353s
#  Epoch: 0309 loss_train: 0.4894 loss_x_train_x: 0.2415 loss_x_train_y: 0.2461 loss_val: 0.4868 loss_x_val_x: 0.2452 loss_x_val_y: 0.2416 time: 0.0365s
#  Epoch: 0310 loss_train: 0.4906 loss_x_train_x: 0.2438 loss_x_train_y: 0.2448 loss_val: 0.4866 loss_x_val_x: 0.2449 loss_x_val_y: 0.2417 time: 0.0354s
#  Epoch: 0311 loss_train: 0.4865 loss_x_train_x: 0.2411 loss_x_train_y: 0.2435 loss_val: 0.4863 loss_x_val_x: 0.2448 loss_x_val_y: 0.2415 time: 0.0356s
#  Epoch: 0312 loss_train: 0.4869 loss_x_train_x: 0.2396 loss_x_train_y: 0.2454 loss_val: 0.4860 loss_x_val_x: 0.2446 loss_x_val_y: 0.2414 time: 0.0354s
#  Epoch: 0313 loss_train: 0.4862 loss_x_train_x: 0.2403 loss_x_train_y: 0.2439 loss_val: 0.4858 loss_x_val_x: 0.2446 loss_x_val_y: 0.2413 time: 0.0353s
#  Epoch: 0314 loss_train: 0.4927 loss_x_train_x: 0.2429 loss_x_train_y: 0.2478 loss_val: 0.4856 loss_x_val_x: 0.2445 loss_x_val_y: 0.2411 time: 0.0363s
#  Epoch: 0315 loss_train: 0.4878 loss_x_train_x: 0.2410 loss_x_train_y: 0.2449 loss_val: 0.4854 loss_x_val_x: 0.2444 loss_x_val_y: 0.2409 time: 0.0344s
#  Epoch: 0316 loss_train: 0.4882 loss_x_train_x: 0.2427 loss_x_train_y: 0.2435 loss_val: 0.4851 loss_x_val_x: 0.2443 loss_x_val_y: 0.2408 time: 0.0355s
# ...
#  Epoch: 2895 loss_train: 0.0440 loss_x_train_x: 0.0154 loss_x_train_y: 0.0240 loss_val: 0.6614 loss_x_val_x: 0.3250 loss_x_val_y: 0.3364 time: 0.0356s
#  Epoch: 2896 loss_train: 0.0431 loss_x_train_x: 0.0150 loss_x_train_y: 0.0235 loss_val: 0.6604 loss_x_val_x: 0.3247 loss_x_val_y: 0.3357 time: 0.0426s
#  Epoch: 2897 loss_train: 0.0426 loss_x_train_x: 0.0147 loss_x_train_y: 0.0233 loss_val: 0.6602 loss_x_val_x: 0.3246 loss_x_val_y: 0.3356 time: 0.0357s
#  Epoch: 2898 loss_train: 0.0452 loss_x_train_x: 0.0161 loss_x_train_y: 0.0244 loss_val: 0.6607 loss_x_val_x: 0.3246 loss_x_val_y: 0.3361 time: 0.0358s
#  Epoch: 2899 loss_train: 0.0439 loss_x_train_x: 0.0156 loss_x_train_y: 0.0236 loss_val: 0.6606 loss_x_val_x: 0.3250 loss_x_val_y: 0.3356 time: 0.0356s
#  Epoch: 2900 loss_train: 0.0431 loss_x_train_x: 0.0154 loss_x_train_y: 0.0230 loss_val: 0.6611 loss_x_val_x: 0.3249 loss_x_val_y: 0.3362 time: 0.0352s
#  Epoch: 2901 loss_train: 0.0425 loss_x_train_x: 0.0144 loss_x_train_y: 0.0234 loss_val: 0.6602 loss_x_val_x: 0.3245 loss_x_val_y: 0.3356 time: 0.0346s
#  Epoch: 2902 loss_train: 0.0436 loss_x_train_x: 0.0151 loss_x_train_y: 0.0238 loss_val: 0.6592 loss_x_val_x: 0.3237 loss_x_val_y: 0.3355 time: 0.0358s
#  Epoch: 2903 loss_train: 0.0422 loss_x_train_x: 0.0142 loss_x_train_y: 0.0233 loss_val: 0.6606 loss_x_val_x: 0.3249 loss_x_val_y: 0.3358 time: 0.0358s
#  Epoch: 2904 loss_train: 0.0444 loss_x_train_x: 0.0155 loss_x_train_y: 0.0243 loss_val: 0.6602 loss_x_val_x: 0.3242 loss_x_val_y: 0.3361 time: 0.0361s
#  Epoch: 2905 loss_train: 0.0425 loss_x_train_x: 0.0148 loss_x_train_y: 0.0230 loss_val: 0.6606 loss_x_val_x: 0.3243 loss_x_val_y: 0.3364 time: 0.0353s
#  Epoch: 2906 loss_train: 0.0433 loss_x_train_x: 0.0151 loss_x_train_y: 0.0236 loss_val: 0.6591 loss_x_val_x: 0.3240 loss_x_val_y: 0.3351 time: 0.0356s
#  Epoch: 2907 loss_train: 0.0432 loss_x_train_x: 0.0151 loss_x_train_y: 0.0234 loss_val: 0.6580 loss_x_val_x: 0.3229 loss_x_val_y: 0.3351 time: 0.0346s
#  Epoch: 2908 loss_train: 0.0424 loss_x_train_x: 0.0143 loss_x_train_y: 0.0235 loss_val: 0.6579 loss_x_val_x: 0.3225 loss_x_val_y: 0.3354 time: 0.0337s
#  Epoch: 2909 loss_train: 0.0439 loss_x_train_x: 0.0146 loss_x_train_y: 0.0246 loss_val: 0.6582 loss_x_val_x: 0.3228 loss_x_val_y: 0.3354 time: 0.0345s
#  Epoch: 2910 loss_train: 0.0424 loss_x_train_x: 0.0137 loss_x_train_y: 0.0240 loss_val: 0.6600 loss_x_val_x: 0.3229 loss_x_val_y: 0.3370 time: 0.0345s
#  Epoch: 2911 loss_train: 0.0429 loss_x_train_x: 0.0148 loss_x_train_y: 0.0234 loss_val: 0.6588 loss_x_val_x: 0.3232 loss_x_val_y: 0.3356 time: 0.0331s
#  Epoch: 2912 loss_train: 0.0429 loss_x_train_x: 0.0140 loss_x_train_y: 0.0242 loss_val: 0.6600 loss_x_val_x: 0.3238 loss_x_val_y: 0.3362 time: 0.0330s
#  Epoch: 2913 loss_train: 0.0423 loss_x_train_x: 0.0148 loss_x_train_y: 0.0229 loss_val: 0.6607 loss_x_val_x: 0.3237 loss_x_val_y: 0.3370 time: 0.0331s
#  Epoch: 2914 loss_train: 0.0413 loss_x_train_x: 0.0132 loss_x_train_y: 0.0234 loss_val: 0.6606 loss_x_val_x: 0.3241 loss_x_val_y: 0.3365 time: 0.0330s
#  Epoch: 2915 loss_train: 0.0433 loss_x_train_x: 0.0145 loss_x_train_y: 0.0242 loss_val: 0.6611 loss_x_val_x: 0.3248 loss_x_val_y: 0.3362 time: 0.0331s
#  Epoch: 2916 loss_train: 0.0448 loss_x_train_x: 0.0153 loss_x_train_y: 0.0248 loss_val: 0.6621 loss_x_val_x: 0.3253 loss_x_val_y: 0.3367 time: 0.0331s
#  Epoch: 2917 loss_train: 0.0433 loss_x_train_x: 0.0143 loss_x_train_y: 0.0243 loss_val: 0.6609 loss_x_val_x: 0.3249 loss_x_val_y: 0.3359 time: 0.0346s
#  Epoch: 2918 loss_train: 0.0430 loss_x_train_x: 0.0138 loss_x_train_y: 0.0244 loss_val: 0.6597 loss_x_val_x: 0.3238 loss_x_val_y: 0.3360 time: 0.0330s
#  Epoch: 2919 loss_train: 0.0445 loss_x_train_x: 0.0153 loss_x_train_y: 0.0245 loss_val: 0.6602 loss_x_val_x: 0.3241 loss_x_val_y: 0.3361 time: 0.0334s
#  Epoch: 2920 loss_train: 0.0445 loss_x_train_x: 0.0148 loss_x_train_y: 0.0250 loss_val: 0.6625 loss_x_val_x: 0.3261 loss_x_val_y: 0.3365 time: 0.0331s
#  Epoch: 2921 loss_train: 0.0429 loss_x_train_x: 0.0145 loss_x_train_y: 0.0237 loss_val: 0.6614 loss_x_val_x: 0.3250 loss_x_val_y: 0.3364 time: 0.0332s
#  Epoch: 2922 loss_train: 0.0417 loss_x_train_x: 0.0138 loss_x_train_y: 0.0232 loss_val: 0.6612 loss_x_val_x: 0.3249 loss_x_val_y: 0.3363 time: 0.0332s
#  Epoch: 2923 loss_train: 0.0403 loss_x_train_x: 0.0135 loss_x_train_y: 0.0221 loss_val: 0.6618 loss_x_val_x: 0.3249 loss_x_val_y: 0.3369 time: 0.0333s
#  Epoch: 2924 loss_train: 0.0420 loss_x_train_x: 0.0140 loss_x_train_y: 0.0233 loss_val: 0.6624 loss_x_val_x: 0.3254 loss_x_val_y: 0.3370 time: 0.0345s
#  Epoch: 2925 loss_train: 0.0450 loss_x_train_x: 0.0167 loss_x_train_y: 0.0236 loss_val: 0.6621 loss_x_val_x: 0.3256 loss_x_val_y: 0.3365 time: 0.0331s
#  Epoch: 2926 loss_train: 0.0433 loss_x_train_x: 0.0143 loss_x_train_y: 0.0244 loss_val: 0.6630 loss_x_val_x: 0.3262 loss_x_val_y: 0.3368 time: 0.0331s
#  Epoch: 2927 loss_train: 0.0441 loss_x_train_x: 0.0140 loss_x_train_y: 0.0255 loss_val: 0.6626 loss_x_val_x: 0.3253 loss_x_val_y: 0.3373 time: 0.0332s
#  Epoch: 2928 loss_train: 0.0418 loss_x_train_x: 0.0137 loss_x_train_y: 0.0234 loss_val: 0.6615 loss_x_val_x: 0.3250 loss_x_val_y: 0.3365 time: 0.0331s
#  Epoch: 2929 loss_train: 0.0437 loss_x_train_x: 0.0146 loss_x_train_y: 0.0245 loss_val: 0.6617 loss_x_val_x: 0.3253 loss_x_val_y: 0.3364 time: 0.0334s
#  Epoch: 2930 loss_train: 0.0435 loss_x_train_x: 0.0149 loss_x_train_y: 0.0239 loss_val: 0.6611 loss_x_val_x: 0.3250 loss_x_val_y: 0.3361 time: 0.0331s
#  Epoch: 2931 loss_train: 0.0427 loss_x_train_x: 0.0145 loss_x_train_y: 0.0234 loss_val: 0.6613 loss_x_val_x: 0.3249 loss_x_val_y: 0.3365 time: 0.0331s
#  Epoch: 2932 loss_train: 0.0423 loss_x_train_x: 0.0144 loss_x_train_y: 0.0232 loss_val: 0.6614 loss_x_val_x: 0.3247 loss_x_val_y: 0.3367 time: 0.0331s
#  Epoch: 2933 loss_train: 0.0439 loss_x_train_x: 0.0145 loss_x_train_y: 0.0246 loss_val: 0.6627 loss_x_val_x: 0.3256 loss_x_val_y: 0.3370 time: 0.0330s
#  Epoch: 2934 loss_train: 0.0418 loss_x_train_x: 0.0140 loss_x_train_y: 0.0231 loss_val: 0.6604 loss_x_val_x: 0.3247 loss_x_val_y: 0.3356 time: 0.0331s
#  Epoch: 2935 loss_train: 0.0427 loss_x_train_x: 0.0144 loss_x_train_y: 0.0235 loss_val: 0.6591 loss_x_val_x: 0.3245 loss_x_val_y: 0.3346 time: 0.0330s
#  Epoch: 2936 loss_train: 0.0430 loss_x_train_x: 0.0142 loss_x_train_y: 0.0241 loss_val: 0.6580 loss_x_val_x: 0.3239 loss_x_val_y: 0.3341 time: 0.0334s
#  Epoch: 2937 loss_train: 0.0428 loss_x_train_x: 0.0147 loss_x_train_y: 0.0235 loss_val: 0.6608 loss_x_val_x: 0.3250 loss_x_val_y: 0.3358 time: 0.0370s
#  Epoch: 2938 loss_train: 0.0417 loss_x_train_x: 0.0144 loss_x_train_y: 0.0226 loss_val: 0.6598 loss_x_val_x: 0.3240 loss_x_val_y: 0.3358 time: 0.0391s
#  Epoch: 2939 loss_train: 0.0433 loss_x_train_x: 0.0146 loss_x_train_y: 0.0240 loss_val: 0.6593 loss_x_val_x: 0.3240 loss_x_val_y: 0.3353 time: 0.0388s
#  Epoch: 2940 loss_train: 0.0427 loss_x_train_x: 0.0149 loss_x_train_y: 0.0231 loss_val: 0.6590 loss_x_val_x: 0.3237 loss_x_val_y: 0.3353 time: 0.0387s
#  Epoch: 2941 loss_train: 0.0413 loss_x_train_x: 0.0150 loss_x_train_y: 0.0217 loss_val: 0.6600 loss_x_val_x: 0.3250 loss_x_val_y: 0.3350 time: 0.0388s
#  Epoch: 2942 loss_train: 0.0404 loss_x_train_x: 0.0141 loss_x_train_y: 0.0217 loss_val: 0.6608 loss_x_val_x: 0.3253 loss_x_val_y: 0.3355 time: 0.0355s
#  Epoch: 2943 loss_train: 0.0427 loss_x_train_x: 0.0144 loss_x_train_y: 0.0236 loss_val: 0.6610 loss_x_val_x: 0.3247 loss_x_val_y: 0.3363 time: 0.0331s
#  Epoch: 2944 loss_train: 0.0423 loss_x_train_x: 0.0138 loss_x_train_y: 0.0238 loss_val: 0.6615 loss_x_val_x: 0.3245 loss_x_val_y: 0.3371 time: 0.0330s
#  Epoch: 2945 loss_train: 0.0432 loss_x_train_x: 0.0144 loss_x_train_y: 0.0241 loss_val: 0.6608 loss_x_val_x: 0.3245 loss_x_val_y: 0.3363 time: 0.0331s
#  Epoch: 2946 loss_train: 0.0448 loss_x_train_x: 0.0160 loss_x_train_y: 0.0242 loss_val: 0.6619 loss_x_val_x: 0.3249 loss_x_val_y: 0.3370 time: 0.0330s
#  Epoch: 2947 loss_train: 0.0410 loss_x_train_x: 0.0134 loss_x_train_y: 0.0228 loss_val: 0.6612 loss_x_val_x: 0.3245 loss_x_val_y: 0.3368 time: 0.0331s
#  Epoch: 2948 loss_train: 0.0421 loss_x_train_x: 0.0144 loss_x_train_y: 0.0231 loss_val: 0.6606 loss_x_val_x: 0.3246 loss_x_val_y: 0.3361 time: 0.0330s
#  Epoch: 2949 loss_train: 0.0416 loss_x_train_x: 0.0133 loss_x_train_y: 0.0236 loss_val: 0.6608 loss_x_val_x: 0.3246 loss_x_val_y: 0.3362 time: 0.0335s
#  Epoch: 2950 loss_train: 0.0450 loss_x_train_x: 0.0146 loss_x_train_y: 0.0256 loss_val: 0.6606 loss_x_val_x: 0.3248 loss_x_val_y: 0.3358 time: 0.0331s
#  Epoch: 2951 loss_train: 0.0414 loss_x_train_x: 0.0142 loss_x_train_y: 0.0225 loss_val: 0.6622 loss_x_val_x: 0.3255 loss_x_val_y: 0.3367 time: 0.0331s
#  Epoch: 2952 loss_train: 0.0426 loss_x_train_x: 0.0149 loss_x_train_y: 0.0231 loss_val: 0.6628 loss_x_val_x: 0.3259 loss_x_val_y: 0.3369 time: 0.0330s
#  Epoch: 2953 loss_train: 0.0425 loss_x_train_x: 0.0148 loss_x_train_y: 0.0230 loss_val: 0.6610 loss_x_val_x: 0.3257 loss_x_val_y: 0.3353 time: 0.0331s
#  Epoch: 2954 loss_train: 0.0416 loss_x_train_x: 0.0139 loss_x_train_y: 0.0230 loss_val: 0.6590 loss_x_val_x: 0.3239 loss_x_val_y: 0.3351 time: 0.0332s
#  Epoch: 2955 loss_train: 0.0431 loss_x_train_x: 0.0153 loss_x_train_y: 0.0231 loss_val: 0.6587 loss_x_val_x: 0.3238 loss_x_val_y: 0.3350 time: 0.0331s
#  Epoch: 2956 loss_train: 0.0430 loss_x_train_x: 0.0147 loss_x_train_y: 0.0236 loss_val: 0.6598 loss_x_val_x: 0.3242 loss_x_val_y: 0.3355 time: 0.0351s
#  Epoch: 2957 loss_train: 0.0422 loss_x_train_x: 0.0152 loss_x_train_y: 0.0224 loss_val: 0.6590 loss_x_val_x: 0.3239 loss_x_val_y: 0.3351 time: 0.0330s
#  Epoch: 2958 loss_train: 0.0432 loss_x_train_x: 0.0141 loss_x_train_y: 0.0244 loss_val: 0.6603 loss_x_val_x: 0.3246 loss_x_val_y: 0.3357 time: 0.0331s
#  Epoch: 2959 loss_train: 0.0424 loss_x_train_x: 0.0143 loss_x_train_y: 0.0234 loss_val: 0.6604 loss_x_val_x: 0.3245 loss_x_val_y: 0.3358 time: 0.0331s
#  Epoch: 2960 loss_train: 0.0436 loss_x_train_x: 0.0150 loss_x_train_y: 0.0238 loss_val: 0.6616 loss_x_val_x: 0.3253 loss_x_val_y: 0.3362 time: 0.0331s
#  Epoch: 2961 loss_train: 0.0449 loss_x_train_x: 0.0155 loss_x_train_y: 0.0246 loss_val: 0.6623 loss_x_val_x: 0.3254 loss_x_val_y: 0.3369 time: 0.0330s
#  Epoch: 2962 loss_train: 0.0437 loss_x_train_x: 0.0148 loss_x_train_y: 0.0242 loss_val: 0.6615 loss_x_val_x: 0.3250 loss_x_val_y: 0.3365 time: 0.0331s
#  Epoch: 2963 loss_train: 0.0450 loss_x_train_x: 0.0153 loss_x_train_y: 0.0250 loss_val: 0.6611 loss_x_val_x: 0.3253 loss_x_val_y: 0.3358 time: 0.0334s
#  Epoch: 2964 loss_train: 0.0419 loss_x_train_x: 0.0145 loss_x_train_y: 0.0227 loss_val: 0.6612 loss_x_val_x: 0.3245 loss_x_val_y: 0.3367 time: 0.0343s
#  Epoch: 2965 loss_train: 0.0412 loss_x_train_x: 0.0140 loss_x_train_y: 0.0225 loss_val: 0.6615 loss_x_val_x: 0.3253 loss_x_val_y: 0.3362 time: 0.0331s
#  Epoch: 2966 loss_train: 0.0424 loss_x_train_x: 0.0145 loss_x_train_y: 0.0232 loss_val: 0.6605 loss_x_val_x: 0.3252 loss_x_val_y: 0.3353 time: 0.0331s
#  Epoch: 2967 loss_train: 0.0417 loss_x_train_x: 0.0146 loss_x_train_y: 0.0224 loss_val: 0.6591 loss_x_val_x: 0.3247 loss_x_val_y: 0.3345 time: 0.0330s
#  Epoch: 2968 loss_train: 0.0433 loss_x_train_x: 0.0150 loss_x_train_y: 0.0236 loss_val: 0.6595 loss_x_val_x: 0.3243 loss_x_val_y: 0.3352 time: 0.0336s
#  Epoch: 2969 loss_train: 0.0405 loss_x_train_x: 0.0133 loss_x_train_y: 0.0225 loss_val: 0.6592 loss_x_val_x: 0.3238 loss_x_val_y: 0.3353 time: 0.0349s
#  Epoch: 2970 loss_train: 0.0432 loss_x_train_x: 0.0143 loss_x_train_y: 0.0242 loss_val: 0.6599 loss_x_val_x: 0.3247 loss_x_val_y: 0.3352 time: 0.0331s
#  Epoch: 2971 loss_train: 0.0413 loss_x_train_x: 0.0144 loss_x_train_y: 0.0222 loss_val: 0.6613 loss_x_val_x: 0.3257 loss_x_val_y: 0.3356 time: 0.0332s
#  Epoch: 2972 loss_train: 0.0429 loss_x_train_x: 0.0142 loss_x_train_y: 0.0240 loss_val: 0.6617 loss_x_val_x: 0.3256 loss_x_val_y: 0.3361 time: 0.0330s
#  Epoch: 2973 loss_train: 0.0421 loss_x_train_x: 0.0138 loss_x_train_y: 0.0236 loss_val: 0.6606 loss_x_val_x: 0.3245 loss_x_val_y: 0.3361 time: 0.0330s
#  Epoch: 2974 loss_train: 0.0436 loss_x_train_x: 0.0146 loss_x_train_y: 0.0243 loss_val: 0.6598 loss_x_val_x: 0.3246 loss_x_val_y: 0.3351 time: 0.0331s
#  Epoch: 2975 loss_train: 0.0426 loss_x_train_x: 0.0143 loss_x_train_y: 0.0236 loss_val: 0.6594 loss_x_val_x: 0.3242 loss_x_val_y: 0.3351 time: 0.0330s
#  Epoch: 2976 loss_train: 0.0435 loss_x_train_x: 0.0143 loss_x_train_y: 0.0246 loss_val: 0.6605 loss_x_val_x: 0.3243 loss_x_val_y: 0.3362 time: 0.0347s
#  Epoch: 2977 loss_train: 0.0422 loss_x_train_x: 0.0146 loss_x_train_y: 0.0229 loss_val: 0.6614 loss_x_val_x: 0.3252 loss_x_val_y: 0.3361 time: 0.0331s
#  Epoch: 2978 loss_train: 0.0405 loss_x_train_x: 0.0133 loss_x_train_y: 0.0225 loss_val: 0.6593 loss_x_val_x: 0.3239 loss_x_val_y: 0.3355 time: 0.0331s
#  Epoch: 2979 loss_train: 0.0430 loss_x_train_x: 0.0148 loss_x_train_y: 0.0234 loss_val: 0.6594 loss_x_val_x: 0.3240 loss_x_val_y: 0.3354 time: 0.0343s
#  Epoch: 2980 loss_train: 0.0426 loss_x_train_x: 0.0153 loss_x_train_y: 0.0226 loss_val: 0.6607 loss_x_val_x: 0.3247 loss_x_val_y: 0.3360 time: 0.0361s
#  Epoch: 2981 loss_train: 0.0425 loss_x_train_x: 0.0143 loss_x_train_y: 0.0235 loss_val: 0.6614 loss_x_val_x: 0.3252 loss_x_val_y: 0.3362 time: 0.0346s
#  Epoch: 2982 loss_train: 0.0414 loss_x_train_x: 0.0138 loss_x_train_y: 0.0229 loss_val: 0.6610 loss_x_val_x: 0.3245 loss_x_val_y: 0.3365 time: 0.0359s
#  Epoch: 2983 loss_train: 0.0418 loss_x_train_x: 0.0132 loss_x_train_y: 0.0238 loss_val: 0.6603 loss_x_val_x: 0.3242 loss_x_val_y: 0.3361 time: 0.0356s
#  Epoch: 2984 loss_train: 0.0408 loss_x_train_x: 0.0132 loss_x_train_y: 0.0228 loss_val: 0.6599 loss_x_val_x: 0.3243 loss_x_val_y: 0.3356 time: 0.0349s
#  Epoch: 2985 loss_train: 0.0449 loss_x_train_x: 0.0158 loss_x_train_y: 0.0243 loss_val: 0.6606 loss_x_val_x: 0.3245 loss_x_val_y: 0.3361 time: 0.0349s
#  Epoch: 2986 loss_train: 0.0414 loss_x_train_x: 0.0141 loss_x_train_y: 0.0225 loss_val: 0.6605 loss_x_val_x: 0.3253 loss_x_val_y: 0.3352 time: 0.0346s
#  Epoch: 2987 loss_train: 0.0431 loss_x_train_x: 0.0146 loss_x_train_y: 0.0237 loss_val: 0.6600 loss_x_val_x: 0.3257 loss_x_val_y: 0.3343 time: 0.0357s
#  Epoch: 2988 loss_train: 0.0417 loss_x_train_x: 0.0148 loss_x_train_y: 0.0221 loss_val: 0.6587 loss_x_val_x: 0.3240 loss_x_val_y: 0.3347 time: 0.0360s
#  Epoch: 2989 loss_train: 0.0420 loss_x_train_x: 0.0149 loss_x_train_y: 0.0224 loss_val: 0.6588 loss_x_val_x: 0.3244 loss_x_val_y: 0.3343 time: 0.0385s
#  Epoch: 2990 loss_train: 0.0429 loss_x_train_x: 0.0146 loss_x_train_y: 0.0235 loss_val: 0.6599 loss_x_val_x: 0.3245 loss_x_val_y: 0.3353 time: 0.0389s
#  Epoch: 2991 loss_train: 0.0415 loss_x_train_x: 0.0142 loss_x_train_y: 0.0226 loss_val: 0.6603 loss_x_val_x: 0.3256 loss_x_val_y: 0.3347 time: 0.0376s
#  Epoch: 2992 loss_train: 0.0430 loss_x_train_x: 0.0151 loss_x_train_y: 0.0231 loss_val: 0.6591 loss_x_val_x: 0.3252 loss_x_val_y: 0.3339 time: 0.0356s
#  Epoch: 2993 loss_train: 0.0435 loss_x_train_x: 0.0153 loss_x_train_y: 0.0234 loss_val: 0.6607 loss_x_val_x: 0.3258 loss_x_val_y: 0.3349 time: 0.0381s
#  Epoch: 2994 loss_train: 0.0422 loss_x_train_x: 0.0147 loss_x_train_y: 0.0228 loss_val: 0.6598 loss_x_val_x: 0.3254 loss_x_val_y: 0.3345 time: 0.0391s
#  Epoch: 2995 loss_train: 0.0418 loss_x_train_x: 0.0147 loss_x_train_y: 0.0224 loss_val: 0.6598 loss_x_val_x: 0.3249 loss_x_val_y: 0.3349 time: 0.0379s
#  Epoch: 2996 loss_train: 0.0412 loss_x_train_x: 0.0140 loss_x_train_y: 0.0226 loss_val: 0.6588 loss_x_val_x: 0.3242 loss_x_val_y: 0.3345 time: 0.0337s
#  Epoch: 2997 loss_train: 0.0420 loss_x_train_x: 0.0144 loss_x_train_y: 0.0229 loss_val: 0.6605 loss_x_val_x: 0.3247 loss_x_val_y: 0.3358 time: 0.0337s
#  Epoch: 2998 loss_train: 0.0418 loss_x_train_x: 0.0138 loss_x_train_y: 0.0232 loss_val: 0.6586 loss_x_val_x: 0.3232 loss_x_val_y: 0.3354 time: 0.0327s
#  Epoch: 2999 loss_train: 0.0417 loss_x_train_x: 0.0143 loss_x_train_y: 0.0226 loss_val: 0.6586 loss_x_val_x: 0.3236 loss_x_val_y: 0.3350 time: 0.0327s
#  total time: 110.2817s

# %%
with open(os.path.join(logsavepath,'train_loss_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_x_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_x_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_y_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_loss_y, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_y_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(val_loss_y, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNorm_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNormx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm_x, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_lNormy_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)), 'wb') as output:
    pickle.dump(train_lNorm_y, output, pickle.HIGHEST_PROTOCOL)



plt.plot(np.arange(epochs),train_loss_x)
plt.plot(np.arange(epochs),val_loss_x)
plt.legend(['training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_x'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()



plt.plot(np.arange(epochs),train_loss_y)
plt.plot(np.arange(epochs),val_loss_y)
plt.legend(['training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_y'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()


plt.plot(np.arange(epochs),train_lNorm)
plt.plot(np.arange(epochs),train_lNorm_x)
plt.plot(np.arange(epochs),train_lNorm_y)
plt.legend(['shared l2','x l2','y l2'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_lNorm'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.jpg'))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,3))
plt.plot(np.arange(epochs),train_loss_x)
plt.plot(np.arange(epochs),train_loss_y)
plt.legend(['Modality 1 reconstruction','Modality 2 reconstruction','training kl loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'fig_loss_xy'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.pdf'))
plt.show()

fig, ax = plt.subplots(figsize=(3,3))
plt.plot(np.arange(epochs),train_lNorm)
plt.plot(np.arange(epochs),train_lNorm_x)
plt.plot(np.arange(epochs),train_lNorm_y)
plt.legend(['Shared l2','Modality 1 l2','Modality 2 l2'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'fig_loss_lNorm'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'.pdf'))
plt.show()

# %%
latent_shared=torch.nn.Embedding(X.shape[0],sharedSize)
latent_x=torch.nn.Embedding(X.shape[0],dSpecificSize)
latent_y=torch.nn.Embedding(X.shape[0],dSpecificSize)

loadEpoch='2000'
with open(os.path.join(modelsavepath,'latentx_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_x.weight=pickle.load(output)
with open(os.path.join(modelsavepath,'latentShared_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_shared.weight=pickle.load( output)
with open(os.path.join(modelsavepath,'latenty_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed)+'_ep'+str(loadEpoch)), 'rb') as output:
    latent_y.weight=pickle.load(output)
latent_x.weight.requires_grad=False
latent_shared.weight.requires_grad=False
latent_y.weight.requires_grad=False

# %%
n_neighbors=10
min_dist=0.25

reducer_sharedlatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_shared.weight[trainIdx_all].cpu().detach())

# %%
def plotembeddingbyCT(ctlist,savename,excludelist,embedding,savepath,plotname,plotdimx=0,plotdimy=1,savenameAdd='',img=None,ncolors=None,colorseq=None,s=2.5):
    
    celltypes=np.unique(ctlist)
    if ncolors is None:
        colortest=sns.color_palette("husl", celltypes.size)
        if colorseq is None:
            colorseq=np.arange(celltypes.size)
    else:
        colortest=sns.color_palette("husl", ncolors)
        if colorseq is None:
            colorseq=np.arange(ncolors)
    
    fig, ax = plt.subplots(dpi=400)
    if not img is None:
        plt.imshow(img)
    for ct in celltypes:
        if ct in excludelist:
            continue
        idx=(ctlist==ct)
        if not img is None:
            ax.scatter(
                embedding[idx, plotdimy],
                embedding[idx, plotdimx],
                color=colortest[colorseq[int(ct)]],label=ct,s=1.5,alpha=0.5
                )
        else:
            ax.scatter(
                embedding[idx, plotdimx],
                embedding[idx, plotdimy],
                color=colortest[colorseq[int(ct)]],label=ct,s=s,alpha=1
                )

    plt.gca().set_aspect('equal', 'datalim')
    fig.set_figheight(5)
    fig.set_figwidth(5)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.1,
                     box.width, box.height * 0.9])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
              fancybox=True,ncol=5, shadow=True,prop={'size': 6})
    plt.title(plotname+' embedding', fontsize=12)
    plt.savefig(os.path.join(savepath,savename+savenameAdd+'.pdf'))
    plt.close('all')
    
def plotembeddingbyCT_str(ctlist,savename,excludelist,embedding,savepath,plotname,plotdimx=0,plotdimy=1,savenameAdd=''):
    celltypes=np.unique(ctlist)
    celltypes_dict={}
    idx=0
    for ct in celltypes:
        celltypes_dict[ct]=idx
        idx+=1
        
    colortest=sns.color_palette("husl", celltypes.size)
    fig, ax = plt.subplots(dpi=400)
    for ct in celltypes:
        if ct in excludelist:
            continue
        idx=(ctlist==ct)
        ax.scatter(
            embedding[idx, plotdimx],
            embedding[idx, plotdimy],
            color=colortest[celltypes_dict[ct]],label=ct,s=1,alpha=0.5
            )

    plt.gca().set_aspect('equal', 'datalim')
    fig.set_figheight(4)
    fig.set_figwidth(4)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.3,
                     box.width, box.height * 0.7])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), 
              fancybox=True, ncol=3, shadow=True, prop={'size': 6})
    plt.title(plotname, fontsize=12)
    plt.savefig(os.path.join(savepath,savename+savenameAdd+'.pdf'))
    plt.close('all')
    
    gc.collect()

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_shared_latent',[],reducer_sharedlatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_shared_latent',[],reducer_sharedlatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
reducer_ylatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_y.weight[trainIdx_all].cpu().detach())

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_Y_latent',[],reducer_ylatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_Y_latent',[],reducer_ylatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
reducer_xlatent = umap.UMAP(n_neighbors=n_neighbors,min_dist=min_dist,random_state=3).fit(latent_x.weight[trainIdx_all].cpu().detach())

# %%
plotembeddingbyCT_str(np.array(Z3[trainIdx_all]),'Z3_X_latent',[],reducer_xlatent.embedding_,plotsavepath,'Z3',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))
plotembeddingbyCT_str(np.array(Z1[trainIdx_all]),'Z1_X_latent',[],reducer_xlatent.embedding_,plotsavepath,'Z1',plotdimx=0,plotdimy=1,savenameAdd='_'+str(sharedSize)+'_'+str(dSpecificSize)+'_'+str(hiddenSize)+'_'+str(seed))

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(latent_shared.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.5727865

# %%
silhouette_score(latent_shared.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.060096707

# %%
silhouette_score(latent_x.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.6115319

# %%
silhouette_score(latent_x.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.19537361

# %%
silhouette_score(latent_y.weight[trainIdx_all].cpu().detach(),Z1[trainIdx_all])
# Out:
# 0.16860898

# %%
silhouette_score(latent_y.weight[trainIdx_all].cpu().detach(),Z3[trainIdx_all])
# Out:
# 0.00096430077
